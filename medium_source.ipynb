# %% [markdown]
# # Libraries

# %%
# pip install TA-Lib

# %%
# Import the Libraries

# Data Manupulation
import numpy as np
import pandas as pd
import scipy.stats as stats
from datetime import datetime, timedelta

# Techinical Indicators
# import talib as ta

# Plotting graphs
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report

# Data fetching
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# # Stock Data

# %% [markdown]
# ## TISCO

# %% [markdown]
# ### 1m

# %%
# TISCO 1m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
TISCO_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_1m_df = pd.concat([TISCO_1m_df, data])

# Reset the index to get Date as a column
TISCO_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_1m_df)

# # Save the DataFrame to a CSV file
# TISCO_1m_df.to_csv('data_TISCO_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date    Open   High     Low  Close  \
# 0         1m 2024-01-03 10:00:00+07:00   99.50   99.5   99.50   99.5
# 1         1m 2024-01-03 10:02:00+07:00   99.75  100.0   99.75  100.0
# 2         1m 2024-01-03 10:03:00+07:00  100.00  100.0  100.00  100.0
# 3         1m 2024-01-03 10:04:00+07:00  100.00  100.5  100.00  100.5
# 4         1m 2024-01-03 10:05:00+07:00  100.50  100.5  100.00  100.5
# ..       ...                       ...     ...    ...     ...    ...
# 722       1m 2024-01-05 16:25:00+07:00  100.50  100.5  100.00  100.5
# 723       1m 2024-01-05 16:26:00+07:00  100.50  100.5  100.00  100.0
# 724       1m 2024-01-05 16:27:00+07:00  100.00  100.5  100.00  100.5
# 725       1m 2024-01-05 16:28:00+07:00  100.50  100.5  100.00  100.0
# 726       1m 2024-01-05 16:29:00+07:00  100.50  100.5  100.00  100.5
#
#      Adj Close  Volume
# 0         99.5       0
# 1        100.0  241605
# 2        100.0    5245
# 3        100.5  675732
# 4        100.5  200635
# ..         ...     ...
# 722      100.5    2801
# 723      100.0    5900
# 724      100.5   19371
# 725      100.0    9400
# 726      100.5    5300
#
# [727 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# TISCO 2m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
TISCO_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_2m_df = pd.concat([TISCO_2m_df, data])

# Reset the index to get Date as a column
TISCO_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_2m_df)

# # Save the DataFrame to a CSV file
# TISCO_2m_df.to_csv('data_TISCO_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date   Open   High    Low  Close  \
# 0          2m 2023-11-20 10:00:00+07:00   97.5   97.5   97.5   97.5
# 1          2m 2023-11-20 10:02:00+07:00   97.5   97.5   97.5   97.5
# 2          2m 2023-11-20 10:04:00+07:00   97.5   97.5   97.5   97.5
# 3          2m 2023-11-20 10:06:00+07:00   97.5   97.5   97.5   97.5
# 4          2m 2023-11-20 10:08:00+07:00   97.5   97.5   97.5   97.5
# ...       ...                       ...    ...    ...    ...    ...
# 3900       2m 2024-01-05 16:20:00+07:00  100.5  100.5  100.0  100.5
# 3901       2m 2024-01-05 16:22:00+07:00  100.0  100.5  100.0  100.5
# 3902       2m 2024-01-05 16:24:00+07:00  100.0  100.5  100.0  100.5
# 3903       2m 2024-01-05 16:26:00+07:00  100.5  100.5  100.0  100.5
# 3904       2m 2024-01-05 16:28:00+07:00  100.5  100.5  100.0  100.5
#
#       Adj Close  Volume
# 0          97.5       0
# 1          97.5   59432
# 2          97.5    5900
# 3          97.5      92
# 4          97.5   10015
# ...         ...     ...
# 3900      100.5    8700
# 3901      100.5    9900
# 3902      100.5    9111
# 3903      100.5   25271
# 3904      100.5   14700
#
# [3905 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# TISCO 5m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
TISCO_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_5m_df = pd.concat([TISCO_5m_df, data])

# Reset the index to get Date as a column
TISCO_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_5m_df)

# # Save the DataFrame to a CSV file
# TISCO_5m_df.to_csv('data_TISCO_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date    Open   High     Low   Close  \
# 0          5m 2023-11-09 10:00:00+07:00   97.00   97.0   96.75   96.75
# 1          5m 2023-11-09 10:05:00+07:00   96.75   97.0   96.75   97.00
# 2          5m 2023-11-09 10:10:00+07:00   96.75   97.0   96.75   96.75
# 3          5m 2023-11-09 10:15:00+07:00   96.75   97.0   96.75   96.75
# 4          5m 2023-11-09 10:20:00+07:00   96.75   97.0   96.75   97.00
# ...       ...                       ...     ...    ...     ...     ...
# 2020       5m 2024-01-05 16:05:00+07:00  100.50  100.5  100.00  100.50
# 2021       5m 2024-01-05 16:10:00+07:00  100.00  100.5  100.00  100.50
# 2022       5m 2024-01-05 16:15:00+07:00  100.50  100.5  100.00  100.50
# 2023       5m 2024-01-05 16:20:00+07:00  100.50  100.5  100.00  100.50
# 2024       5m 2024-01-05 16:25:00+07:00  100.50  100.5  100.00  100.50
#
#       Adj Close  Volume
# 0         96.75       0
# 1         97.00    7200
# 2         96.75    7667
# 3         96.75   10837
# 4         97.00  229149
# ...         ...     ...
# 2020     100.50   15428
# 2021     100.50   31955
# 2022     100.50   24401
# 2023     100.50   24910
# 2024     100.50   42772
#
# [2025 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# TISCO 15m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
TISCO_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_15m_df = pd.concat([TISCO_15m_df, data])

# Reset the index to get Date as a column
TISCO_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_15m_df)

# # Save the DataFrame to a CSV file
# TISCO_15m_df.to_csv('data_TISCO_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date    Open   High     Low   Close  Adj Close  \
# 0        15m 2023-11-09 10:00:00   97.00   97.0   96.75   96.75      96.75
# 1        15m 2023-11-09 10:15:00   96.75   97.0   96.75   97.00      97.00
# 2        15m 2023-11-09 10:30:00   96.75   97.0   96.75   96.75      96.75
# 3        15m 2023-11-09 10:45:00   96.75   97.0   96.75   96.75      96.75
# 4        15m 2023-11-09 11:00:00   96.75   97.0   96.75   97.00      97.00
# ..       ...                 ...     ...    ...     ...     ...        ...
# 698      15m 2024-01-05 15:15:00  100.00  100.5  100.00  100.50     100.50
# 699      15m 2024-01-05 15:30:00  100.00  100.5  100.00  100.50     100.50
# 700      15m 2024-01-05 15:45:00  100.50  100.5  100.00  100.50     100.50
# 701      15m 2024-01-05 16:00:00  100.50  100.5  100.00  100.50     100.50
# 702      15m 2024-01-05 16:15:00  100.50  100.5  100.00  100.50     100.50
#
#      Volume
# 0     14867
# 1    245949
# 2     50562
# 3      2683
# 4     72211
# ..      ...
# 698   30995
# 699   66794
# 700   55503
# 701   64386
# 702   92083
#
# [703 rows x 8 columns]

# %% [markdown]
# ## ERW

# %% [markdown]
# ### 1m

# %%
# ERW 1m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
ERW_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_1m_df = pd.concat([ERW_1m_df, data])

# Reset the index to get Date as a column
ERW_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_1m_df)

# # Save the DataFrame to a CSV file
# ERW_1m_df.to_csv('data_ERW_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0         1m 2024-01-03 10:00:00+07:00  5.15  5.15  5.15   5.15       5.15
# 1         1m 2024-01-03 10:01:00+07:00  5.15  5.20  5.15   5.20       5.20
# 2         1m 2024-01-03 10:02:00+07:00  5.15  5.15  5.15   5.15       5.15
# 3         1m 2024-01-03 10:03:00+07:00  5.15  5.20  5.10   5.20       5.20
# 4         1m 2024-01-03 10:04:00+07:00  5.20  5.20  5.20   5.20       5.20
# ..       ...                       ...   ...   ...   ...    ...        ...
# 628       1m 2024-01-05 16:25:00+07:00  5.25  5.25  5.20   5.25       5.25
# 629       1m 2024-01-05 16:26:00+07:00  5.25  5.25  5.20   5.20       5.20
# 630       1m 2024-01-05 16:27:00+07:00  5.25  5.25  5.20   5.20       5.20
# 631       1m 2024-01-05 16:28:00+07:00  5.20  5.25  5.20   5.25       5.25
# 632       1m 2024-01-05 16:29:00+07:00  5.25  5.25  5.25   5.25       5.25
#
#       Volume
# 0          0
# 1          0
# 2     509401
# 3    2215500
# 4       5500
# ..       ...
# 628     5900
# 629    14700
# 630     9400
# 631    33500
# 632   279100
#
# [633 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# ERW 2m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
ERW_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_2m_df = pd.concat([ERW_2m_df, data])

# Reset the index to get Date as a column
ERW_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_2m_df)

# # Save the DataFrame to a CSV file
# ERW_2m_df.to_csv('data_ERW_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High  Low  Close  Adj Close  \
# 0          2m 2023-11-20 10:00:00+07:00  5.45  5.45  5.4   5.40       5.40
# 1          2m 2023-11-20 10:02:00+07:00  5.40  5.40  5.4   5.40       5.40
# 2          2m 2023-11-20 10:04:00+07:00  5.40  5.45  5.4   5.45       5.45
# 3          2m 2023-11-20 10:06:00+07:00  5.45  5.45  5.4   5.40       5.40
# 4          2m 2023-11-20 10:08:00+07:00  5.45  5.45  5.4   5.40       5.40
# ...       ...                       ...   ...   ...  ...    ...        ...
# 3345       2m 2024-01-05 16:20:00+07:00  5.20  5.25  5.2   5.20       5.20
# 3346       2m 2024-01-05 16:22:00+07:00  5.25  5.25  5.2   5.20       5.20
# 3347       2m 2024-01-05 16:24:00+07:00  5.25  5.25  5.2   5.25       5.25
# 3348       2m 2024-01-05 16:26:00+07:00  5.25  5.25  5.2   5.20       5.20
# 3349       2m 2024-01-05 16:28:00+07:00  5.20  5.25  5.2   5.25       5.25
#
#       Volume
# 0          0
# 1          0
# 2      10200
# 3          0
# 4      10100
# ...      ...
# 3345   12000
# 3346   22100
# 3347   27100
# 3348   24100
# 3349  312600
#
# [3350 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# ERW 5m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
ERW_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_5m_df = pd.concat([ERW_5m_df, data])

# Reset the index to get Date as a column
ERW_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_5m_df)

# # Save the DataFrame to a CSV file
# ERW_5m_df.to_csv('data_ERW_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          5m 2023-11-09 10:00:00+07:00  5.20  5.20  5.20   5.20       5.20
# 1          5m 2023-11-09 10:05:00+07:00  5.15  5.15  5.15   5.15       5.15
# 2          5m 2023-11-09 10:10:00+07:00  5.15  5.20  5.15   5.15       5.15
# 3          5m 2023-11-09 10:15:00+07:00  5.15  5.20  5.15   5.15       5.15
# 4          5m 2023-11-09 10:20:00+07:00  5.20  5.20  5.20   5.20       5.20
# ...       ...                       ...   ...   ...   ...    ...        ...
# 1963       5m 2024-01-05 16:05:00+07:00  5.20  5.25  5.20   5.20       5.20
# 1964       5m 2024-01-05 16:10:00+07:00  5.20  5.25  5.20   5.20       5.20
# 1965       5m 2024-01-05 16:15:00+07:00  5.20  5.25  5.20   5.20       5.20
# 1966       5m 2024-01-05 16:20:00+07:00  5.20  5.25  5.20   5.25       5.25
# 1967       5m 2024-01-05 16:25:00+07:00  5.25  5.25  5.20   5.25       5.25
#
#       Volume
# 0          0
# 1       4600
# 2      13300
# 3      10500
# 4        600
# ...      ...
# 1963   88000
# 1964  885500
# 1965  140500
# 1966   55300
# 1967  342600
#
# [1968 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# ERW 15m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
ERW_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_15m_df = pd.concat([ERW_15m_df, data])

# Reset the index to get Date as a column
ERW_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_15m_df)

# # Save the DataFrame to a CSV file
# ERW_15m_df.to_csv('data_ERW_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close   Volume
# 0        15m 2023-11-09 10:00:00  5.20  5.20  5.15   5.15       5.15    17900
# 1        15m 2023-11-09 10:15:00  5.15  5.20  5.15   5.15       5.15   907200
# 2        15m 2023-11-09 10:30:00  5.10  5.15  5.10   5.10       5.10    80800
# 3        15m 2023-11-09 10:45:00  5.10  5.15  5.10   5.10       5.10   327800
# 4        15m 2023-11-09 11:00:00  5.10  5.10  5.05   5.05       5.05  1715700
# ..       ...                 ...   ...   ...   ...    ...        ...      ...
# 698      15m 2024-01-05 15:15:00  5.20  5.25  5.20   5.20       5.20   317900
# 699      15m 2024-01-05 15:30:00  5.25  5.25  5.20   5.20       5.20   362100
# 700      15m 2024-01-05 15:45:00  5.25  5.25  5.20   5.20       5.20   175800
# 701      15m 2024-01-05 16:00:00  5.25  5.25  5.20   5.20       5.20  1028400
# 702      15m 2024-01-05 16:15:00  5.20  5.25  5.20   5.25       5.25   538400
#
# [703 rows x 8 columns]

# %% [markdown]
# ## SPRC

# %% [markdown]
# ### 1m

# %%
# SPRC 1m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
SPRC_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_1m_df = pd.concat([SPRC_1m_df, data])

# Reset the index to get Date as a column
SPRC_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_1m_df)

# # Save the DataFrame to a CSV file
# SPRC_1m_df.to_csv('data_SPRC_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0         1m 2024-01-03 10:01:00+07:00  8.30   8.3  8.30   8.30       8.30
# 1         1m 2024-01-03 10:02:00+07:00  8.30   8.3  8.30   8.30       8.30
# 2         1m 2024-01-03 10:03:00+07:00  8.30   8.3  8.25   8.30       8.30
# 3         1m 2024-01-03 10:04:00+07:00  8.30   8.3  8.25   8.25       8.25
# 4         1m 2024-01-03 10:05:00+07:00  8.30   8.3  8.25   8.25       8.25
# ..       ...                       ...   ...   ...   ...    ...        ...
# 725       1m 2024-01-05 16:25:00+07:00  8.50   8.5  8.45   8.50       8.50
# 726       1m 2024-01-05 16:26:00+07:00  8.45   8.5  8.45   8.45       8.45
# 727       1m 2024-01-05 16:27:00+07:00  8.50   8.5  8.45   8.45       8.45
# 728       1m 2024-01-05 16:28:00+07:00  8.45   8.5  8.45   8.45       8.45
# 729       1m 2024-01-05 16:29:00+07:00  8.50   8.5  8.45   8.45       8.45
#
#      Volume
# 0         0
# 1         0
# 2     23800
# 3     17200
# 4      1500
# ..      ...
# 725    6800
# 726   10301
# 727    7200
# 728    5400
# 729    5400
#
# [730 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# SPRC 2m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
SPRC_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_2m_df = pd.concat([SPRC_2m_df, data])

# Reset the index to get Date as a column
SPRC_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_2m_df)

# # Save the DataFrame to a CSV file
# SPRC_2m_df.to_csv('data_SPRC_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          2m 2023-11-20 10:00:00+07:00  8.25  8.25  8.20   8.20       8.20
# 1          2m 2023-11-20 10:02:00+07:00  8.20  8.20  8.15   8.15       8.15
# 2          2m 2023-11-20 10:04:00+07:00  8.15  8.15  8.15   8.15       8.15
# 3          2m 2023-11-20 10:06:00+07:00  8.15  8.15  8.10   8.10       8.10
# 4          2m 2023-11-20 10:08:00+07:00  8.10  8.15  8.10   8.15       8.15
# ...       ...                       ...   ...   ...   ...    ...        ...
# 3525       2m 2024-01-05 16:20:00+07:00  8.50  8.50  8.45   8.50       8.50
# 3526       2m 2024-01-05 16:22:00+07:00  8.45  8.50  8.45   8.45       8.45
# 3527       2m 2024-01-05 16:24:00+07:00  8.50  8.50  8.45   8.50       8.50
# 3528       2m 2024-01-05 16:26:00+07:00  8.45  8.50  8.45   8.45       8.45
# 3529       2m 2024-01-05 16:28:00+07:00  8.45  8.50  8.45   8.45       8.45
#
#       Volume
# 0     285800
# 1     289300
# 2     290700
# 3      12900
# 4      18200
# ...      ...
# 3525   15800
# 3526   12700
# 3527   14700
# 3528   17501
# 3529   10800
#
# [3530 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# SPRC 5m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
SPRC_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_5m_df = pd.concat([SPRC_5m_df, data])

# Reset the index to get Date as a column
SPRC_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_5m_df)

# # Save the DataFrame to a CSV file
# SPRC_5m_df.to_csv('data_SPRC_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          5m 2023-11-09 10:00:00+07:00  7.65  7.65  7.55   7.55       7.55
# 1          5m 2023-11-09 10:05:00+07:00  7.60  7.60  7.55   7.60       7.60
# 2          5m 2023-11-09 10:10:00+07:00  7.65  7.65  7.55   7.60       7.60
# 3          5m 2023-11-09 10:15:00+07:00  7.60  7.65  7.60   7.65       7.65
# 4          5m 2023-11-09 10:20:00+07:00  7.60  7.65  7.60   7.65       7.65
# ...       ...                       ...   ...   ...   ...    ...        ...
# 1982       5m 2024-01-05 16:05:00+07:00  8.50  8.55  8.45   8.50       8.50
# 1983       5m 2024-01-05 16:10:00+07:00  8.50  8.50  8.45   8.45       8.45
# 1984       5m 2024-01-05 16:15:00+07:00  8.45  8.50  8.45   8.45       8.45
# 1985       5m 2024-01-05 16:20:00+07:00  8.50  8.50  8.45   8.50       8.50
# 1986       5m 2024-01-05 16:25:00+07:00  8.50  8.50  8.45   8.45       8.45
#
#        Volume
# 0           0
# 1      356300
# 2     1151300
# 3      233100
# 4       52400
# ...       ...
# 1982   307300
# 1983    51800
# 1984    53200
# 1985    36400
# 1986    35101
#
# [1987 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# SPRC 15m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SPRC_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_15m_df = pd.concat([SPRC_15m_df, data])

# Reset the index to get Date as a column
SPRC_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_15m_df)

# # Save the DataFrame to a CSV file
# SPRC_15m_df.to_csv('data_SPRC_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close   Volume
# 0        15m 2023-11-09 10:00:00  7.65  7.65  7.55   7.60       7.60  1507600
# 1        15m 2023-11-09 10:15:00  7.60  7.65  7.60   7.65       7.65   294800
# 2        15m 2023-11-09 10:30:00  7.60  7.65  7.50   7.50       7.50  2913206
# 3        15m 2023-11-09 10:45:00  7.55  7.55  7.50   7.50       7.50   787901
# 4        15m 2023-11-09 11:00:00  7.50  7.55  7.45   7.50       7.50   520103
# ..       ...                 ...   ...   ...   ...    ...        ...      ...
# 696      15m 2024-01-05 15:15:00  8.60  8.65  8.50   8.55       8.55  2891525
# 697      15m 2024-01-05 15:30:00  8.55  8.60  8.45   8.50       8.50  3804060
# 698      15m 2024-01-05 15:45:00  8.55  8.55  8.45   8.55       8.55  1084419
# 699      15m 2024-01-05 16:00:00  8.50  8.55  8.45   8.45       8.45   462100
# 700      15m 2024-01-05 16:15:00  8.45  8.50  8.45   8.45       8.45   124701
#
# [701 rows x 8 columns]

# %% [markdown]
# # Features Data

# %% [markdown]
# ## FX RATE USD-THB

# %%
# USD 15m
stock_symbol = 'THB=X'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
USD_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    USD_df = pd.concat([USD_df, data])

# Reset the index to get Date as a column
USD_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(USD_df)

# # Save the DataFrame to a CSV file
# USD_df.to_csv('data_USD.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-09 00:00:00  35.500000  35.528000  35.500000  35.519001
# 1         15m 2023-11-09 00:15:00  35.518002  35.521999  35.490002  35.521999
# 2         15m 2023-11-09 00:30:00  35.520000  35.532001  35.500000  35.527000
# 3         15m 2023-11-09 00:45:00  35.530998  35.530998  35.470001  35.509998
# 4         15m 2023-11-09 01:00:00  35.520000  35.533001  35.480000  35.520000
# ...       ...                 ...        ...        ...        ...        ...
# 3809      15m 2024-01-05 21:15:00  34.700001  34.700001  34.689999  34.689999
# 3810      15m 2024-01-05 21:30:00  34.700001  34.700001  34.680000  34.700001
# 3811      15m 2024-01-05 21:45:00  34.669998  34.680000  34.669998  34.680000
# 3812      15m 2024-01-05 22:00:00  34.680000  34.680000  34.680000  34.680000
# 3813      15m 2024-01-05 23:45:00  34.680000  34.680000  34.680000  34.680000
#
#       Adj Close  Volume
# 0     35.519001       0
# 1     35.521999       0
# 2     35.527000       0
# 3     35.509998       0
# 4     35.520000       0
# ...         ...     ...
# 3809  34.689999       0
# 3810  34.700001       0
# 3811  34.680000       0
# 3812  34.680000       0
# 3813  34.680000       0
#
# [3814 rows x 8 columns]

# %% [markdown]
# ## CNYX

# %%
# CNY 15m
stock_symbol = 'CNY=X'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
CNY_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    CNY_df = pd.concat([CNY_df, data])

# Reset the index to get Date as a column
CNY_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(CNY_df)

# # Save the DataFrame to a CSV file
# CNY_df.to_csv('data_CNY.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date    Open    High     Low   Close  Adj Close  \
# 0         15m 2023-11-09 01:30:00  7.2767  7.2775  7.2758  7.2774     7.2774
# 1         15m 2023-11-09 01:45:00  7.2772  7.2791  7.2772  7.2791     7.2791
# 2         15m 2023-11-09 02:00:00  7.2792  7.2806  7.2792  7.2805     7.2805
# 3         15m 2023-11-09 02:15:00  7.2804  7.2809  7.2804  7.2805     7.2805
# 4         15m 2023-11-09 02:30:00  7.2802  7.2807  7.2801  7.2807     7.2807
# ...       ...                 ...     ...     ...     ...     ...        ...
# 2433      15m 2024-01-05 17:45:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2434      15m 2024-01-05 19:15:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2435      15m 2024-01-05 19:45:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2436      15m 2024-01-05 20:30:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2437      15m 2024-01-05 22:00:00  7.1390  7.1390  7.1390  7.1390     7.1390
#
#       Volume
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2433       0
# 2434       0
# 2435       0
# 2436       0
# 2437       0
#
# [2438 rows x 8 columns]

# %% [markdown]
# ## SET100

# %%
# SET100 15m
stock_symbol = 'BSET100.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SET100_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SET100_df = pd.concat([SET100_df, data])

# Reset the index to get Date as a column
SET100_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SET100_df)

# # Save the DataFrame to a CSV file
# SET100_df.to_csv('data_SET100.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close  Volume
# 0        15m 2023-11-09 10:00:00  9.17  9.17  9.16   9.17       9.17    5300
# 1        15m 2023-11-09 10:15:00  9.11  9.11  9.11   9.11       9.11    1000
# 2        15m 2023-11-09 10:45:00  9.10  9.10  9.10   9.10       9.10     100
# 3        15m 2023-11-09 11:00:00  9.10  9.10  9.10   9.10       9.10    4200
# 4        15m 2023-11-09 12:00:00  9.10  9.10  9.10   9.10       9.10     100
# ..       ...                 ...   ...   ...   ...    ...        ...     ...
# 407      15m 2024-01-05 12:00:00  9.30  9.30  9.30   9.30       9.30     500
# 408      15m 2024-01-05 14:15:00  9.29  9.29  9.29   9.29       9.29     600
# 409      15m 2024-01-05 14:30:00  9.29  9.29  9.29   9.29       9.29    1000
# 410      15m 2024-01-05 15:45:00  9.27  9.27  9.27   9.27       9.27     700
# 411      15m 2024-01-05 16:00:00  9.27  9.27  9.25   9.25       9.25    6401
#
# [412 rows x 8 columns]

# %% [markdown]
# ## SET50

# %%
# SET50 15m
stock_symbol = 'TDEX.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SET50_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SET50_df = pd.concat([SET50_df, data])

# Reset the index to get Date as a column
SET50_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SET50_df)

# # Save the DataFrame to a CSV file
# SET50_df.to_csv('data_SET50.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close  Volume
# 0        15m 2023-11-09 10:00:00  8.56  8.57  8.52   8.53       8.53   38392
# 1        15m 2023-11-09 10:15:00  8.54  8.54  8.52   8.53       8.53    3500
# 2        15m 2023-11-09 10:30:00  8.52  8.53  8.50   8.50       8.50  114723
# 3        15m 2023-11-09 10:45:00  8.49  8.50  8.49   8.50       8.50   32403
# 4        15m 2023-11-09 11:00:00  8.50  8.50  8.48   8.49       8.49   37655
# ..       ...                 ...   ...   ...   ...    ...        ...     ...
# 698      15m 2024-01-05 15:15:00  8.63  8.63  8.62   8.62       8.62    4100
# 699      15m 2024-01-05 15:30:00  8.62  8.63  8.61   8.62       8.62   14437
# 700      15m 2024-01-05 15:45:00  8.62  8.63  8.61   8.62       8.62    2950
# 701      15m 2024-01-05 16:00:00  8.62  8.62  8.61   8.61       8.61   31366
# 702      15m 2024-01-05 16:15:00  8.61  8.61  8.61   8.61       8.61   10518
#
# [703 rows x 8 columns]

# %% [markdown]
# ## Gold

# %%
# Gold 15m
stock_symbol = 'GC=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
GOLD_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    GOLD_df = pd.concat([GOLD_df, data])

# Reset the index to get Date as a column
GOLD_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(GOLD_df)

# # Save the DataFrame to a CSV file
# GOLD_df.to_csv('data_GOLD.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date         Open         High          Low  \
# 0         15m 2023-11-09 00:00:00  1954.400024  1954.699951  1953.599976
# 1         15m 2023-11-09 00:15:00  1954.199951  1954.300049  1953.400024
# 2         15m 2023-11-09 00:30:00  1953.400024  1954.300049  1952.800049
# 3         15m 2023-11-09 00:45:00  1954.300049  1955.199951  1953.599976
# 4         15m 2023-11-09 01:00:00  1955.000000  1955.199951  1954.500000
# ...       ...                 ...          ...          ...          ...
# 3587      15m 2024-01-05 15:45:00  2050.800049  2051.899902  2050.600098
# 3588      15m 2024-01-05 16:00:00  2050.800049  2051.800049  2050.800049
# 3589      15m 2024-01-05 16:15:00  2051.399902  2052.000000  2051.199951
# 3590      15m 2024-01-05 16:30:00  2051.899902  2052.000000  2050.899902
# 3591      15m 2024-01-05 16:45:00  2051.899902  2053.199951  2051.699951
#
#             Close    Adj Close  Volume
# 0     1954.199951  1954.199951     217
# 1     1953.400024  1953.400024     340
# 2     1954.300049  1954.300049     667
# 3     1955.099976  1955.099976     651
# 4     1954.900024  1954.900024     546
# ...           ...          ...     ...
# 3587  2050.800049  2050.800049     952
# 3588  2051.600098  2051.600098     572
# 3589  2051.800049  2051.800049     250
# 3590  2051.899902  2051.899902     376
# 3591  2052.600098  2052.600098     613
#
# [3592 rows x 8 columns]

# %% [markdown]
# ## Financial Index

# %%
# Fincial Index 15m
stock_symbol = '^FINCIAL.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
FINCIAL_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    FINCIAL_df = pd.concat([FINCIAL_df, data])

# Reset the index to get Date as a column
FINCIAL_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(FINCIAL_df)

# # Save the DataFrame to a CSV file
# FINCIAL_df.to_csv('data_FINCIAL.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-09 10:00:00  140.979996  140.979996  140.139999
# 1        15m 2023-11-09 10:15:00  140.240005  140.490005  140.020004
# 2        15m 2023-11-09 10:30:00  139.899994  140.169998  139.720001
# 3        15m 2023-11-09 10:45:00  139.820007  139.979996  139.630005
# 4        15m 2023-11-09 11:00:00  139.979996  140.009995  139.600006
# ..       ...                 ...         ...         ...         ...
# 733      15m 2024-01-05 15:15:00  142.139999  142.429993  141.990005
# 734      15m 2024-01-05 15:30:00  142.240005  142.309998  141.960007
# 735      15m 2024-01-05 15:45:00  142.050003  142.289993  141.979996
# 736      15m 2024-01-05 16:00:00  142.220001  142.250000  141.860001
# 737      15m 2024-01-05 16:15:00  141.949997  142.169998  141.850006
#
#           Close   Adj Close  Volume
# 0    140.220001  140.220001       0
# 1    140.020004  140.020004       0
# 2    139.869995  139.869995       0
# 3    139.899994  139.899994       0
# 4    139.759995  139.759995       0
# ..          ...         ...     ...
# 733  142.199997  142.199997       0
# 734  142.000000  142.000000       0
# 735  142.139999  142.139999       0
# 736  142.050003  142.050003       0
# 737  142.029999  142.029999       0
#
# [738 rows x 8 columns]

# %% [markdown]
# ## Banking Sector

# %%
# Banking Index 15m
stock_symbol = '^BANK.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
BANKING_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    BANKING_df = pd.concat([BANKING_df, data])

# Reset the index to get Date as a column
BANKING_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(BANKING_df)

# # Save the DataFrame to a CSV file
# BANKING_df.to_csv('data_BANKING.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-09 10:00:00  378.700012  378.700012  376.329987
# 1        15m 2023-11-09 10:15:00  377.010010  377.880005  377.010010
# 2        15m 2023-11-09 10:30:00  376.559998  377.559998  376.559998
# 3        15m 2023-11-09 10:45:00  377.109985  377.820007  376.309998
# 4        15m 2023-11-09 11:00:00  377.529999  377.619995  376.850006
# ..       ...                 ...         ...         ...         ...
# 731      15m 2024-01-05 15:15:00  385.309998  386.239990  384.619995
# 732      15m 2024-01-05 15:30:00  385.609985  385.859985  384.700012
# 733      15m 2024-01-05 15:45:00  385.149994  385.649994  384.670013
# 734      15m 2024-01-05 16:00:00  385.549988  385.549988  384.510010
# 735      15m 2024-01-05 16:15:00  384.880005  385.809998  384.459991
#
#           Close   Adj Close  Volume
# 0    377.010010  377.010010       0
# 1    377.049988  377.049988       0
# 2    377.559998  377.559998       0
# 3    377.779999  377.779999       0
# 4    377.209991  377.209991       0
# ..          ...         ...     ...
# 731  385.609985  385.609985       0
# 732  385.250000  385.250000       0
# 733  385.299988  385.299988       0
# 734  385.130005  385.130005       0
# 735  385.760010  385.760010       0
#
# [736 rows x 8 columns]

# %% [markdown]
# ## Service Index

# %%
# Service Index 15m
stock_symbol = '^SERVICE.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SERVICE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SERVICE_df = pd.concat([SERVICE_df, data])

# Reset the index to get Date as a column
SERVICE_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SERVICE_df)

# # Save the DataFrame to a CSV file
# SERVICE_df.to_csv('data_SERVICE.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-09 10:00:00  433.929993  433.929993  430.820007
# 1        15m 2023-11-09 10:15:00  431.429993  431.910004  430.820007
# 2        15m 2023-11-09 10:30:00  430.760010  431.450012  428.239990
# 3        15m 2023-11-09 10:45:00  428.220001  428.950012  427.750000
# 4        15m 2023-11-09 11:00:00  428.399994  428.700012  426.329987
# ..       ...                 ...         ...         ...         ...
# 733      15m 2024-01-05 15:15:00  432.369995  433.010010  431.549988
# 734      15m 2024-01-05 15:30:00  432.750000  433.079987  431.630005
# 735      15m 2024-01-05 15:45:00  432.070007  432.809998  431.670013
# 736      15m 2024-01-05 16:00:00  432.149994  432.540009  430.869995
# 737      15m 2024-01-05 16:15:00  431.239990  432.910004  430.980011
#
#           Close   Adj Close  Volume
# 0    431.609985  431.609985       0
# 1    431.119995  431.119995       0
# 2    428.239990  428.239990       0
# 3    428.000000  428.000000       0
# 4    427.579987  427.579987       0
# ..          ...         ...     ...
# 733  431.679993  431.679993       0
# 734  432.049988  432.049988       0
# 735  431.929993  431.929993       0
# 736  431.190002  431.190002       0
# 737  432.489990  432.489990       0
#
# [738 rows x 8 columns]

# %% [markdown]
# ## Tourism Sector

# %%
# Tourism Index 15m
stock_symbol = '^TOURISM.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
TOURISM_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TOURISM_df = pd.concat([TOURISM_df, data])

# Reset the index to get Date as a column
TOURISM_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TOURISM_df)

# # Save the DataFrame to a CSV file
# TOURISM_df.to_csv('data_TOURISM.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-09 10:00:00  561.770020  561.770020  557.599976
# 1        15m 2023-11-09 10:15:00  560.330017  561.010010  557.659973
# 2        15m 2023-11-09 10:30:00  557.590027  557.590027  550.989990
# 3        15m 2023-11-09 10:45:00  550.989990  554.979980  550.989990
# 4        15m 2023-11-09 11:00:00  553.900024  554.549988  549.940002
# ..       ...                 ...         ...         ...         ...
# 727      15m 2024-01-05 15:15:00  568.169983  571.200012  567.599976
# 728      15m 2024-01-05 15:30:00  571.059998  571.409973  567.669983
# 729      15m 2024-01-05 15:45:00  568.580017  571.250000  567.760010
# 730      15m 2024-01-05 16:00:00  568.250000  571.190002  567.630005
# 731      15m 2024-01-05 16:15:00  568.409973  572.359985  567.630005
#
#           Close   Adj Close  Volume
# 0    560.330017  560.330017       0
# 1    560.250000  560.250000       0
# 2    550.989990  550.989990       0
# 3    553.900024  553.900024       0
# 4    552.429993  552.429993       0
# ..          ...         ...     ...
# 727  568.400024  568.400024       0
# 728  568.150024  568.150024       0
# 729  567.809998  567.809998       0
# 730  568.409973  568.409973       0
# 731  572.359985  572.359985       0
#
# [732 rows x 8 columns]

# %% [markdown]
# ## Resource Index

# %%
# Resource Index 15m
stock_symbol = '^RESOURC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
RESOURCE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    RESOURCE_df = pd.concat([TOURISM_df, data])

# Reset the index to get Date as a column
TOURISM_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(RESOURCE_df)

# # Save the DataFrame to a CSV file
# RESOURCE_df.to_csv('data_RESOURC.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                             index Interval                Date        Open  \
# 0                             0.0      15m 2023-11-09 10:00:00  561.770020
# 1                             1.0      15m 2023-11-09 10:15:00  560.330017
# 2                             2.0      15m 2023-11-09 10:30:00  557.590027
# 3                             3.0      15m 2023-11-09 10:45:00  550.989990
# 4                             4.0      15m 2023-11-09 11:00:00  553.900024
# ...                           ...      ...                 ...         ...
# (15m, 2024-01-05 15:15:00)    NaN      NaN                 NaT  181.850006
# (15m, 2024-01-05 15:30:00)    NaN      NaN                 NaT  181.639999
# (15m, 2024-01-05 15:45:00)    NaN      NaN                 NaT  182.100006
# (15m, 2024-01-05 16:00:00)    NaN      NaN                 NaT  181.899994
# (15m, 2024-01-05 16:15:00)    NaN      NaN                 NaT  181.580002
#
#                                   High         Low       Close   Adj Close  \
# 0                           561.770020  557.599976  560.330017  560.330017
# 1                           561.010010  557.659973  560.250000  560.250000
# 2                           557.590027  550.989990  550.989990  550.989990
# 3                           554.979980  550.989990  553.900024  553.900024
# 4                           554.549988  549.940002  552.429993  552.429993
# ...                                ...         ...         ...         ...
# (15m, 2024-01-05 15:15:00)  182.440002  181.600006  181.639999  181.639999
# (15m, 2024-01-05 15:30:00)  182.119995  181.509995  182.039993  182.039993
# (15m, 2024-01-05 15:45:00)  182.190002  181.490005  181.940002  181.940002
# (15m, 2024-01-05 16:00:00)  182.169998  181.449997  181.639999  181.639999
# (15m, 2024-01-05 16:15:00)  182.240005  181.550003  181.940002  181.940002
#
#                             Volume
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# (15m, 2024-01-05 15:15:00)       0
# (15m, 2024-01-05 15:30:00)       0
# (15m, 2024-01-05 15:45:00)       0
# (15m, 2024-01-05 16:00:00)       0
# (15m, 2024-01-05 16:15:00)       0
#
# [1470 rows x 9 columns]

# %% [markdown]
# ## Energy Sector

# %%
# Energy Index 15m
stock_symbol = '^ENERG.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
ENERGY_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ENERGY_df = pd.concat([ENERGY_df, data])

# Reset the index to get Date as a column
ENERGY_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ENERGY_df)

# # Save the DataFrame to a CSV file
# ENERGY_df.to_csv('data_ENERG.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date          Open          High           Low  \
# 0        15m 2023-11-09 10:00:00  20204.550781  20205.630859  20114.990234
# 1        15m 2023-11-09 10:15:00  20126.349609  20219.119141  20126.349609
# 2        15m 2023-11-09 10:30:00  20172.330078  20200.070312  20095.919922
# 3        15m 2023-11-09 10:45:00  20087.359375  20188.400391  20082.240234
# 4        15m 2023-11-09 11:00:00  20177.460938  20177.460938  20085.050781
# ..       ...                 ...           ...           ...           ...
# 733      15m 2024-01-05 15:15:00  20742.310547  20809.000000  20713.140625
# 734      15m 2024-01-05 15:30:00  20717.380859  20772.990234  20702.630859
# 735      15m 2024-01-05 15:45:00  20770.769531  20780.820312  20701.060547
# 736      15m 2024-01-05 16:00:00  20747.529297  20778.330078  20696.039062
# 737      15m 2024-01-05 16:15:00  20710.830078  20786.550781  20707.839844
#
#             Close     Adj Close  Volume
# 0    20148.890625  20148.890625       0
# 1    20157.439453  20157.439453       0
# 2    20095.919922  20095.919922       0
# 3    20123.830078  20123.830078       0
# 4    20150.009766  20150.009766       0
# ..            ...           ...     ...
# 733  20718.339844  20718.339844       0
# 734  20763.289062  20763.289062       0
# 735  20752.400391  20752.400391       0
# 736  20718.000000  20718.000000       0
# 737  20752.099609  20752.099609       0
#
# [738 rows x 8 columns]

# %% [markdown]
# ## BRENT

# %%
# BRENT 15m
stock_symbol = 'BZ=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
BRENT_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    BRENT_df = pd.concat([BRENT_df, data])

# Reset the index to get Date as a column
BRENT_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(BRENT_df)

# # Save the DataFrame to a CSV file
# BRENT_df.to_csv('data_BRENT.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-09 00:00:00  79.610001  79.660004  79.610001  79.660004
# 1         15m 2023-11-09 00:15:00  79.669998  79.669998  79.669998  79.669998
# 2         15m 2023-11-09 00:30:00  79.580002  79.580002  79.440002  79.580002
# 3         15m 2023-11-09 00:45:00  79.650002  79.709999  79.570000  79.709999
# 4         15m 2023-11-09 01:00:00  79.699997  79.830002  79.669998  79.769997
# ...       ...                 ...        ...        ...        ...        ...
# 3116      15m 2024-01-05 15:45:00  78.760002  78.849998  78.750000  78.839996
# 3117      15m 2024-01-05 16:00:00  78.839996  78.900002  78.800003  78.809998
# 3118      15m 2024-01-05 16:15:00  78.809998  78.839996  78.809998  78.839996
# 3119      15m 2024-01-05 16:30:00  78.820000  78.820000  78.769997  78.769997
# 3120      15m 2024-01-05 16:45:00  78.779999  78.900002  78.779999  78.900002
#
#       Adj Close  Volume
# 0     79.660004       0
# 1     79.669998       2
# 2     79.580002      66
# 3     79.709999     100
# 4     79.769997      60
# ...         ...     ...
# 3116  78.839996     216
# 3117  78.809998      78
# 3118  78.839996      12
# 3119  78.769997      27
# 3120  78.900002      88
#
# [3121 rows x 8 columns]

# %% [markdown]
# ## Crude (WTI)

# %%
# Crude 15m
stock_symbol = 'CL=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
CRUDE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    CRUDE_df = pd.concat([CRUDE_df, data])

# Reset the index to get Date as a column
CRUDE_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(CRUDE_df)

# # Save the DataFrame to a CSV file
# CRUDE_df.to_csv('data_CRUDE.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-09 00:00:00  75.379997  75.459999  75.379997  75.459999
# 1         15m 2023-11-09 00:15:00  75.449997  75.470001  75.400002  75.419998
# 2         15m 2023-11-09 00:30:00  75.410004  75.459999  75.209999  75.459999
# 3         15m 2023-11-09 00:45:00  75.449997  75.510002  75.349998  75.489998
# 4         15m 2023-11-09 01:00:00  75.480003  75.610001  75.459999  75.529999
# ...       ...                 ...        ...        ...        ...        ...
# 3440      15m 2024-01-05 15:45:00  73.849998  73.930000  73.830002  73.919998
# 3441      15m 2024-01-05 16:00:00  73.919998  73.989998  73.879997  73.889999
# 3442      15m 2024-01-05 16:15:00  73.889999  73.930000  73.889999  73.919998
# 3443      15m 2024-01-05 16:30:00  73.919998  73.930000  73.860001  73.870003
# 3444      15m 2024-01-05 16:45:00  73.860001  73.970001  73.860001  73.949997
#
#       Adj Close  Volume
# 0     75.459999     123
# 1     75.419998     224
# 2     75.459999    1974
# 3     75.489998    1267
# 4     75.529999     832
# ...         ...     ...
# 3440  73.919998    1406
# 3441  73.889999    1473
# 3442  73.919998     396
# 3443  73.870003     348
# 3444  73.949997     465
#
# [3445 rows x 8 columns]

# %% [markdown]
# # Read Files

# %%
# Main Stock
## TISCO
TISCO_15m = pd.read_csv('training_datasource/data_TISCO_15m.csv')
TISCO_5m = pd.read_csv('training_datasource/data_TISCO_5m.csv')
TISCO_2m = pd.read_csv('training_datasource/data_TISCO_2m.csv')
TISCO_1m = pd.read_csv('training_datasource/data_TISCO_1m.csv')

## ERW
ERW_15m = pd.read_csv('training_datasource/data_ERW_15m.csv')
ERW_5m = pd.read_csv('training_datasource/data_ERW_5m.csv')
ERW_2m = pd.read_csv('training_datasource/data_ERW_2m.csv')
ERW_1m = pd.read_csv('training_datasource/data_ERW_1m.csv')

## SPRC
SPRC_15m = pd.read_csv('training_datasource/data_SPRC_15m.csv')
SPRC_5m = pd.read_csv('training_datasource/data_SPRC_5m.csv')
SPRC_2m = pd.read_csv('training_datasource/data_SPRC_2m.csv')
SPRC_1m = pd.read_csv('training_datasource/data_SPRC_1m.csv')

# Features
BANKING = pd.read_csv('training_datasource/data_BANKING.csv')
BRENT = pd.read_csv('training_datasource/data_BRENT.csv')
CNY = pd.read_csv('training_datasource/data_CNY.csv')
CRUDE = pd.read_csv('training_datasource/data_CRUDE.csv')
ENERGY = pd.read_csv('training_datasource/data_ENERG.csv')
FINCIAL = pd.read_csv('training_datasource/data_FINCIAL.csv')
GOLD = pd.read_csv('training_datasource/data_GOLD.csv')
RESOURCE = pd.read_csv('training_datasource/data_RESOURC.csv')
SERVICE = pd.read_csv('training_datasource/data_SERVICE.csv')
SET50 = pd.read_csv('training_datasource/data_SET50.csv')
SET100 = pd.read_csv('training_datasource/data_SET100.csv')
TOURISM = pd.read_csv('training_datasource/data_TOURISM.csv')
USD = pd.read_csv('training_datasource/data_USD.csv')

# %% [markdown]
# # Define Variables

# %%
## Add Diff Columns
#### Adjust data
TISCO_15m['Diff'] = TISCO_15m['Open'] - TISCO_15m['Close']
ERW_15m['Diff'] = ERW_15m['Open'] - ERW_15m['Close']
SPRC_15m['Diff'] = SPRC_15m['Open'] - SPRC_15m['Close']

# %%
# Set Variables
# Set Y
tisco15_diff = TISCO_15m['Diff']
erw15_diff = ERW_15m['Diff']
sprc15_diff = SPRC_15m['Diff']

# Reference date
ref_date = TISCO_15m['Date']

# Features (X)
tisco15_close = TISCO_15m['Close']
erw15_close = ERW_15m['Close']
sprc15_close = SPRC_15m['Close']
tisco15_vol = TISCO_15m['Volume']
erw15_vol = ERW_15m['Volume']
sprc15_vol = SPRC_15m['Volume']
usd = USD['Close']
cny = CNY['Close']
set100 = SET100['Close']
set50 = SET50['Close']
gold = GOLD['Close']
fin = FINCIAL['Close']
bank = BANKING['Close']
service = SERVICE['Close']
tour = TOURISM['Close']
resource = RESOURCE['Close']
energy = ENERGY['Close']
brent = BRENT['Close']
crude = CRUDE['Close']

# %% [markdown]
# # Data Exploration

# %%
# Assuming all your data frames have the same index (timestamps)
keys = ['ref_date', 'tisco15_close', 'erw15_close', 'sprc15_close',
        'tisco15_vol', 'erw15_vol', 'sprc15_vol',
        'usd', 'cny', 'set100', 'set50',
        'gold', 'fin', 'bank', 'service', 'tour',
        'resource', 'energy', 'brent', 'crude']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data = pd.concat([ref_date, tisco15_close, erw15_close, sprc15_close,
                        tisco15_vol, erw15_vol, sprc15_vol,
                        usd, cny, set100, set50,
                        gold, fin, bank, service, tour,
                        resource, energy, brent, crude], axis=1, keys=keys).reindex(reference_index)

# %%
#Check Null values
nan_count = merged_data.isna().sum()
print("NaN (n) = 722:")
print(nan_count, '\n')
# Out:
# NaN (n) = 722:
# ref_date           0
# tisco15_close      0
# erw15_close        0
# sprc15_close       2
# tisco15_vol        0
# erw15_vol          0
# sprc15_vol         2
# usd                0
# cny                0
# set100           291
# set50              0
# gold               0
# fin                0
# bank               0
# service            0
# tour               0
# resource           0
# energy             0
# brent              0
# crude              0
# dtype: int64

# %% [markdown]
# ## Check Normality & Outliers

# %%
column_names_list = list(merged_data.columns)
print(column_names_list)
# Out:
# ['ref_date', 'tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy', 'brent', 'crude']

# %%
## Check Skewness
columns = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

fig, axs = plt.subplots(9, 2, figsize=(12, 18))

# Flatten the 2D array of axes to simplify indexing
axs = axs.flatten()

for i, column in enumerate(columns):
    axs[i].hist(merged_data[column], bins=20, color='skyblue', edgecolor='black')
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('Frequency')
    axs[i].set_title(f'Histogram of {column}')
    
    mean_val = merged_data[column].mean()
    median_val = merged_data[column].median()
    
    axs[i].axvline(mean_val, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_val:.2f}')
    axs[i].axvline(median_val, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_val:.2f}')
    axs[i].legend()

# Hide any unused subplots
for i in range(len(columns), len(axs)):
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Check Outliers
fig, axs = plt.subplots(5, 4, figsize=(15, 15))

columns_to_test = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

color = 'pink'

for i, column in enumerate(columns_to_test):
    plt.subplot(5, 4, i + 1)
    sns.boxplot(x=merged_data[column], color=color)
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cleansing Data

# %%
columns_to_fillna = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_data[column].median()
    merged_data[column].fillna(median_value, inplace=True)

# %%
columns_to_test = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

for column_name in columns_to_test:
    df_tmp = merged_data[[column_name]].dropna()
    
    print(f'{column_name} : ', end='')
    
    # Perform Anderson-Darling test for normality
    statistic, critical_values, significance_levels = stats.anderson(df_tmp[column_name], dist='norm')
    print(f'Statistic: {statistic:.3f}, Critical Values: {critical_values}, Significance Levels: {significance_levels}')
    
    # Check normality based on the 5% significance level
    if statistic >= critical_values[2]:
        print('Not normal')
    else:
        print('Normal')
    
    print('==========================================')
# Out:
# tisco15_close : Statistic: 15.344, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# erw15_close : Statistic: 9.102, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# sprc15_close : Statistic: 7.076, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# tisco15_vol : Statistic: 63.345, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# erw15_vol : Statistic: 66.004, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# sprc15_vol : Statistic: 52.626, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# usd : Statistic: 15.142, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# cny : Statistic: 36.928, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# set100 : Statistic: 26.966, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# set50 : Statistic: 7.068, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# gold : Statistic: 7.808, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# fin : Statistic: 4.045, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# bank : Statistic: 10.607, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# service : Statistic: 12.227, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# tour : Statistic: 15.294, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# resource : Statistic: 15.294, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# energy : Statistic: 4.076, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## TISCO

# %%
import pandas as pd

# Assuming all your data frames have the same index (timestamps)
## Model with Other Features
keys = ['ref_date','tisco15_close', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'brent', 'crude']
## Model with Technical Index
# keys1 = ['tisco15_vol', 'tisco_ma', 'tisco_macd', 'tisco_rsi']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data_tisco = pd.concat([ref_date,tisco15_close, usd, cny, set100, set50, gold, fin, bank, brent, crude], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['tisco15_close', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'brent', 'crude']

for column in columns_to_fillna:
    median_value = merged_data_tisco[column].median()
    merged_data_tisco[column].fillna(median_value, inplace=True)

# %%
correlations = merged_data_tisco.corr()['tisco15_close']

print("Correlation with tisco15_close:")
print(correlations)

print("\nInterpretation:")
for variable, correlation in correlations.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 correlations = merged_data_tisco.corr()['tisco15_close']
#       3 print("Correlation with tisco15_close:")
#       4 print(correlations)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: '2023-11-09 10:00:00'

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(merged_data_tisco.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Heat Map of merged_data_TISCO')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[175], line 2
#       1 plt.figure(figsize=(10, 8))
# ----> 2 sns.heatmap(merged_data_tisco.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
#       3 plt.title('Heat Map of merged_data_TISCO')
#       5 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: '2023-11-09 10:00:00'

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['tisco15_close', 'usd', 'cny', 'set50', 'gold', 'bank']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_tisco[columns_to_normalize] = scaler.fit_transform(merged_data_tisco[columns_to_normalize])

# %%
# Assuming merged_data_SRPC is a DataFrame
filtered_data_tisco = merged_data_tisco[['ref_date', 'tisco15_close', 'usd', 'cny', 'set50', 'gold', 'bank']]
filtered_data_tisco
# Out:
#                 ref_date  tisco15_close       usd       cny     set50  \
# 0    2023-11-09 10:00:00       0.117647  0.468030  0.884728  0.619047
# 1    2023-11-09 10:15:00       0.176471  0.470587  0.894674  0.619047
# 2    2023-11-09 10:30:00       0.117647  0.474850  0.902866  0.547619
# 3    2023-11-09 10:45:00       0.117647  0.460355  0.902866  0.547619
# 4    2023-11-09 11:00:00       0.176471  0.468882  0.904038  0.523809
# ..                   ...            ...       ...       ...       ...
# 698  2024-01-05 15:15:00       1.000000  0.154305  0.158570  0.833334
# 699  2024-01-05 15:30:00       1.000000  0.165388  0.159742  0.833334
# 700  2024-01-05 15:45:00       1.000000  0.172208  0.159742  0.833334
# 701  2024-01-05 16:00:00       1.000000  0.167092  0.159742  0.809524
# 702  2024-01-05 16:15:00       1.000000  0.165388  0.153305  0.809524
#
#          gold      bank
# 0    0.297114  0.634626
# 1    0.283533  0.636874
# 2    0.298813  0.665542
# 3    0.312394  0.677908
# 4    0.308999  0.645868
# ..        ...       ...
# 698  0.738540  0.812815
# 699  0.733447  0.851039
# 700  0.709678  0.812815
# 701  0.736842  0.826868
# 702  0.753820  0.807194
#
# [703 rows x 7 columns]

# %% [markdown]
# ## ERW

# %%
import pandas as pd

# Assuming all your data frames have the same index (timestamps)
keys = ['ref_date','erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']
## Model with Technical Index
# keys1 = ['erw15_vol', 'erw15_ma', 'erw15_macd', 'erw15_rsi']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data_erw = pd.concat([ref_date,erw15_close, erw15_vol, usd, cny, set100, set50, gold, service, tour], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

for column in columns_to_fillna:
    median_value = merged_data_erw[column].median()
    merged_data_erw[column].fillna(median_value, inplace=True)

# %%
correlations = merged_data_erw.corr()['erw15_close']

print("Correlation with erw15_close:")
print(correlations)

print("\nInterpretation:")
for variable, correlation in correlations.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'erw15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'erw15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'erw15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'erw15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation with erw15_close:
# ref_date      -0.236492
# erw15_close    1.000000
# erw15_vol      0.174720
# usd            0.410676
# cny            0.379097
# set100        -0.198226
# set50          0.499039
# gold          -0.496642
# service        0.541460
# tour           0.367890
# Name: erw15_close, dtype: float64
#
# Interpretation:
# The correlation between 'erw15_close' and 'ref_date' is weak (-0.24)
# The correlation between 'erw15_close' and 'erw15_close' is strong (1.00)
# The correlation between 'erw15_close' and 'erw15_vol' is weak (0.17)
# The correlation between 'erw15_close' and 'usd' is moderate (0.41)
# The correlation between 'erw15_close' and 'cny' is moderate (0.38)
# The correlation between 'erw15_close' and 'set100' is weak (-0.20)
# The correlation between 'erw15_close' and 'set50' is moderate (0.50)
# The correlation between 'erw15_close' and 'gold' is moderate (-0.50)
# The correlation between 'erw15_close' and 'service' is moderate (0.54)
# The correlation between 'erw15_close' and 'tour' is moderate (0.37)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(merged_data_erw.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Heat Map of merged_data_ERW')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['erw15_close', 'cny', 'set50', 'service', 'tour']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_erw[columns_to_normalize] = scaler.fit_transform(merged_data_erw[columns_to_normalize])

# %%
# Assuming merged_data_SRPC is a DataFrame
filtered_data_erw = merged_data_erw[['ref_date', 'erw15_close', 'cny', 'set50', 'service', 'tour']]
filtered_data_erw
# Out:
#                ref_date  erw15_close       cny     set50   service      tour
# 0   2023-11-09 10:00:00     0.272727  0.884728  0.619047  0.848098  0.712184
# 1   2023-11-09 10:15:00     0.272727  0.894674  0.619047  0.834491  0.710748
# 2   2023-11-09 10:30:00     0.181818  0.902866  0.547619  0.754513  0.544590
# 3   2023-11-09 10:45:00     0.181818  0.902866  0.547619  0.747848  0.596806
# 4   2023-11-09 11:00:00     0.090909  0.904038  0.523809  0.736184  0.570429
# ..                  ...          ...       ...       ...       ...       ...
# 698 2024-01-05 15:15:00     0.363636  0.158570  0.833334  0.802277  0.832227
# 699 2024-01-05 15:30:00     0.363636  0.159742  0.833334  0.791447  0.831151
# 700 2024-01-05 15:45:00     0.363636  0.159742  0.833334  0.751736  0.853401
# 701 2024-01-05 16:00:00     0.363636  0.159742  0.809524  0.769509  0.846043
# 702 2024-01-05 16:15:00     0.454545  0.153305  0.809524  0.783116  0.843532
#
# [703 rows x 6 columns]

# %% [markdown]
# ## SRPC

# %%
import pandas as pd

# Assuming all your data frames have the same index (timestamps)
keys = ['ref_date','sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']
## Model with Technical Index
# keys1 = ['sprc15_vol', 'sprc15_ma', 'sprc15_macd', 'sprc15_rsi']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data_SRPC = pd.concat([ref_date, sprc15_close, sprc15_vol, usd ,cny, set100, set50, gold, resource, energy], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_data_SRPC[column].median()
    merged_data_SRPC[column].fillna(median_value, inplace=True)

# %%
correlations = merged_data_SRPC.corr()['sprc15_close']

print("Correlation with sprc15_close:")
print(correlations)

print("\nInterpretation:")
for variable, correlation in correlations.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'sprc15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'sprc15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'sprc15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'sprc15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation with sprc15_close:
# ref_date        0.587271
# sprc15_close    1.000000
# sprc15_vol     -0.033584
# usd            -0.267648
# cny            -0.539148
# set100         -0.193782
# set50           0.652522
# gold            0.323666
# resource        0.345416
# energy          0.546494
# Name: sprc15_close, dtype: float64
#
# Interpretation:
# The correlation between 'sprc15_close' and 'ref_date' is moderate (0.59)
# The correlation between 'sprc15_close' and 'sprc15_close' is strong (1.00)
# There is no significant correlation between 'sprc15_close' and 'sprc15_vol' (-0.03)
# The correlation between 'sprc15_close' and 'usd' is weak (-0.27)
# The correlation between 'sprc15_close' and 'cny' is moderate (-0.54)
# The correlation between 'sprc15_close' and 'set100' is weak (-0.19)
# The correlation between 'sprc15_close' and 'set50' is moderate (0.65)
# The correlation between 'sprc15_close' and 'gold' is moderate (0.32)
# The correlation between 'sprc15_close' and 'resource' is moderate (0.35)
# The correlation between 'sprc15_close' and 'energy' is moderate (0.55)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(merged_data_SRPC.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Heat Map of merged_data_SRPC')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['sprc15_close', 'cny', 'set50', 'energy']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_SRPC[columns_to_normalize] = scaler.fit_transform(merged_data_SRPC[columns_to_normalize])

# %%
# Assuming merged_data_SRPC is a DataFrame
filtered_data_SPRC = merged_data_SRPC[['ref_date', 'sprc15_close', 'cny', 'set50', 'energy']]
filtered_data_SPRC
# Out:
#                ref_date  sprc15_close       cny     set50    energy
# 0   2023-11-09 10:00:00      0.153846  0.884728  0.619047  0.084885
# 1   2023-11-09 10:15:00      0.192308  0.894674  0.619047  0.092421
# 2   2023-11-09 10:30:00      0.076923  0.902866  0.547619  0.038189
# 3   2023-11-09 10:45:00      0.076923  0.902866  0.547619  0.062793
# 4   2023-11-09 11:00:00      0.076923  0.904038  0.523809  0.085872
# ..                  ...           ...       ...       ...       ...
# 698 2024-01-05 15:15:00      0.884616  0.158570  0.833334  0.608170
# 699 2024-01-05 15:30:00      0.807692  0.159742  0.833334  0.542450
# 700 2024-01-05 15:45:00      0.807692  0.159742  0.833334  0.507691
# 701 2024-01-05 16:00:00      0.576923  0.159742  0.809524  0.577395
# 702 2024-01-05 16:15:00      0.576923  0.153305  0.809524  0.587295
#
# [703 rows x 5 columns]

# %% [markdown]
# # Part P'Bell

# %%
import pandas as pd
import talib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf
import numpy as np

# Calculate MACD
# Calculate MACD with forward-fill to handle NaN values
tisco15_close['macd'], tisco15_close['signal'], _ = talib.MACD(tisco15_close['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
tisco15_close[['macd', 'signal']] = tisco15_close[['macd', 'signal']].fillna(method='ffill')

# Create Label (target variable)
tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['macd', 'signal', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])
    
# Create Features
features = tisco15_close[['macd', 'signal']]
print(features)
# Create Label (target variable)

tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['macd', 'signal', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])


# Remove rows with missing data
tisco15_close = tisco15_close.dropna(subset=['macd', 'signal', 'target'])

print("Shape of features:", features.shape)
print("Shape of target:", tisco15_close['target'].shape)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, tisco15_close['target'], test_size=0.2, random_state=42)

# Create and Train Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Test the Model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# Evaluate the Model
print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 11
#       7 import numpy as np
#       9 # Calculate MACD
#      10 # Calculate MACD with forward-fill to handle NaN values
# ---> 11 tisco15_close['macd'], tisco15_close['signal'], _ = talib.MACD(tisco15_close['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
#      12 tisco15_close[['macd', 'signal']] = tisco15_close[['macd', 'signal']].fillna(method='ffill')
#      14 # Create Label (target variable)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'Close'

# %%
import pandas as pd
import talib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf
import numpy as np

# Calculate Moving Averages
# Assume you want to use a simple moving average (SMA) with a window of 10 periods
tisco15_close['ma'] = talib.SMA(tisco15_close['Close'], timeperiod=10)

# Create Label (target variable)
tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['ma', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])

# Create Features
features = tisco15_close[['ma']]
print(features)

# Verify the shapes of features and target
print("Shape of features:", features.shape)
print("Shape of target:", tisco15_close['target'].shape)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, tisco15_close['target'], test_size=0.2, random_state=42)

# Create and Train Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Test the Model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# Evaluate the Model
print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(y_test, predictions))
# Out:
#           ma
# 372   97.525
# 373   97.525
# 374   97.525
# 375   97.525
# 376   97.550
# ..       ...
# 717  100.450
# 718  100.450
# 719  100.450
# 720  100.450
# 721  100.450
#
# [350 rows x 1 columns]
# Shape of features: (350, 1)
# Shape of target: (350,)
# Accuracy: 0.7428571428571429
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85        54
#            1       0.33      0.12      0.18        16
#
#     accuracy                           0.74        70
#    macro avg       0.56      0.53      0.51        70
# weighted avg       0.68      0.74      0.70        70

# %%
import pandas as pd
import talib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf
import numpy as np

# Calculate Relative Strength Index (RSI)
# Assume you want to use a window of 14 periods for RSI
tisco15_close['rsi'] = talib.RSI(tisco15_close['Close'], timeperiod=14)

# Create Label (target variable)
tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['rsi', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])

# Create Features
features = tisco15_close[['rsi']]
print(features)

# Verify the shapes of features and target
print("Shape of features:", features.shape)
print("Shape of target:", tisco15_close['target'].shape)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, tisco15_close['target'], test_size=0.2, random_state=42)

# Create and Train Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Test the Model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# Evaluate the Model
print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(y_test, predictions))
# Out:
#             rsi
# 386  100.000000
# 387  100.000000
# 388  100.000000
# 389  100.000000
# 390  100.000000
# ..          ...
# 717   59.166108
# 718   59.166108
# 719   59.166108
# 720   59.166108
# 721   59.166108
#
# [336 rows x 1 columns]
# Shape of features: (336, 1)
# Shape of target: (336,)
# Accuracy: 0.6764705882352942
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79        48
#            1       0.40      0.20      0.27        20
#
#     accuracy                           0.68        68
#    macro avg       0.56      0.54      0.53        68
# weighted avg       0.63      0.68      0.64        68

# %% [markdown]
# ## Add corr between min

# %% [markdown]
# TISCO

# %%
correlation_matrix = TISCO_1m_df.corrwith(TISCO_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open         0.276463
# High         0.335537
# Low          0.220804
# Close        0.315291
# Adj Close    0.315291
# Volume      -0.008268
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is weak (0.28)
# The correlation between 'tisco15_close' and 'High' is moderate (0.34)
# The correlation between 'tisco15_close' and 'Low' is weak (0.22)
# The correlation between 'tisco15_close' and 'Close' is moderate (0.32)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (0.32)
# There is no significant correlation between 'tisco15_close' and 'Volume' (-0.01)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\3299380281.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = TISCO_1m_df.corrwith(TISCO_15m_df)

# %%
correlation_matrix = TISCO_5m_df.corrwith(TISCO_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open         0.630599
# High         0.608561
# Low          0.626095
# Close        0.620825
# Adj Close    0.620825
# Volume       0.002656
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is moderate (0.63)
# The correlation between 'tisco15_close' and 'High' is moderate (0.61)
# The correlation between 'tisco15_close' and 'Low' is moderate (0.63)
# The correlation between 'tisco15_close' and 'Close' is moderate (0.62)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (0.62)
# There is no significant correlation between 'tisco15_close' and 'Volume' (0.00)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\2997211836.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = TISCO_5m_df.corrwith(TISCO_15m_df)

# %%
correlation_matrix = TISCO_2m_df.corrwith(TISCO_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open         0.667270
# High         0.650459
# Low          0.678412
# Close        0.656002
# Adj Close    0.656002
# Volume      -0.038061
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is moderate (0.67)
# The correlation between 'tisco15_close' and 'High' is moderate (0.65)
# The correlation between 'tisco15_close' and 'Low' is moderate (0.68)
# The correlation between 'tisco15_close' and 'Close' is moderate (0.66)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (0.66)
# There is no significant correlation between 'tisco15_close' and 'Volume' (-0.04)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\2783260350.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = TISCO_2m_df.corrwith(TISCO_15m_df)

# %% [markdown]
# ERW

# %%
correlation_matrix = ERW_1m_df.corrwith(ERW_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open        -0.198041
# High        -0.213678
# Low         -0.223228
# Close       -0.188516
# Adj Close   -0.188516
# Volume      -0.066339
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is weak (-0.20)
# The correlation between 'tisco15_close' and 'High' is weak (-0.21)
# The correlation between 'tisco15_close' and 'Low' is weak (-0.22)
# The correlation between 'tisco15_close' and 'Close' is weak (-0.19)
# The correlation between 'tisco15_close' and 'Adj Close' is weak (-0.19)
# There is no significant correlation between 'tisco15_close' and 'Volume' (-0.07)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\3306132503.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = ERW_1m_df.corrwith(ERW_15m_df)

# %%
correlation_matrix = ERW_5m_df.corrwith(ERW_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open        -0.545070
# High        -0.557945
# Low         -0.543858
# Close       -0.533178
# Adj Close   -0.533178
# Volume      -0.036110
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is moderate (-0.55)
# The correlation between 'tisco15_close' and 'High' is moderate (-0.56)
# The correlation between 'tisco15_close' and 'Low' is moderate (-0.54)
# The correlation between 'tisco15_close' and 'Close' is moderate (-0.53)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (-0.53)
# There is no significant correlation between 'tisco15_close' and 'Volume' (-0.04)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\1576398406.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = ERW_5m_df.corrwith(ERW_15m_df)

# %%
correlation_matrix = ERW_2m_df.corrwith(ERW_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open         0.328706
# High         0.355397
# Low          0.334106
# Close        0.322633
# Adj Close    0.322633
# Volume      -0.029090
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is moderate (0.33)
# The correlation between 'tisco15_close' and 'High' is moderate (0.36)
# The correlation between 'tisco15_close' and 'Low' is moderate (0.33)
# The correlation between 'tisco15_close' and 'Close' is moderate (0.32)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (0.32)
# There is no significant correlation between 'tisco15_close' and 'Volume' (-0.03)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\3038201153.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = ERW_2m_df.corrwith(ERW_15m_df)

# %% [markdown]
# SPRC

# %%
correlation_matrix = SPRC_1m_df.corrwith(SPRC_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open         0.376084
# High         0.394498
# Low          0.421975
# Close        0.395436
# Adj Close    0.395436
# Volume      -0.088317
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is moderate (0.38)
# The correlation between 'tisco15_close' and 'High' is moderate (0.39)
# The correlation between 'tisco15_close' and 'Low' is moderate (0.42)
# The correlation between 'tisco15_close' and 'Close' is moderate (0.40)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (0.40)
# There is no significant correlation between 'tisco15_close' and 'Volume' (-0.09)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\2154650747.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = SPRC_1m_df.corrwith(SPRC_15m_df)

# %%
correlation_matrix = SPRC_5m_df.corrwith(SPRC_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open         0.375656
# High         0.387610
# Low          0.399607
# Close        0.384296
# Adj Close    0.384296
# Volume       0.017392
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is moderate (0.38)
# The correlation between 'tisco15_close' and 'High' is moderate (0.39)
# The correlation between 'tisco15_close' and 'Low' is moderate (0.40)
# The correlation between 'tisco15_close' and 'Close' is moderate (0.38)
# The correlation between 'tisco15_close' and 'Adj Close' is moderate (0.38)
# There is no significant correlation between 'tisco15_close' and 'Volume' (0.02)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\2067714339.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = SPRC_5m_df.corrwith(SPRC_15m_df)

# %%
correlation_matrix = SPRC_2m_df.corrwith(SPRC_15m_df)

# แสดงผลลัพธ์
print("Correlation Matrix:")
print(correlation_matrix)

print("\nInterpretation:")
for variable, correlation in correlation_matrix.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")
# Out:
# Correlation Matrix:
# Open        -0.132315
# High        -0.159087
# Low         -0.167681
# Close       -0.148206
# Adj Close   -0.148206
# Volume       0.068905
# Diff              NaN
# dtype: float64
#
# Interpretation:
# The correlation between 'tisco15_close' and 'Open' is weak (-0.13)
# The correlation between 'tisco15_close' and 'High' is weak (-0.16)
# The correlation between 'tisco15_close' and 'Low' is weak (-0.17)
# The correlation between 'tisco15_close' and 'Close' is weak (-0.15)
# The correlation between 'tisco15_close' and 'Adj Close' is weak (-0.15)
# There is no significant correlation between 'tisco15_close' and 'Volume' (0.07)
# There is no significant correlation between 'tisco15_close' and 'Diff' (nan)
# C:\Users\Natthita\AppData\Local\Temp\ipykernel_24012\2315715909.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = SPRC_2m_df.corrwith(SPRC_15m_df)

# %% [markdown]
# Data Splitting

# %%
# Split dataset

# %% [markdown]
# ## Model Development (Training)

# %%
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer, roc_auc_score, confusion_matrix
import numpy as np

# set parameter
y_train = y_train_df.values.ravel()
k = 10
auc_scorer = make_scorer(roc_auc_score, greater_is_better = True, average= 'macro',multi_class='ovr',needs_proba=True)

# 1. Logistic regression
lgr = LogisticRegression(solver='liblinear')
param_grid_lgr = {'C': np.logspace(-4, 4, 20), 'penalty': ['l1', 'l2']}
grid_search_lgr = GridSearchCV(estimator=lgr, param_grid=param_grid_lgr, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_lgr.fit(X_train_scaled_df, y_train)


# 2. Extreme Gradient Boosting (XGBoost) 
xgb_classifier = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
param_grid_xgb = {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 5], 'learning_rate': [0.1, 0.01, 0.001]}
grid_search_xgb = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid_xgb, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_xgb.fit(X_train_scaled_df, y_train)


# 3. SVM Support Vector Machine (SVM)
svm = SVC(probability=True)
param_grid_svm = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}
grid_search_svm = GridSearchCV(estimator=svm, param_grid=param_grid_svm, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_svm.fit(X_train_scaled_df, y_train)


# 4. Random forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
param_grid_rf = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_rf.fit(X_train_scaled_df, y_train)


# 5. Decision tree

dt = DecisionTreeClassifier(random_state=42)
param_grid_dt = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_dt = GridSearchCV(estimator=dt, param_grid=param_grid_dt, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_dt.fit(X_train_scaled_df, y_train)

# %%
# Threshold Tuning

# Logistic Regression
custom_threshold_lgr = 0.6  # Adjust as needed
y_pred_lgr = (y_prob_lgr[:, 1] >= custom_threshold_lgr).astype(int)

# XGBoost
custom_threshold_xgb = 0.6  # Adjust as needed
y_pred_xgb = (y_prob_xgb[:, 1] >= custom_threshold_xgb).astype(int)

# Random Forest
custom_threshold_rf = 0.6  # Adjust as needed
y_pred_rf = (y_prob_rf[:, 1] >= custom_threshold_rf).astype(int)

# %% [markdown]
# ## Model Evaluation (Testing Model):

# %%
# Prediction
# Confusion Matrix and AUC Calculation

# 1. Logistic regression

y_prob_lgr = grid_search_lgr.predict_proba(X_test)
auc_lgr = roc_auc_score(y_test, y_prob_lgr, multi_class='ovr') * 100

print("\nLogistic Regression Confusion Matrix:", conf_matrix_lgr)
print(f"Logistic Regression AUC Score: {auc_lgr:.2f}%")


# 2. Extreme Gradient Boosting (XGBoost)

y_prob_xgb = grid_search_xgb.predict_proba(X_test)
auc_xgb = roc_auc_score(y_test, y_prob_xgb, multi_class='ovr') * 100

print("\nXGBoost Confusion Matrix:", confusion_matrix(y_test, grid_search_xgb.predict(X_test)))
print(f"XGBoost AUC Score: {auc_xgb:.2f}%")

# 3. SVM

y_prob_svm = grid_search_svm.predict_proba(X_test)
auc_svm = roc_auc_score(y_test, y_prob_svm, multi_class='ovr') * 100

print("\nSVM Confusion Matrix:", confusion_matrix(y_test, grid_search_svm.predict(X_test)))
print(f"SVM AUC Score: {auc_svm:.2f}%")


# 4. Random forest

y_prob_rf = grid_search_rf.predict_proba(X_test)
auc_rf = roc_auc_score(y_test, y_prob_rf, multi_class='ovr') * 100

print("\nRandom Forest Confusion Matrix:", confusion_matrix(y_test, grid_search_rf.predict(X_test)))
print(f"Random Forest AUC Score: {auc_rf:.2f}%")


# 5. Decision tree

y_prob_dt = grid_search_dt.predict_proba(X_test)
auc_dt = roc_auc_score(y_test, y_prob_dt, multi_class='ovr') * 100

print("\nDecision Tree Confusion Matrix:", confusion_matrix(y_test, grid_search_dt.predict(X_test)))
print(f"Decision Tree AUC Score: {auc_dt:.2f}%")

# %% [markdown]
# ## Deployment: (Prediction)

# %%
# Select the best score Model

# %% [markdown]
# ## Submission

# %%
# Output
submission = pd.DataFrame({"Id":range(1,301),"Expected":result}) # To be revised
print(submission.shape)
print(submission.head())
submission.to_csv("submission.csv", index=False)
