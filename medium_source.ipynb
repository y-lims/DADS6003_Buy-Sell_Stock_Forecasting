# %% [markdown]
# # Libraries

# %% [markdown]
# ## to Install

# %%
# pip install TA-Lib

# # For Colab
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
# !pip install ta

# %% [markdown]
# ## to Import

# %%
# Import the Libraries

# Data Manupulation
import numpy as np
import pandas as pd
import scipy.stats as stats
from datetime import datetime, timedelta

# Techinical Indicators
import talib

# Plotting graphs
import matplotlib.pyplot as plt
import seaborn as sns

# Standardization
from sklearn.preprocessing import MinMaxScaler

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report

# Data fetching
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# # Stock Data

# %% [markdown]
# ## TISCO

# %% [markdown]
# ### 1m

# %%
# TISCO 1m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
TISCO_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_1m_df = pd.concat([TISCO_1m_df, data])

# Reset the index to get Date as a column
TISCO_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_1m_df)

# # Save the DataFrame to a CSV file
# TISCO_1m_df.to_csv('data_TISCO_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date    Open   High     Low  Close  \
# 0         1m 2024-01-03 10:00:00+07:00   99.50   99.5   99.50   99.5
# 1         1m 2024-01-03 10:02:00+07:00   99.75  100.0   99.75  100.0
# 2         1m 2024-01-03 10:03:00+07:00  100.00  100.0  100.00  100.0
# 3         1m 2024-01-03 10:04:00+07:00  100.00  100.5  100.00  100.5
# 4         1m 2024-01-03 10:05:00+07:00  100.50  100.5  100.00  100.5
# ..       ...                       ...     ...    ...     ...    ...
# 989       1m 2024-01-08 16:24:00+07:00  101.00  101.0  100.50  101.0
# 990       1m 2024-01-08 16:25:00+07:00  100.50  101.0  100.50  101.0
# 991       1m 2024-01-08 16:26:00+07:00  100.50  101.0  100.50  101.0
# 992       1m 2024-01-08 16:28:00+07:00  101.00  101.0  100.50  101.0
# 993       1m 2024-01-08 16:29:00+07:00  101.00  101.0  100.50  101.0
#
#      Adj Close  Volume
# 0         99.5       0
# 1        100.0  241605
# 2        100.0    5245
# 3        100.5  675732
# 4        100.5  200635
# ..         ...     ...
# 989      101.0    4800
# 990      101.0    4601
# 991      101.0    2100
# 992      101.0   84015
# 993      101.0   18090
#
# [994 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# TISCO 2m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
TISCO_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_2m_df = pd.concat([TISCO_2m_df, data])

# Reset the index to get Date as a column
TISCO_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_2m_df)

# # Save the DataFrame to a CSV file
# TISCO_2m_df.to_csv('data_TISCO_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date   Open   High    Low  Close  \
# 0          2m 2023-11-20 10:00:00+07:00   97.5   97.5   97.5   97.5
# 1          2m 2023-11-20 10:02:00+07:00   97.5   97.5   97.5   97.5
# 2          2m 2023-11-20 10:04:00+07:00   97.5   97.5   97.5   97.5
# 3          2m 2023-11-20 10:06:00+07:00   97.5   97.5   97.5   97.5
# 4          2m 2023-11-20 10:08:00+07:00   97.5   97.5   97.5   97.5
# ...       ...                       ...    ...    ...    ...    ...
# 4036       2m 2024-01-08 16:20:00+07:00  100.5  100.5  100.5  100.5
# 4037       2m 2024-01-08 16:22:00+07:00  101.0  101.0  100.5  100.5
# 4038       2m 2024-01-08 16:24:00+07:00  101.0  101.0  100.5  101.0
# 4039       2m 2024-01-08 16:26:00+07:00  100.5  101.0  100.5  101.0
# 4040       2m 2024-01-08 16:28:00+07:00  101.0  101.0  100.5  101.0
#
#       Adj Close  Volume
# 0          97.5       0
# 1          97.5   59432
# 2          97.5    5900
# 3          97.5      92
# 4          97.5   10015
# ...         ...     ...
# 4036      100.5     401
# 4037      100.5   13704
# 4038      101.0    9401
# 4039      101.0    2100
# 4040      101.0  102105
#
# [4041 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# TISCO 5m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
TISCO_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_5m_df = pd.concat([TISCO_5m_df, data])

# Reset the index to get Date as a column
TISCO_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_5m_df)

# # Save the DataFrame to a CSV file
# TISCO_5m_df.to_csv('data_TISCO_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date   Open    High     Low  Close  \
# 0          5m 2023-11-13 10:00:00+07:00   96.5   96.50   96.25   96.5
# 1          5m 2023-11-13 10:05:00+07:00   96.5   96.75   96.50   96.5
# 2          5m 2023-11-13 10:10:00+07:00   96.5   96.50   96.50   96.5
# 3          5m 2023-11-13 10:15:00+07:00   96.5   96.75   96.50   96.5
# 4          5m 2023-11-13 10:20:00+07:00   96.5   96.75   96.50   96.5
# ...       ...                       ...    ...     ...     ...    ...
# 1965       5m 2024-01-08 16:05:00+07:00  101.0  101.00  100.50  101.0
# 1966       5m 2024-01-08 16:10:00+07:00  101.0  101.00  100.50  101.0
# 1967       5m 2024-01-08 16:15:00+07:00  101.0  101.00  100.50  100.5
# 1968       5m 2024-01-08 16:20:00+07:00  100.5  101.00  100.50  101.0
# 1969       5m 2024-01-08 16:25:00+07:00  100.5  101.00  100.50  101.0
#
#       Adj Close  Volume
# 0          96.5   87343
# 1          96.5    4578
# 2          96.5   10810
# 3          96.5    7917
# 4          96.5   12739
# ...         ...     ...
# 1965      101.0   24286
# 1966      101.0   29411
# 1967      100.5  138061
# 1968      101.0   18905
# 1969      101.0  108806
#
# [1970 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# TISCO 15m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
TISCO_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_15m_df = pd.concat([TISCO_15m_df, data])

# Reset the index to get Date as a column
TISCO_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_15m_df)

# # Save the DataFrame to a CSV file
# TISCO_15m_df.to_csv('data_TISCO_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date   Open    High     Low  Close  Adj Close  \
# 0        15m 2023-11-13 10:00:00   96.5   96.75   96.25   96.5       96.5
# 1        15m 2023-11-13 10:15:00   96.5   96.75   96.50   96.5       96.5
# 2        15m 2023-11-13 10:30:00   96.5   96.50   96.25   96.5       96.5
# 3        15m 2023-11-13 10:45:00   96.5   96.50   96.25   96.5       96.5
# 4        15m 2023-11-13 11:00:00   96.5   96.75   96.50   96.5       96.5
# ..       ...                 ...    ...     ...     ...    ...        ...
# 679      15m 2024-01-08 15:15:00  101.0  101.00  100.50  100.5      100.5
# 680      15m 2024-01-08 15:30:00  100.5  101.00  100.50  101.0      101.0
# 681      15m 2024-01-08 15:45:00  100.5  101.00  100.50  101.0      101.0
# 682      15m 2024-01-08 16:00:00  101.0  101.00  100.50  101.0      101.0
# 683      15m 2024-01-08 16:15:00  101.0  101.00  100.50  101.0      101.0
#
#      Volume
# 0    102731
# 1     27159
# 2     87613
# 3     80911
# 4     90534
# ..      ...
# 679   54074
# 680   85697
# 681   67019
# 682  101935
# 683  265772
#
# [684 rows x 8 columns]

# %%
#Add Y
# Shift the 'Close' column up by one row
TISCO_15m_df['Close_Shifted'] = TISCO_15m_df['Close'].shift(-1)

# Add a new column 'Signal' based on the condition
TISCO_15m_df['Signal'] = np.where(TISCO_15m_df['Close_Shifted'] > TISCO_15m_df['Close'], 2,
                         np.where(TISCO_15m_df['Close_Shifted'] < TISCO_15m_df['Close'], 1, 0))

# Display the resulting DataFrame with the new columns
display(TISCO_15m_df)
# Out:
#     Interval                Date   Open    High     Low  Close  Adj Close  \
# 0        15m 2023-11-13 10:00:00   96.5   96.75   96.25   96.5       96.5
# 1        15m 2023-11-13 10:15:00   96.5   96.75   96.50   96.5       96.5
# 2        15m 2023-11-13 10:30:00   96.5   96.50   96.25   96.5       96.5
# 3        15m 2023-11-13 10:45:00   96.5   96.50   96.25   96.5       96.5
# 4        15m 2023-11-13 11:00:00   96.5   96.75   96.50   96.5       96.5
# ..       ...                 ...    ...     ...     ...    ...        ...
# 679      15m 2024-01-08 15:15:00  101.0  101.00  100.50  100.5      100.5
# 680      15m 2024-01-08 15:30:00  100.5  101.00  100.50  101.0      101.0
# 681      15m 2024-01-08 15:45:00  100.5  101.00  100.50  101.0      101.0
# 682      15m 2024-01-08 16:00:00  101.0  101.00  100.50  101.0      101.0
# 683      15m 2024-01-08 16:15:00  101.0  101.00  100.50  101.0      101.0
#
#      Volume  Close_Shifted  Signal
# 0    102731           96.5       0
# 1     27159           96.5       0
# 2     87613           96.5       0
# 3     80911           96.5       0
# 4     90534           96.5       0
# ..      ...            ...     ...
# 679   54074          101.0       2
# 680   85697          101.0       0
# 681   67019          101.0       0
# 682  101935          101.0       0
# 683  265772            NaN       0
#
# [684 rows x 10 columns]

# %% [markdown]
# ## ERW

# %% [markdown]
# ### 1m

# %%
# ERW 1m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
ERW_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_1m_df = pd.concat([ERW_1m_df, data])

# Reset the index to get Date as a column
ERW_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_1m_df)

# # Save the DataFrame to a CSV file
# ERW_1m_df.to_csv('data_ERW_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0         1m 2024-01-03 10:00:00+07:00  5.15  5.15  5.15   5.15       5.15
# 1         1m 2024-01-03 10:01:00+07:00  5.15  5.20  5.15   5.20       5.20
# 2         1m 2024-01-03 10:02:00+07:00  5.15  5.15  5.15   5.15       5.15
# 3         1m 2024-01-03 10:03:00+07:00  5.15  5.20  5.10   5.20       5.20
# 4         1m 2024-01-03 10:04:00+07:00  5.20  5.20  5.20   5.20       5.20
# ..       ...                       ...   ...   ...   ...    ...        ...
# 823       1m 2024-01-08 16:23:00+07:00  5.15  5.15  5.10   5.10       5.10
# 824       1m 2024-01-08 16:25:00+07:00  5.10  5.15  5.10   5.15       5.15
# 825       1m 2024-01-08 16:26:00+07:00  5.10  5.10  5.10   5.10       5.10
# 826       1m 2024-01-08 16:27:00+07:00  5.15  5.15  5.15   5.15       5.15
# 827       1m 2024-01-08 16:29:00+07:00  5.15  5.15  5.10   5.10       5.10
#
#       Volume
# 0          0
# 1          0
# 2     509401
# 3    2215500
# 4       5500
# ..       ...
# 823      700
# 824    50500
# 825    99300
# 826     2300
# 827    47400
#
# [828 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# ERW 2m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
ERW_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_2m_df = pd.concat([ERW_2m_df, data])

# Reset the index to get Date as a column
ERW_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_2m_df)

# # Save the DataFrame to a CSV file
# ERW_2m_df.to_csv('data_ERW_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High  Low  Close  Adj Close  \
# 0          2m 2023-11-20 10:00:00+07:00  5.45  5.45  5.4   5.40       5.40
# 1          2m 2023-11-20 10:02:00+07:00  5.40  5.40  5.4   5.40       5.40
# 2          2m 2023-11-20 10:04:00+07:00  5.40  5.45  5.4   5.45       5.45
# 3          2m 2023-11-20 10:06:00+07:00  5.45  5.45  5.4   5.40       5.40
# 4          2m 2023-11-20 10:08:00+07:00  5.45  5.45  5.4   5.40       5.40
# ...       ...                       ...   ...   ...  ...    ...        ...
# 3465       2m 2024-01-08 16:20:00+07:00  5.15  5.15  5.1   5.10       5.10
# 3466       2m 2024-01-08 16:22:00+07:00  5.10  5.15  5.1   5.10       5.10
# 3467       2m 2024-01-08 16:24:00+07:00  5.10  5.15  5.1   5.15       5.15
# 3468       2m 2024-01-08 16:26:00+07:00  5.10  5.15  5.1   5.15       5.15
# 3469       2m 2024-01-08 16:28:00+07:00  5.15  5.15  5.1   5.10       5.10
#
#       Volume
# 0          0
# 1          0
# 2      10200
# 3          0
# 4      10100
# ...      ...
# 3465  103200
# 3466  102600
# 3467   50500
# 3468  101600
# 3469   47400
#
# [3470 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# ERW 5m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
ERW_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_5m_df = pd.concat([ERW_5m_df, data])

# Reset the index to get Date as a column
ERW_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_5m_df)

# # Save the DataFrame to a CSV file
# ERW_5m_df.to_csv('data_ERW_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High  Low  Close  Adj Close  \
# 0          5m 2023-11-13 10:00:00+07:00  5.05  5.05  5.0   5.00       5.00
# 1          5m 2023-11-13 10:05:00+07:00  5.00  5.00  5.0   5.00       5.00
# 2          5m 2023-11-13 10:10:00+07:00  5.00  5.00  5.0   5.00       5.00
# 3          5m 2023-11-13 10:15:00+07:00  5.05  5.05  5.0   5.00       5.00
# 4          5m 2023-11-13 10:20:00+07:00  5.00  5.00  5.0   5.00       5.00
# ...       ...                       ...   ...   ...  ...    ...        ...
# 1908       5m 2024-01-08 16:05:00+07:00  5.10  5.15  5.1   5.15       5.15
# 1909       5m 2024-01-08 16:10:00+07:00  5.15  5.15  5.1   5.15       5.15
# 1910       5m 2024-01-08 16:15:00+07:00  5.15  5.15  5.1   5.15       5.15
# 1911       5m 2024-01-08 16:20:00+07:00  5.15  5.15  5.1   5.10       5.10
# 1912       5m 2024-01-08 16:25:00+07:00  5.10  5.15  5.1   5.10       5.10
#
#       Volume
# 0          0
# 1     480600
# 2     348800
# 3       5205
# 4       3406
# ...      ...
# 1908   74000
# 1909   93300
# 1910   77500
# 1911  205800
# 1912  199500
#
# [1913 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# ERW 15m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
ERW_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_15m_df = pd.concat([ERW_15m_df, data])

# Reset the index to get Date as a column
ERW_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_15m_df)

# # Save the DataFrame to a CSV file
# ERW_15m_df.to_csv('data_ERW_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High  Low  Close  Adj Close  Volume
# 0        15m 2023-11-13 10:00:00  5.05  5.05  5.0   5.00       5.00  829400
# 1        15m 2023-11-13 10:15:00  5.05  5.05  5.0   5.00       5.00   30354
# 2        15m 2023-11-13 10:30:00  5.00  5.00  5.0   5.00       5.00   48152
# 3        15m 2023-11-13 10:45:00  5.00  5.00  5.0   5.00       5.00    7403
# 4        15m 2023-11-13 11:00:00  5.00  5.05  5.0   5.00       5.00   79000
# ..       ...                 ...   ...   ...  ...    ...        ...     ...
# 679      15m 2024-01-08 15:15:00  5.10  5.15  5.1   5.10       5.10  300900
# 680      15m 2024-01-08 15:30:00  5.15  5.15  5.1   5.15       5.15  127700
# 681      15m 2024-01-08 15:45:00  5.10  5.15  5.1   5.15       5.15  312500
# 682      15m 2024-01-08 16:00:00  5.10  5.15  5.1   5.15       5.15  242800
# 683      15m 2024-01-08 16:15:00  5.15  5.15  5.1   5.10       5.10  482800
#
# [684 rows x 8 columns]

# %%
#Add Y
# Shift the 'Close' column up by one row
ERW_15m_df['Close_Shifted'] = ERW_15m_df['Close'].shift(-1)

# Add a new column 'Signal' based on the condition
ERW_15m_df['Signal'] = np.where(ERW_15m_df['Close_Shifted'] > ERW_15m_df['Close'], 2,
                       np.where(ERW_15m_df['Close_Shifted'] < ERW_15m_df['Close'], 1, 0))

# Display the resulting DataFrame with the new columns
display(ERW_15m_df)
# Out:
#     Interval                Date  Open  High  Low  Close  Adj Close  Volume  \
# 0        15m 2023-11-13 10:00:00  5.05  5.05  5.0   5.00       5.00  829400
# 1        15m 2023-11-13 10:15:00  5.05  5.05  5.0   5.00       5.00   30354
# 2        15m 2023-11-13 10:30:00  5.00  5.00  5.0   5.00       5.00   48152
# 3        15m 2023-11-13 10:45:00  5.00  5.00  5.0   5.00       5.00    7403
# 4        15m 2023-11-13 11:00:00  5.00  5.05  5.0   5.00       5.00   79000
# ..       ...                 ...   ...   ...  ...    ...        ...     ...
# 679      15m 2024-01-08 15:15:00  5.10  5.15  5.1   5.10       5.10  300900
# 680      15m 2024-01-08 15:30:00  5.15  5.15  5.1   5.15       5.15  127700
# 681      15m 2024-01-08 15:45:00  5.10  5.15  5.1   5.15       5.15  312500
# 682      15m 2024-01-08 16:00:00  5.10  5.15  5.1   5.15       5.15  242800
# 683      15m 2024-01-08 16:15:00  5.15  5.15  5.1   5.10       5.10  482800
#
#      Close_Shifted  Signal
# 0             5.00       0
# 1             5.00       0
# 2             5.00       0
# 3             5.00       0
# 4             5.05       2
# ..             ...     ...
# 679           5.15       2
# 680           5.15       0
# 681           5.15       0
# 682           5.10       1
# 683            NaN       0
#
# [684 rows x 10 columns]

# %% [markdown]
# ## SPRC

# %% [markdown]
# ### 1m

# %%
# SPRC 1m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
SPRC_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_1m_df = pd.concat([SPRC_1m_df, data])

# Reset the index to get Date as a column
SPRC_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_1m_df)

# # Save the DataFrame to a CSV file
# SPRC_1m_df.to_csv('data_SPRC_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0         1m 2024-01-03 10:01:00+07:00  8.30  8.30  8.30   8.30       8.30
# 1         1m 2024-01-03 10:02:00+07:00  8.30  8.30  8.30   8.30       8.30
# 2         1m 2024-01-03 10:03:00+07:00  8.30  8.30  8.25   8.30       8.30
# 3         1m 2024-01-03 10:04:00+07:00  8.30  8.30  8.25   8.25       8.25
# 4         1m 2024-01-03 10:05:00+07:00  8.30  8.30  8.25   8.25       8.25
# ..       ...                       ...   ...   ...   ...    ...        ...
# 963       1m 2024-01-08 16:25:00+07:00  8.40  8.45  8.40   8.40       8.40
# 964       1m 2024-01-08 16:26:00+07:00  8.45  8.45  8.40   8.40       8.40
# 965       1m 2024-01-08 16:27:00+07:00  8.45  8.45  8.45   8.45       8.45
# 966       1m 2024-01-08 16:28:00+07:00  8.45  8.45  8.40   8.45       8.45
# 967       1m 2024-01-08 16:29:00+07:00  8.40  8.45  8.40   8.45       8.45
#
#      Volume
# 0         0
# 1         0
# 2     23800
# 3     17200
# 4      1500
# ..      ...
# 963   21900
# 964   14400
# 965   12500
# 966   33600
# 967     700
#
# [968 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# SPRC 2m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
SPRC_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_2m_df = pd.concat([SPRC_2m_df, data])

# Reset the index to get Date as a column
SPRC_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_2m_df)

# # Save the DataFrame to a CSV file
# SPRC_2m_df.to_csv('data_SPRC_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          2m 2023-11-20 10:00:00+07:00  8.25  8.25  8.20   8.20       8.20
# 1          2m 2023-11-20 10:02:00+07:00  8.20  8.20  8.15   8.15       8.15
# 2          2m 2023-11-20 10:04:00+07:00  8.15  8.15  8.15   8.15       8.15
# 3          2m 2023-11-20 10:06:00+07:00  8.15  8.15  8.10   8.10       8.10
# 4          2m 2023-11-20 10:08:00+07:00  8.10  8.15  8.10   8.15       8.15
# ...       ...                       ...   ...   ...   ...    ...        ...
# 3658       2m 2024-01-08 16:20:00+07:00  8.45  8.45  8.40   8.45       8.45
# 3659       2m 2024-01-08 16:22:00+07:00  8.45  8.45  8.45   8.45       8.45
# 3660       2m 2024-01-08 16:24:00+07:00  8.45  8.45  8.40   8.40       8.40
# 3661       2m 2024-01-08 16:26:00+07:00  8.45  8.45  8.40   8.45       8.45
# 3662       2m 2024-01-08 16:28:00+07:00  8.45  8.45  8.40   8.45       8.45
#
#       Volume
# 0     285800
# 1     289300
# 2     290700
# 3      12900
# 4      18200
# ...      ...
# 3658    2700
# 3659  103601
# 3660   28200
# 3661   26900
# 3662   34300
#
# [3663 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# SPRC 5m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
SPRC_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_5m_df = pd.concat([SPRC_5m_df, data])

# Reset the index to get Date as a column
SPRC_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_5m_df)

# # Save the DataFrame to a CSV file
# SPRC_5m_df.to_csv('data_SPRC_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          5m 2023-11-13 10:00:00+07:00  7.75  7.75  7.65   7.70       7.70
# 1          5m 2023-11-13 10:05:00+07:00  7.70  7.70  7.65   7.70       7.70
# 2          5m 2023-11-13 10:10:00+07:00  7.70  7.70  7.60   7.65       7.65
# 3          5m 2023-11-13 10:15:00+07:00  7.60  7.70  7.60   7.70       7.70
# 4          5m 2023-11-13 10:20:00+07:00  7.70  7.70  7.70   7.70       7.70
# ...       ...                       ...   ...   ...   ...    ...        ...
# 1927       5m 2024-01-08 16:05:00+07:00  8.45  8.45  8.40   8.40       8.40
# 1928       5m 2024-01-08 16:10:00+07:00  8.40  8.45  8.40   8.45       8.45
# 1929       5m 2024-01-08 16:15:00+07:00  8.45  8.45  8.45   8.45       8.45
# 1930       5m 2024-01-08 16:20:00+07:00  8.45  8.45  8.40   8.45       8.45
# 1931       5m 2024-01-08 16:25:00+07:00  8.40  8.45  8.40   8.45       8.45
#
#       Volume
# 0          0
# 1      30200
# 2     248104
# 3     428700
# 4       2700
# ...      ...
# 1927   25400
# 1928  500800
# 1929    2659
# 1930  112601
# 1931   83100
#
# [1932 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# SPRC 15m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SPRC_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_15m_df = pd.concat([SPRC_15m_df, data])

# Reset the index to get Date as a column
SPRC_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_15m_df)

# # Save the DataFrame to a CSV file
# SPRC_15m_df.to_csv('data_SPRC_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close   Volume
# 0        15m 2023-11-13 10:00:00  7.75  7.75  7.60   7.65       7.65   278304
# 1        15m 2023-11-13 10:15:00  7.60  7.70  7.60   7.65       7.65   604209
# 2        15m 2023-11-13 10:30:00  7.60  7.65  7.55   7.65       7.65  1756301
# 3        15m 2023-11-13 10:45:00  7.65  7.65  7.55   7.60       7.60   362500
# 4        15m 2023-11-13 11:00:00  7.55  7.60  7.55   7.60       7.60  1048500
# ..       ...                 ...   ...   ...   ...    ...        ...      ...
# 677      15m 2024-01-08 15:15:00  8.45  8.45  8.40   8.40       8.40   228000
# 678      15m 2024-01-08 15:30:00  8.40  8.45  8.40   8.45       8.45   195000
# 679      15m 2024-01-08 15:45:00  8.40  8.50  8.40   8.45       8.45   904000
# 680      15m 2024-01-08 16:00:00  8.45  8.45  8.40   8.45       8.45   569601
# 681      15m 2024-01-08 16:15:00  8.45  8.45  8.40   8.45       8.45   198360
#
# [682 rows x 8 columns]

# %%
#Add Y
# Shift the 'Close' column up by one row
SPRC_15m_df['Close_Shifted'] = SPRC_15m_df['Close'].shift(-1)

# Add a new column 'Signal' based on the condition
SPRC_15m_df['Signal'] = np.where(SPRC_15m_df['Close_Shifted'] > SPRC_15m_df['Close'], 2,
                        np.where(SPRC_15m_df['Close_Shifted'] < SPRC_15m_df['Close'], 1, 0))

# Display the resulting DataFrame with the new columns
display(SPRC_15m_df)
# Out:
#     Interval                Date  Open  High   Low  Close  Adj Close   Volume  \
# 0        15m 2023-11-13 10:00:00  7.75  7.75  7.60   7.65       7.65   278304
# 1        15m 2023-11-13 10:15:00  7.60  7.70  7.60   7.65       7.65   604209
# 2        15m 2023-11-13 10:30:00  7.60  7.65  7.55   7.65       7.65  1756301
# 3        15m 2023-11-13 10:45:00  7.65  7.65  7.55   7.60       7.60   362500
# 4        15m 2023-11-13 11:00:00  7.55  7.60  7.55   7.60       7.60  1048500
# ..       ...                 ...   ...   ...   ...    ...        ...      ...
# 677      15m 2024-01-08 15:15:00  8.45  8.45  8.40   8.40       8.40   228000
# 678      15m 2024-01-08 15:30:00  8.40  8.45  8.40   8.45       8.45   195000
# 679      15m 2024-01-08 15:45:00  8.40  8.50  8.40   8.45       8.45   904000
# 680      15m 2024-01-08 16:00:00  8.45  8.45  8.40   8.45       8.45   569601
# 681      15m 2024-01-08 16:15:00  8.45  8.45  8.40   8.45       8.45   198360
#
#      Close_Shifted  Signal
# 0             7.65       0
# 1             7.65       0
# 2             7.60       1
# 3             7.60       0
# 4             7.60       0
# ..             ...     ...
# 677           8.45       2
# 678           8.45       0
# 679           8.45       0
# 680           8.45       0
# 681            NaN       0
#
# [682 rows x 10 columns]

# %% [markdown]
# # Features Data

# %% [markdown]
# ## FX RATE USD-THB

# %%
# USD 15m
stock_symbol = 'THB=X'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
USD_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    USD_df = pd.concat([USD_df, data])

# Reset the index to get Date as a column
USD_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(USD_df)

# # Save the DataFrame to a CSV file
# USD_df.to_csv('data_USD.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-13 00:00:00  36.073002  36.104000  36.060001  36.089001
# 1         15m 2023-11-13 00:15:00  36.090000  36.092999  36.060001  36.060001
# 2         15m 2023-11-13 00:30:00  36.074001  36.080002  36.060001  36.076000
# 3         15m 2023-11-13 00:45:00  36.076000  36.077999  36.000000  36.035999
# 4         15m 2023-11-13 01:00:00  36.035000  36.035000  35.959999  35.959999
# ...       ...                 ...        ...        ...        ...        ...
# 3713      15m 2024-01-08 22:45:00  34.915001  34.959999  34.915001  34.919998
# 3714      15m 2024-01-08 23:00:00  34.950001  34.959999  34.890999  34.928001
# 3715      15m 2024-01-08 23:15:00  34.931000  34.950001  34.910000  34.929001
# 3716      15m 2024-01-08 23:30:00  34.931000  34.950001  34.919998  34.938999
# 3717      15m 2024-01-08 23:45:00  34.938000  34.959999  34.930000  34.950001
#
#       Adj Close  Volume
# 0     36.089001       0
# 1     36.060001       0
# 2     36.076000       0
# 3     36.035999       0
# 4     35.959999       0
# ...         ...     ...
# 3713  34.919998       0
# 3714  34.928001       0
# 3715  34.929001       0
# 3716  34.938999       0
# 3717  34.950001       0
#
# [3718 rows x 8 columns]

# %% [markdown]
# ## CNYX

# %%
# CNY 15m
stock_symbol = 'CNY=X'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
CNY_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    CNY_df = pd.concat([CNY_df, data])

# Reset the index to get Date as a column
CNY_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(CNY_df)

# # Save the DataFrame to a CSV file
# CNY_df.to_csv('data_CNY.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date    Open    High     Low   Close  Adj Close  \
# 0         15m 2023-11-13 01:30:00  7.2936  7.2936  7.2906  7.2908     7.2908
# 1         15m 2023-11-13 01:45:00  7.2907  7.2907  7.2881  7.2906     7.2906
# 2         15m 2023-11-13 02:00:00  7.2908  7.2927  7.2908  7.2924     7.2924
# 3         15m 2023-11-13 02:15:00  7.2926  7.2931  7.2925  7.2931     7.2931
# 4         15m 2023-11-13 02:30:00  7.2932  7.2940  7.2930  7.2938     7.2938
# ...       ...                 ...     ...     ...     ...     ...        ...
# 2376      15m 2024-01-08 16:00:00  7.1536  7.1536  7.1535  7.1535     7.1535
# 2377      15m 2024-01-08 16:45:00  7.1540  7.1540  7.1540  7.1540     7.1540
# 2378      15m 2024-01-08 17:00:00  7.1535  7.1535  7.1535  7.1535     7.1535
# 2379      15m 2024-01-08 17:15:00  7.1535  7.1535  7.1535  7.1535     7.1535
# 2380      15m 2024-01-08 17:30:00  7.1535  7.1535  7.1535  7.1535     7.1535
#
#       Volume
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2376       0
# 2377       0
# 2378       0
# 2379       0
# 2380       0
#
# [2381 rows x 8 columns]

# %% [markdown]
# ## SET100

# %%
# SET100 15m
stock_symbol = 'BSET100.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SET100_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SET100_df = pd.concat([SET100_df, data])

# Reset the index to get Date as a column
SET100_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SET100_df)

# # Save the DataFrame to a CSV file
# SET100_df.to_csv('data_SET100.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close  Volume
# 0        15m 2023-11-13 10:00:00  9.05  9.06  9.05   9.05       9.05     200
# 1        15m 2023-11-13 10:15:00  9.05  9.05  9.05   9.05       9.05     222
# 2        15m 2023-11-13 10:30:00  9.03  9.03  9.03   9.03       9.03     215
# 3        15m 2023-11-13 11:00:00  9.01  9.01  9.01   9.01       9.01    3500
# 4        15m 2023-11-13 11:30:00  9.04  9.04  9.00   9.01       9.01    1000
# ..       ...                 ...   ...   ...   ...    ...        ...     ...
# 393      15m 2024-01-08 14:30:00  9.20  9.20  9.20   9.20       9.20     600
# 394      15m 2024-01-08 15:00:00  9.20  9.20  9.20   9.20       9.20     600
# 395      15m 2024-01-08 15:30:00  9.20  9.20  9.20   9.20       9.20     500
# 396      15m 2024-01-08 15:45:00  9.20  9.22  9.20   9.22       9.22     400
# 397      15m 2024-01-08 16:00:00  9.21  9.21  9.19   9.19       9.19     200
#
# [398 rows x 8 columns]

# %% [markdown]
# ## SET50

# %%
# SET50 15m
stock_symbol = 'TDEX.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SET50_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SET50_df = pd.concat([SET50_df, data])

# Reset the index to get Date as a column
SET50_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SET50_df)

# # Save the DataFrame to a CSV file
# SET50_df.to_csv('data_SET50.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close  Volume
# 0        15m 2023-11-13 10:00:00  8.47  8.47  8.44   8.45       8.45   37794
# 1        15m 2023-11-13 10:15:00  8.44  8.45  8.42   8.42       8.42   33300
# 2        15m 2023-11-13 10:30:00  8.42  8.43  8.42   8.43       8.43   26625
# 3        15m 2023-11-13 10:45:00  8.42  8.43  8.42   8.43       8.43   69912
# 4        15m 2023-11-13 11:00:00  8.43  8.43  8.41   8.42       8.42    7900
# ..       ...                 ...   ...   ...   ...    ...        ...     ...
# 679      15m 2024-01-08 15:15:00  8.55  8.58  8.54   8.58       8.58    3905
# 680      15m 2024-01-08 15:30:00  8.58  8.58  8.56   8.56       8.56    1676
# 681      15m 2024-01-08 15:45:00  8.58  8.58  8.58   8.58       8.58    1053
# 682      15m 2024-01-08 16:00:00  8.57  8.57  8.57   8.57       8.57     100
# 683      15m 2024-01-08 16:15:00  8.57  8.57  8.56   8.56       8.56    1200
#
# [684 rows x 8 columns]

# %% [markdown]
# ## Gold

# %%
# Gold 15m
stock_symbol = 'GC=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
GOLD_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    GOLD_df = pd.concat([GOLD_df, data])

# Reset the index to get Date as a column
GOLD_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(GOLD_df)

# # Save the DataFrame to a CSV file
# GOLD_df.to_csv('data_GOLD.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date         Open         High          Low  \
# 0         15m 2023-11-12 18:00:00  1943.400024  1945.000000  1942.500000
# 1         15m 2023-11-12 18:15:00  1944.400024  1944.699951  1943.900024
# 2         15m 2023-11-12 18:30:00  1944.500000  1944.699951  1941.300049
# 3         15m 2023-11-12 18:45:00  1943.699951  1944.599976  1943.300049
# 4         15m 2023-11-12 19:00:00  1944.500000  1946.099976  1944.400024
# ...       ...                 ...          ...          ...          ...
# 3543      15m 2024-01-08 22:45:00  2039.900024  2040.199951  2039.099976
# 3544      15m 2024-01-08 23:00:00  2039.599976  2040.900024  2039.400024
# 3545      15m 2024-01-08 23:15:00  2039.599976  2039.800049  2038.800049
# 3546      15m 2024-01-08 23:30:00  2038.800049  2039.800049  2038.599976
# 3547      15m 2024-01-08 23:45:00  2039.000000  2039.300049  2038.199951
#
#             Close    Adj Close  Volume
# 0     1944.400024  1944.400024     784
# 1     1944.500000  1944.500000     407
# 2     1943.800049  1943.800049    1444
# 3     1944.500000  1944.500000     361
# 4     1946.099976  1946.099976    1043
# ...           ...          ...     ...
# 3543  2039.599976  2039.599976     551
# 3544  2039.500000  2039.500000    1354
# 3545  2038.900024  2038.900024     346
# 3546  2039.099976  2039.099976     442
# 3547  2039.000000  2039.000000    1047
#
# [3548 rows x 8 columns]

# %% [markdown]
# ## Financial Index

# %%
# Fincial Index 15m
stock_symbol = '^FINCIAL.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
FINCIAL_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    FINCIAL_df = pd.concat([FINCIAL_df, data])

# Reset the index to get Date as a column
FINCIAL_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(FINCIAL_df)

# # Save the DataFrame to a CSV file
# FINCIAL_df.to_csv('data_FINCIAL.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-13 10:00:00  138.570007  138.580002  137.699997
# 1        15m 2023-11-13 10:15:00  137.869995  138.080002  137.520004
# 2        15m 2023-11-13 10:30:00  137.610001  137.610001  136.970001
# 3        15m 2023-11-13 10:45:00  137.119995  137.300003  137.009995
# 4        15m 2023-11-13 11:00:00  137.229996  137.270004  137.039993
# ..       ...                 ...         ...         ...         ...
# 713      15m 2024-01-08 15:15:00  140.970001  141.449997  140.830002
# 714      15m 2024-01-08 15:30:00  141.360001  141.449997  141.160004
# 715      15m 2024-01-08 15:45:00  141.330002  141.410004  140.949997
# 716      15m 2024-01-08 16:00:00  141.360001  141.360001  140.889999
# 717      15m 2024-01-08 16:15:00  141.119995  141.199997  140.770004
#
#           Close   Adj Close  Volume
# 0    137.759995  137.759995       0
# 1    137.580002  137.580002       0
# 2    137.119995  137.119995       0
# 3    137.210007  137.210007       0
# 4    137.210007  137.210007       0
# ..          ...         ...     ...
# 713  141.449997  141.449997       0
# 714  141.389999  141.389999       0
# 715  141.350006  141.350006       0
# 716  141.080002  141.080002       0
# 717  140.850006  140.850006       0
#
# [718 rows x 8 columns]

# %% [markdown]
# ## Banking Index

# %%
# Banking Index 15m
stock_symbol = '^BANK.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
BANKING_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    BANKING_df = pd.concat([BANKING_df, data])

# Reset the index to get Date as a column
BANKING_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(BANKING_df)

# # Save the DataFrame to a CSV file
# BANKING_df.to_csv('data_BANKING.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-13 10:00:00  374.829987  374.829987  372.600006
# 1        15m 2023-11-13 10:15:00  373.730011  374.250000  372.660004
# 2        15m 2023-11-13 10:30:00  373.670013  373.670013  371.670013
# 3        15m 2023-11-13 10:45:00  372.170013  372.720001  371.549988
# 4        15m 2023-11-13 11:00:00  372.359985  373.019989  371.890015
# ..       ...                 ...         ...         ...         ...
# 711      15m 2024-01-08 15:15:00  382.049988  383.420013  381.559998
# 712      15m 2024-01-08 15:30:00  383.070007  383.559998  382.459991
# 713      15m 2024-01-08 15:45:00  383.140015  383.519989  382.320007
# 714      15m 2024-01-08 16:00:00  383.320007  383.440002  381.959991
# 715      15m 2024-01-08 16:15:00  382.320007  383.010010  381.410004
#
#           Close   Adj Close  Volume
# 0    373.279999  373.279999       0
# 1    373.109985  373.109985       0
# 2    372.170013  372.170013       0
# 3    372.359985  372.359985       0
# 4    372.809998  372.809998       0
# ..          ...         ...     ...
# 711  383.420013  383.420013       0
# 712  383.459991  383.459991       0
# 713  383.320007  383.320007       0
# 714  382.269989  382.269989       0
# 715  382.109985  382.109985       0
#
# [716 rows x 8 columns]

# %% [markdown]
# ## Service Index

# %%
# Service Index 15m
stock_symbol = '^SERVICE.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SERVICE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SERVICE_df = pd.concat([SERVICE_df, data])

# Reset the index to get Date as a column
SERVICE_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SERVICE_df)

# # Save the DataFrame to a CSV file
# SERVICE_df.to_csv('data_SERVICE.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-13 10:00:00  429.179993  429.260010  424.260010
# 1        15m 2023-11-13 10:15:00  424.709991  425.950012  423.730011
# 2        15m 2023-11-13 10:30:00  423.209991  424.500000  423.130005
# 3        15m 2023-11-13 10:45:00  423.440002  424.220001  422.920013
# 4        15m 2023-11-13 11:00:00  423.850006  423.850006  421.839996
# ..       ...                 ...         ...         ...         ...
# 713      15m 2024-01-08 15:15:00  428.609985  430.399994  427.809998
# 714      15m 2024-01-08 15:30:00  430.380005  430.380005  428.660004
# 715      15m 2024-01-08 15:45:00  429.359985  430.029999  428.480011
# 716      15m 2024-01-08 16:00:00  429.149994  429.790009  428.549988
# 717      15m 2024-01-08 16:15:00  429.350006  430.079987  428.779999
#
#           Close   Adj Close  Volume
# 0    424.700012  424.700012       0
# 1    424.119995  424.119995       0
# 2    423.690002  423.690002       0
# 3    424.220001  424.220001       0
# 4    422.739990  422.739990       0
# ..          ...         ...     ...
# 713  430.399994  430.399994       0
# 714  428.899994  428.899994       0
# 715  429.529999  429.529999       0
# 716  429.380005  429.380005       0
# 717  429.220001  429.220001       0
#
# [718 rows x 8 columns]

# %% [markdown]
# ## Tourism Index

# %%
# Tourism Index 15m
stock_symbol = '^TOURISM.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
TOURISM_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TOURISM_df = pd.concat([TOURISM_df, data])

# Reset the index to get Date as a column
TOURISM_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TOURISM_df)

# # Save the DataFrame to a CSV file
# TOURISM_df.to_csv('data_TOURISM.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-13 10:00:00  545.969971  546.000000  538.299988
# 1        15m 2023-11-13 10:15:00  541.859985  543.719971  538.979980
# 2        15m 2023-11-13 10:30:00  540.489990  544.309998  540.349976
# 3        15m 2023-11-13 10:45:00  540.780029  544.010010  539.659973
# 4        15m 2023-11-13 11:00:00  542.330017  542.869995  537.099976
# ..       ...                 ...         ...         ...         ...
# 708      15m 2024-01-08 15:15:00  561.289978  565.000000  561.039978
# 709      15m 2024-01-08 15:30:00  564.359985  565.479980  561.659973
# 710      15m 2024-01-08 15:45:00  565.479980  565.479980  561.710022
# 711      15m 2024-01-08 16:00:00  561.989990  565.489990  561.559998
# 712      15m 2024-01-08 16:15:00  564.849976  565.489990  562.260010
#
#           Close   Adj Close  Volume
# 0    541.859985  541.859985       0
# 1    543.080017  543.080017       0
# 2    540.780029  540.780029       0
# 3    539.659973  539.659973       0
# 4    540.419983  540.419983       0
# ..          ...         ...     ...
# 708  565.000000  565.000000       0
# 709  565.479980  565.479980       0
# 710  561.989990  561.989990       0
# 711  564.419983  564.419983       0
# 712  564.929993  564.929993       0
#
# [713 rows x 8 columns]

# %% [markdown]
# ## Resource Index

# %%
# Resource Index 15m
stock_symbol = '^RESOURC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
RESOURCE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    RESOURCE_df = pd.concat([TOURISM_df, data])

# Reset the index to get Date as a column
TOURISM_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(RESOURCE_df)

# # Save the DataFrame to a CSV file
# RESOURCE_df.to_csv('data_RESOURC.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                            Interval                Date        Open  \
# 0                               15m 2023-11-13 10:00:00  545.969971
# 1                               15m 2023-11-13 10:15:00  541.859985
# 2                               15m 2023-11-13 10:30:00  540.489990
# 3                               15m 2023-11-13 10:45:00  540.780029
# 4                               15m 2023-11-13 11:00:00  542.330017
# ...                             ...                 ...         ...
# (15m, 2024-01-08 15:15:00)      NaN                 NaT  180.460007
# (15m, 2024-01-08 15:30:00)      NaN                 NaT  180.690002
# (15m, 2024-01-08 15:45:00)      NaN                 NaT  181.009995
# (15m, 2024-01-08 16:00:00)      NaN                 NaT  180.949997
# (15m, 2024-01-08 16:15:00)      NaN                 NaT  180.850006
#
#                                   High         Low       Close   Adj Close  \
# 0                           546.000000  538.299988  541.859985  541.859985
# 1                           543.719971  538.979980  543.080017  543.080017
# 2                           544.309998  540.349976  540.780029  540.780029
# 3                           544.010010  539.659973  539.659973  539.659973
# 4                           542.869995  537.099976  540.419983  540.419983
# ...                                ...         ...         ...         ...
# (15m, 2024-01-08 15:15:00)  181.259995  180.440002  181.059998  181.059998
# (15m, 2024-01-08 15:30:00)  181.089996  180.520004  181.039993  181.039993
# (15m, 2024-01-08 15:45:00)  181.059998  180.410004  180.589996  180.589996
# (15m, 2024-01-08 16:00:00)  181.100006  180.460007  180.460007  180.460007
# (15m, 2024-01-08 16:15:00)  181.289993  180.440002  181.119995  181.119995
#
#                             Volume
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# (15m, 2024-01-08 15:15:00)       0
# (15m, 2024-01-08 15:30:00)       0
# (15m, 2024-01-08 15:45:00)       0
# (15m, 2024-01-08 16:00:00)       0
# (15m, 2024-01-08 16:15:00)       0
#
# [1431 rows x 8 columns]

# %% [markdown]
# ## Energy Index

# %%
# Energy Index 15m
stock_symbol = '^ENERG.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
ENERGY_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ENERGY_df = pd.concat([ENERGY_df, data])

# Reset the index to get Date as a column
ENERGY_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ENERGY_df)

# # Save the DataFrame to a CSV file
# ENERGY_df.to_csv('data_ENERG.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date          Open          High           Low  \
# 0        15m 2023-11-13 10:00:00  20124.869141  20145.689453  20048.380859
# 1        15m 2023-11-13 10:15:00  20097.279297  20175.150391  20078.169922
# 2        15m 2023-11-13 10:30:00  20067.949219  20117.109375  20044.960938
# 3        15m 2023-11-13 10:45:00  20051.439453  20148.869141  20051.439453
# 4        15m 2023-11-13 11:00:00  20115.529297  20134.519531  20041.929688
# ..       ...                 ...           ...           ...           ...
# 713      15m 2024-01-08 15:15:00  20582.929688  20675.000000  20580.939453
# 714      15m 2024-01-08 15:30:00  20609.710938  20655.169922  20589.859375
# 715      15m 2024-01-08 15:45:00  20646.460938  20651.699219  20578.050781
# 716      15m 2024-01-08 16:00:00  20639.250000  20655.970703  20583.580078
# 717      15m 2024-01-08 16:15:00  20627.279297  20677.699219  20581.529297
#
#             Close     Adj Close  Volume
# 0    20090.550781  20090.550781       0
# 1    20084.919922  20084.919922       0
# 2    20052.599609  20052.599609       0
# 3    20082.160156  20082.160156       0
# 4    20085.169922  20085.169922       0
# ..            ...           ...     ...
# 713  20652.240234  20652.240234       0
# 714  20649.669922  20649.669922       0
# 715  20598.630859  20598.630859       0
# 716  20583.580078  20583.580078       0
# 717  20658.339844  20658.339844       0
#
# [718 rows x 8 columns]

# %% [markdown]
# ## BRENT

# %%
# BRENT 15m
stock_symbol = 'BZ=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
BRENT_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    BRENT_df = pd.concat([BRENT_df, data])

# Reset the index to get Date as a column
BRENT_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(BRENT_df)

# # Save the DataFrame to a CSV file
# BRENT_df.to_csv('data_BRENT.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-12 18:00:00  81.449997  81.449997  81.110001  81.349998
# 1         15m 2023-11-12 18:15:00  81.300003  81.300003  81.290001  81.290001
# 2         15m 2023-11-12 18:30:00  81.230003  81.230003  81.199997  81.199997
# 3         15m 2023-11-12 18:45:00  81.300003  81.300003  81.190002  81.190002
# 4         15m 2023-11-12 19:00:00  81.180000  81.180000  81.160004  81.160004
# ...       ...                 ...        ...        ...        ...        ...
# 3071      15m 2024-01-08 22:45:00  76.330002  76.349998  76.330002  76.349998
# 3072      15m 2024-01-08 23:00:00  76.290001  76.300003  76.260002  76.260002
# 3073      15m 2024-01-08 23:15:00  76.279999  76.279999  76.230003  76.239998
# 3074      15m 2024-01-08 23:30:00  76.239998  76.290001  76.239998  76.290001
# 3075      15m 2024-01-08 23:45:00  76.290001  76.290001  76.290001  76.290001
#
#       Adj Close  Volume
# 0     81.349998      45
# 1     81.290001       9
# 2     81.199997       5
# 3     81.190002      15
# 4     81.160004       9
# ...         ...     ...
# 3071  76.349998      13
# 3072  76.260002      11
# 3073  76.239998      29
# 3074  76.290001       9
# 3075  76.290001       1
#
# [3076 rows x 8 columns]

# %% [markdown]
# ## Crude

# %%
# Crude 15m
stock_symbol = 'CL=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
CRUDE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    CRUDE_df = pd.concat([CRUDE_df, data])

# Reset the index to get Date as a column
CRUDE_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(CRUDE_df)

# # Save the DataFrame to a CSV file
# CRUDE_df.to_csv('data_CRUDE.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-12 18:00:00  77.150002  77.279999  76.830002  77.050003
# 1         15m 2023-11-12 18:15:00  77.050003  77.070000  77.000000  77.040001
# 2         15m 2023-11-12 18:30:00  77.029999  77.029999  76.900002  77.029999
# 3         15m 2023-11-12 18:45:00  77.019997  77.040001  76.879997  76.919998
# 4         15m 2023-11-12 19:00:00  76.919998  76.919998  76.839996  76.860001
# ...       ...                 ...        ...        ...        ...        ...
# 3396      15m 2024-01-08 22:45:00  70.879997  70.919998  70.839996  70.900002
# 3397      15m 2024-01-08 23:00:00  70.900002  70.900002  70.800003  70.809998
# 3398      15m 2024-01-08 23:15:00  70.809998  70.820000  70.769997  70.790001
# 3399      15m 2024-01-08 23:30:00  70.790001  70.839996  70.779999  70.830002
# 3400      15m 2024-01-08 23:45:00  70.839996  70.849998  70.820000  70.820000
#
#       Adj Close  Volume
# 0     77.050003    1245
# 1     77.040001     313
# 2     77.029999     385
# 3     76.919998     341
# 4     76.860001     406
# ...         ...     ...
# 3396  70.900002     331
# 3397  70.809998     327
# 3398  70.790001     271
# 3399  70.830002     114
# 3400  70.820000     104
#
# [3401 rows x 8 columns]

# %% [markdown]
# # Read Files

# %% [markdown]
# ## For Colab

# %%
# Main Stock
## TISCO
TISCO_15m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_15m.csv')
TISCO_5m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_5m.csv')
TISCO_2m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_2m.csv')
TISCO_1m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_1m.csv')

## ERW
ERW_15m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_ERW_15m.csv')
ERW_5m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_ERW_5m.csv')
ERW_2m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_ERW_2m.csv')
ERW_1m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_ERW_1m.csv')

## SPRC
SPRC_15m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SPRC_15m.csv')
SPRC_5m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SPRC_5m.csv')
SPRC_2m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SPRC_2m.csv')
SPRC_1m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SPRC_1m.csv')

# Features
BANKING = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_BANKING.csv')
BRENT = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_BRENT.csv')
CNY = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_CNY.csv')
CRUDE = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_CRUDE.csv')
ENERGY = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_ENERG.csv')
FINCIAL = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_FINCIAL.csv')
GOLD = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_GOLD.csv')
RESOURCE = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_RESOURC.csv')
SERVICE = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SERVICE.csv')
SET50 = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SET50.csv')
SET100 = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_SET100.csv')
TOURISM = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TOURISM.csv')
USD = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_USD.csv')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1458, in HTTPSConnection.connect(self)
#    1456     server_hostname = self.host
# -> 1458 self.sock = self._context.wrap_socket(self.sock,
#    1459                                       server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[226], line 3
#       1 # Main Stock
#       2 ## TISCO
# ----> 3 TISCO_15m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_15m.csv')
#       4 TISCO_5m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_5m.csv')
#       5 TISCO_2m = pd.read_csv('https://raw.githubusercontent.com/y-lims/DADS6003_Buy-Sell_Stock_Forecasting/main/training_datasource/data_TISCO_2m.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)>

# %% [markdown]
# ## For Local Workspace

# %%
# # Main Stock
# ## TISCO
# TISCO_15m = pd.read_csv('training_datasource/data_TISCO_15m.csv')
# TISCO_5m = pd.read_csv('training_datasource/data_TISCO_5m.csv')
# TISCO_2m = pd.read_csv('training_datasource/data_TISCO_2m.csv')
# TISCO_1m = pd.read_csv('training_datasource/data_TISCO_1m.csv')

# ## ERW
# ERW_15m = pd.read_csv('training_datasource/data_ERW_15m.csv')
# ERW_5m = pd.read_csv('training_datasource/data_ERW_5m.csv')
# ERW_2m = pd.read_csv('training_datasource/data_ERW_2m.csv')
# ERW_1m = pd.read_csv('training_datasource/data_ERW_1m.csv')

# ## SPRC
# SPRC_15m = pd.read_csv('training_datasource/data_SPRC_15m.csv')
# SPRC_5m = pd.read_csv('training_datasource/data_SPRC_5m.csv')
# SPRC_2m = pd.read_csv('training_datasource/data_SPRC_2m.csv')
# SPRC_1m = pd.read_csv('training_datasource/data_SPRC_1m.csv')

# # Features
# BANKING = pd.read_csv('training_datasource/data_BANKING.csv')
# BRENT = pd.read_csv('training_datasource/data_BRENT.csv')
# CNY = pd.read_csv('training_datasource/data_CNY.csv')
# CRUDE = pd.read_csv('training_datasource/data_CRUDE.csv')
# ENERGY = pd.read_csv('training_datasource/data_ENERG.csv')
# FINCIAL = pd.read_csv('training_datasource/data_FINCIAL.csv')
# GOLD = pd.read_csv('training_datasource/data_GOLD.csv')
# RESOURCE = pd.read_csv('training_datasource/data_RESOURC.csv')
# SERVICE = pd.read_csv('training_datasource/data_SERVICE.csv')
# SET50 = pd.read_csv('training_datasource/data_SET50.csv')
# SET100 = pd.read_csv('training_datasource/data_SET100.csv')
# TOURISM = pd.read_csv('training_datasource/data_TOURISM.csv')
# USD = pd.read_csv('training_datasource/data_USD.csv')

# %% [markdown]
# # Define Variables

# %%
## Add Diff Columns
#### Adjust data
TISCO_15m['Diff'] = TISCO_15m['Close'].shift(-1)
TISCO_15m['Diff'] = TISCO_15m['Diff'].fillna(TISCO_15m['Close'] - TISCO_15m['Open'])

ERW_15m['Diff'] = ERW_15m['Close'].shift(-1)
ERW_15m['Diff'] = ERW_15m['Diff'].fillna(ERW_15m['Close'] - ERW_15m['Open'])

SPRC_15m['Diff'] = SPRC_15m['Close'].shift(-1)
SPRC_15m['Diff'] = SPRC_15m['Diff'].fillna(SPRC_15m['Close'] - SPRC_15m['Open'])

# %%
## Set Signal Condition
TISCO_15m['Signal'] = np.where(TISCO_15m['Diff'] > TISCO_15m['Close'], 2,
                      np.where(TISCO_15m['Diff'] < TISCO_15m['Close'], 1, 0))
ERW_15m['Signal'] = np.where(ERW_15m['Diff'] > ERW_15m['Close'], 2,
                    np.where(ERW_15m['Diff'] < ERW_15m['Close'], 1, 0))
SPRC_15m['Signal'] = np.where(SPRC_15m['Diff'] > SPRC_15m['Close'], 2,
                     np.where(SPRC_15m['Diff'] < SPRC_15m['Close'], 1, 0))

# %%
# Set Variables
# Set Y
tisco15_signal = TISCO_15m['Signal']
erw15_signal = ERW_15m['Signal']
sprc15_signal = SPRC_15m['Signal']

# Reference date
ref_date = TISCO_15m['Date']

# Features (X)
tisco15_close = TISCO_15m['Close']
erw15_close = ERW_15m['Close']
sprc15_close = SPRC_15m['Close']
tisco15_vol = TISCO_15m['Volume']
erw15_vol = ERW_15m['Volume']
sprc15_vol = SPRC_15m['Volume']
usd = USD['Close']
cny = CNY['Close']
set100 = SET100['Close']
set50 = SET50['Close']
gold = GOLD['Close']
fin = FINCIAL['Close']
bank = BANKING['Close']
service = SERVICE['Close']
tour = TOURISM['Close']
resource = RESOURCE['Close']
energy = ENERGY['Close']
brent = BRENT['Close']
crude = CRUDE['Close']

# %% [markdown]
# # Data Exploration

# %%
# Assuming all your data frames have the same index (timestamps)
keys = ['ref_date', 'tisco15_close', 'erw15_close', 'sprc15_close',
        'tisco15_vol', 'erw15_vol', 'sprc15_vol',
        'usd', 'cny', 'set100', 'set50',
        'gold', 'fin', 'bank', 'service', 'tour',
        'resource', 'energy', 'brent', 'crude']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data = pd.concat([ref_date, tisco15_close, erw15_close, sprc15_close,
                        tisco15_vol, erw15_vol, sprc15_vol,
                        usd, cny, set100, set50,
                        gold, fin, bank, service, tour,
                        resource, energy, brent, crude], axis=1, keys=keys).reindex(reference_index)

# %%
#Check Null values
nan_count = merged_data.isna().sum()
print("NaN (n) = 722:")
print(nan_count, '\n')
# Out:
# NaN (n) = 722:
# ref_date           0
# tisco15_close      0
# erw15_close        0
# sprc15_close       2
# tisco15_vol        0
# erw15_vol          0
# sprc15_vol         2
# usd                0
# cny                0
# set100           291
# set50              0
# gold               0
# fin                0
# bank               0
# service            0
# tour               0
# resource           0
# energy             0
# brent              0
# crude              0
# dtype: int64

# %% [markdown]
# ## Check Normality & Outliers

# %%
column_names_list = list(merged_data.columns)
print(column_names_list)
# Out:
# ['ref_date', 'tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy', 'brent', 'crude']

# %%
## Check Skewness
columns = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

fig, axs = plt.subplots(9, 2, figsize=(12, 18))

# Flatten the 2D array of axes to simplify indexing
axs = axs.flatten()

for i, column in enumerate(columns):
    axs[i].hist(merged_data[column], bins=20, color='skyblue', edgecolor='black')
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('Frequency')
    axs[i].set_title(f'Histogram of {column}')

    mean_val = merged_data[column].mean()
    median_val = merged_data[column].median()

    axs[i].axvline(mean_val, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_val:.2f}')
    axs[i].axvline(median_val, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_val:.2f}')
    axs[i].legend()

# Hide any unused subplots
for i in range(len(columns), len(axs)):
    axs[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# Check Outliers
fig, axs = plt.subplots(5, 4, figsize=(15, 15))

columns_to_test = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

color = 'pink'

for i, column in enumerate(columns_to_test):
    plt.subplot(5, 4, i + 1)
    sns.boxplot(x=merged_data[column], color=color)
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cleansing Data

# %%
columns_to_fillna = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_data[column].median()
    merged_data[column].fillna(median_value, inplace=True)

# %%
columns_to_test = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

for column_name in columns_to_test:
    df_tmp = merged_data[[column_name]].dropna()

    print(f'{column_name} : ', end='')

    # Perform Anderson-Darling test for normality
    statistic, critical_values, significance_levels = stats.anderson(df_tmp[column_name], dist='norm')
    print(f'Statistic: {statistic:.3f}, Critical Values: {critical_values}, Significance Levels: {significance_levels}')

    # Check normality based on the 5% significance level
    if statistic >= critical_values[2]:
        print('Not normal')
    else:
        print('Normal')

    print('==========================================')
# Out:
# tisco15_close : Statistic: 15.344, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# erw15_close : Statistic: 9.102, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# sprc15_close : Statistic: 7.076, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# tisco15_vol : Statistic: 63.345, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# erw15_vol : Statistic: 66.004, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# sprc15_vol : Statistic: 52.626, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# usd : Statistic: 15.142, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# cny : Statistic: 36.928, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# set100 : Statistic: 26.966, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# set50 : Statistic: 7.068, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# gold : Statistic: 7.808, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# fin : Statistic: 4.045, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# bank : Statistic: 10.607, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# service : Statistic: 12.227, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# tour : Statistic: 15.294, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# resource : Statistic: 15.294, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# energy : Statistic: 4.076, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## TISCO

# %% [markdown]
# ### TISCO Data Preparation

# %%
# Assuming all your data frames have the same index (timestamps)
## Model with Other Features
keys = ['ref_date','tisco15_close', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'brent', 'crude','tisco15_signal']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data_tisco = pd.concat([ref_date,tisco15_close, usd, cny, set100, set50, gold, fin, bank, brent, crude,tisco15_signal], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['tisco15_close', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'brent', 'crude']

for column in columns_to_fillna:
    median_value = merged_data_tisco[column].median()
    merged_data_tisco[column].fillna(median_value, inplace=True)

# %% [markdown]
# ### TISCO Technical Features

# %%
# Features
tisco2_close = TISCO_2m_df['Close']
tisco5_close = TISCO_5m_df['Close']

keys = ['ref_date','tisco2_close', 'tisco5_close', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'brent', 'crude']

reference_index = ref_date.index

merged_tisco_new = pd.concat([ref_date, tisco2_close, tisco5_close, usd, cny, set100, set50, gold, fin, bank, brent, crude], axis=1, keys=keys).reindex(reference_index)
merged_tisco_new
# Out:
#                 ref_date  tisco2_close  tisco5_close        usd     cny  \
# 0    2023-11-09 10:00:00          97.5         96.75  35.519001  7.2774
# 1    2023-11-09 10:15:00          97.5         96.50  35.521999  7.2791
# 2    2023-11-09 10:30:00          97.5         96.50  35.527000  7.2805
# 3    2023-11-09 10:45:00          97.5         96.50  35.509998  7.2805
# 4    2023-11-09 11:00:00          97.5         96.75  35.520000  7.2807
# ..                   ...           ...           ...        ...     ...
# 698  2024-01-05 15:15:00          98.5         98.75  35.151001  7.1533
# 699  2024-01-05 15:30:00          98.5         98.75  35.164001  7.1535
# 700  2024-01-05 15:45:00          98.5         98.75  35.172001  7.1535
# 701  2024-01-05 16:00:00          98.5         98.75  35.166000  7.1535
# 702  2024-01-05 16:15:00          98.5         98.50  35.164001  7.1524
#
#      set100  set50         gold         fin        bank      brent      crude
# 0      9.17   8.53  1954.199951  140.220001  377.010010  79.660004  75.459999
# 1      9.11   8.53  1953.400024  140.020004  377.049988  79.669998  75.419998
# 2      9.10   8.50  1954.300049  139.869995  377.559998  79.580002  75.459999
# 3      9.10   8.50  1955.099976  139.899994  377.779999  79.709999  75.489998
# 4      9.10   8.49  1954.900024  139.759995  377.209991  79.769997  75.529999
# ..      ...    ...          ...         ...         ...        ...        ...
# 698     NaN   8.62  1980.199951  140.860001  380.179993  82.110001  77.570000
# 699     NaN   8.62  1979.900024  140.580002  380.859985  82.120003  77.470001
# 700     NaN   8.62  1978.500000  140.100006  380.179993  82.120003  77.419998
# 701     NaN   8.61  1980.099976  140.240005  380.429993  82.139999  77.470001
# 702     NaN   8.61  1981.099976  140.220001  380.079987  82.010002  77.279999
#
# [703 rows x 12 columns]

# %% [markdown]
# #### 15m

# %% [markdown]
# ##### EMA

# %%
# TISCO EMA 15m
# Calculate Exponential Moving Averages (EMA) with a window of 15 periods (15 minutes in this case)
merged_data_tisco['ema_15m'] = talib.EMA(merged_data_tisco['tisco15_close'], timeperiod=15)

# Create Label (target variable)
merged_data_tisco['target_ema_15m'] = np.where(merged_data_tisco['tisco15_close'].shift(-1) > merged_data_tisco['tisco15_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_data_tisco['ema_15m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_data_tisco['target_ema_15m'].fillna(method='ffill', inplace=True)

print(merged_data_tisco[['ema_15m']])

# Verify the shapes of features and target
print("Shape of features:", merged_data_tisco[['ema_15m']].shape)
print("Shape of target:", merged_data_tisco['target_ema_15m'].shape)

# Plotting
plt.figure(figsize=(14, 8))
plt.plot(merged_data_tisco.index, merged_data_tisco['tisco15_close'], label='TISCO 15 Close')
plt.plot(merged_data_tisco.index, merged_data_tisco['ema_15m'], label='EMA (15 periods)')
plt.title('TISCO 15 Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_data_tisco['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_data_tisco.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.show()
# Out:
#         ema_15m
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 698  100.285405
# 699  100.312229
# 700  100.335700
# 701  100.356238
# 702  100.374208
#
# [703 rows x 1 columns]
# Shape of features: (703, 1)
# Shape of target: (703,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-199-136bfd1d4313> in <cell line: 30>()
#      28
#      29 selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
# ---> 30 selected_dates = merged_data_tisco['ref_date'].iloc[selected_rows].dt.date
#      31
#      32 plt.xticks(merged_data_tisco.index[selected_rows], selected_dates, rotation=45, ha='right')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     510             return PeriodProperties(data, orig)
#     511
# --> 512         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# ##### MACD

# %%
# TISCO MACD_15m
# Calculate MACD with forward-fill to handle NaN values
merged_data_tisco['macd_15m'], merged_data_tisco['signal_macd_15m'], _ = talib.MACD(merged_data_tisco['tisco15_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_data_tisco[['macd_15m', 'signal_macd_15m']] = merged_data_tisco[['macd_15m', 'signal_macd_15m']
].fillna(method='ffill')

# Create Label (target variable)
merged_data_tisco['target_macd_15m'] = np.where(
    merged_data_tisco['tisco15_close'].shift(-1) > merged_data_tisco['tisco15_close'], 1, 0
)

# Replace missing values in 'target' with forward fill (if any)
merged_data_tisco['target_macd_15m'].fillna(method='ffill', inplace=True)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

ax1.plot(merged_data_tisco['ref_date'], merged_data_tisco['macd_15m'], label='MACD (12,26,9)', color='green')
ax1.plot(merged_data_tisco['ref_date'], merged_data_tisco['signal_macd_15m'], label='Signal Line (MACD)', color='red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='black')
ax1.tick_params(axis='y', colors='black')

# Creating a secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.bar(merged_data_tisco['ref_date'], merged_data_tisco['tisco15_vol'], alpha=0.3, color='purple', label='Volume')
ax2.set_ylabel('Volume', color='purple')
ax2.tick_params(axis='y', colors='purple')

# Tilt the y-axis labels
ax1.tick_params(axis='x', labelrotation=45)

# Displaying legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('TISCO 15 Close, MACD, Signal Line, and Volume')
plt.show()

# %% [markdown]
# ##### RSI

# %%
# TISCO RSI
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_data_tisco['rsi_15'] = talib.RSI(merged_data_tisco['tisco15_close'], timeperiod=15)

# Create Label (target variable)
merged_data_tisco['target_rsi_15'] = np.where(merged_data_tisco['tisco15_close'].shift(-1) > merged_data_tisco['tisco15_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_data_tisco['rsi_15'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_data_tisco['target_rsi_15'].fillna(method='ffill', inplace=True)

print(merged_data_tisco[['rsi_15']])

# Verify the shapes of features and target
print("Shape of features:", merged_data_tisco[['rsi_15']].shape)
print("Shape of target:", merged_data_tisco['target_rsi_15'].shape)

# Plotting the RSI only with horizontal lines at levels 30 and 70
plt.figure(figsize=(14, 8))
plt.plot(merged_data_tisco.index, merged_data_tisco['rsi_15'], color='orange', label='RSI')
plt.axhline(y=30, color='blue', linestyle='--', label='RSI 30')
plt.axhline(y=70, color='blue', linestyle='--', label='RSI 70')

plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_data_tisco['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_data_tisco.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2m

# %% [markdown]
# ##### EMA

# %%
# TISCO EMA 2m
# Calculate EMA with a window of period (minute)
merged_tisco_new['ema_2m'] = talib.EMA(merged_tisco_new['tisco2_close'], timeperiod=2)

# Create Label (target variable)
merged_tisco_new['target_ema_2m'] = np.where(merged_tisco_new['tisco2_close'].shift(-1) > merged_tisco_new['tisco2_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_tisco_new['ema_2m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_tisco_new['target_ema_2m'].fillna(method='ffill', inplace=True)

print(merged_tisco_new[['ema_2m']])

# Plotting the EMA_2m
plt.figure(figsize=(14, 8))
plt.plot(merged_tisco_new.index, merged_tisco_new['tisco2_close'], label='TISCO 2 Close')
plt.plot(merged_tisco_new.index, merged_tisco_new[['ema_2m']], label='EMA (2 periods)')

plt.title('TISCO Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_tisco_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_tisco_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.show()

# %% [markdown]
# ##### MACD

# %%
# TISCO MACD 2m
# Calculate MACD with forward-fill to handle NaN values
merged_tisco_new['macd_2m'], merged_tisco_new['signal_macd_2m'], _ = talib.MACD(merged_tisco_new['tisco2_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_tisco_new[['macd_2m', 'signal_macd_2m']] = merged_tisco_new[['macd_2m', 'signal_macd_2m']].fillna(method='ffill')

# Create Label (target variable)
merged_tisco_new['target_macd_2m'] = np.where(merged_tisco_new['tisco2_close'].shift(-1) > merged_tisco_new['tisco2_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_tisco_new['target_macd_2m'].fillna(method='ffill', inplace=True)

print(merged_tisco_new[['macd_2m', 'signal_macd_2m']])

# Verify the shapes of features and target
print("Shape of features:", merged_tisco_new[['macd_2m', 'signal_macd_2m']].shape)
print("Shape of target:", merged_tisco_new['target_macd_2m'].shape)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

ax1.plot(merged_tisco_new['ref_date'], merged_tisco_new['macd_2m'], label='MACD (12,26,9)', color='green')
ax1.plot(merged_tisco_new['ref_date'], merged_tisco_new['signal_macd_2m'], label='Signal Line (MACD)', color='red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='black')
ax1.tick_params(axis='y', colors='black')

# Creating a secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.bar(merged_tisco_new['ref_date'], merged_tisco_new['tisco2_vol'], alpha=0.3, color='purple', label='Volume')
ax2.set_ylabel('Volume', color='purple')
ax2.tick_params(axis='y', colors='purple')

# Tilt the y-axis labels
ax1.tick_params(axis='x', labelrotation=45)

# Displaying legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('TISCO 2 Close, MACD, Signal Line, and Volume')
plt.show()

# %% [markdown]
# ##### RSI

# %%
# TISCO RSI 2m
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_tisco_new['rsi_2'] = talib.RSI(merged_tisco_new['tisco2_close'], timeperiod=2)

# Create Label (target variable)
merged_tisco_new['target_rsi_2'] = np.where(merged_tisco_new['tisco2_close'].shift(-1) > merged_tisco_new['tisco2_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_tisco_new['rsi_2'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_tisco_new['target_rsi_2'].fillna(method='ffill', inplace=True)

print(merged_tisco_new[['rsi_2']])

# Verify the shapes of features and target
print("Shape of features:", merged_tisco_new[['rsi_2']].shape)
print("Shape of target:", merged_tisco_new['target_rsi_2'].shape)

# Plotting the RSI only with horizontal lines at levels 30 and 70
plt.figure(figsize=(14, 8))
plt.plot(merged_tisco_new.index, merged_tisco_new['rsi_2'], color='orange', label='RSI')
plt.axhline(y=30, color='blue', linestyle='--')
plt.axhline(y=70, color='blue', linestyle='--')

plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend(loc='upper right')

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_tisco_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_tisco_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5m

# %% [markdown]
# ##### EMA

# %%
# TISCO EMA 5m
# Calculate EMA with a window of period ( minute)
merged_tisco_new['ema_5m'] = talib.EMA(merged_tisco_new['tisco5_close'], timeperiod=5)

# Create Label (target variable)
merged_tisco_new['target_ema_5m'] = np.where(merged_tisco_new['tisco5_close'].shift(-1) > merged_tisco_new['tisco5_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_tisco_new['ema_5m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_tisco_new['target_ema_5m'].fillna(method='ffill', inplace=True)

print(merged_tisco_new[['ema_5m']])

# Plotting the EMA_5m
plt.figure(figsize=(14, 8))
plt.plot(merged_tisco_new.index, merged_tisco_new['tisco5_close'], label='TISCO 5 Close')
plt.plot(merged_tisco_new.index, merged_tisco_new[['ema_5m']], label='EMA (5 periods)')

plt.title('TISCO Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_tisco_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_tisco_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.show()

# %% [markdown]
# ##### MACD

# %%
# TISCO MACD 5m
# Calculate MACD with forward-fill to handle NaN values
merged_tisco_new['macd_5m'], merged_tisco_new['signal_macd_5m'], _ = talib.MACD(merged_tisco_new['tisco5_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_tisco_new[['macd_5m', 'signal_macd_5m']] = merged_tisco_new[['macd_5m', 'signal_macd_5m']].fillna(method='ffill')

# Create Label (target variable)
merged_tisco_new['target_macd_5m'] = np.where(merged_tisco_new['tisco5_close'].shift(-1) > merged_tisco_new['tisco5_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_tisco_new['target_macd_5m'].fillna(method='ffill', inplace=True)

print(merged_tisco_new[['macd_5m', 'signal_macd_5m']])

# Verify the shapes of features and target
print("Shape of features:", merged_tisco_new[['macd_5m', 'signal_macd_5m']].shape)
print("Shape of target:", merged_tisco_new['target_macd_5m'].shape)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

ax1.plot(merged_tisco_new['ref_date'], merged_tisco_new['macd_5m'], label='MACD (12,26,9)', color='green')
ax1.plot(merged_tisco_new['ref_date'], merged_tisco_new['signal_macd_5m'], label='Signal Line (MACD)', color='red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='black')
ax1.tick_params(axis='y', colors='black')

# Creating a secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.bar(merged_tisco_new['ref_date'], merged_tisco_new['tisco5_vol'], alpha=0.3, color='purple', label='Volume')
ax2.set_ylabel('Volume', color='purple')
ax2.tick_params(axis='y', colors='purple')

# Tilt the y-axis labels
ax1.tick_params(axis='x', labelrotation=45)

# Displaying legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('TISCO 5 Close, MACD, Signal Line, and Volume')
plt.show()

# %% [markdown]
# ##### RSI

# %%
# TISCO RSI 5m
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_tisco_new['rsi_5'] = talib.RSI(merged_tisco_new['tisco5_close'], timeperiod=5)

# Create Label (target variable)
merged_tisco_new['target_rsi_5'] = np.where(merged_tisco_new['tisco5_close'].shift(-1) > merged_tisco_new['tisco5_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_tisco_new['rsi_5'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_tisco_new['target_rsi_5'].fillna(method='ffill', inplace=True)

print(merged_tisco_new[['rsi_5']])

# Verify the shapes of features and target
print("Shape of features:", merged_tisco_new[['rsi_5']].shape)
print("Shape of target:", merged_tisco_new['target_rsi_5'].shape)

# Plotting the RSI only with horizontal lines at levels 30 and 70
plt.figure(figsize=(14, 8))
plt.plot(merged_tisco_new.index, merged_tisco_new['rsi_5'], color='orange', label='RSI')
plt.axhline(y=30, color='blue', linestyle='--')
plt.axhline(y=70, color='blue', linestyle='--')

plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend(loc='upper right')

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_tisco_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_tisco_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fill Null Values

# %%
columns_to_fillna = ['tisco15_close', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'brent', 'crude','ema_15m','macd_15m','rsi_15']

for column in columns_to_fillna:
    median_value = merged_data_tisco[column].median()
    merged_data_tisco[column].fillna(median_value, inplace=True)

# %% [markdown]
# ### Correlations

# %%
correlations = merged_data_tisco.corr()['tisco15_close']

print("Correlation with tisco15_close:")
print(correlations)

print("\nInterpretation:")
for variable, correlation in correlations.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'tisco15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'tisco15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'tisco15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'tisco15_close' and '{variable}' ({correlation:.2f})")

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(merged_data_tisco.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Heat Map of merged_data_TISCO')

plt.show()

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['tisco15_close', 'usd', 'cny', 'set50', 'gold', 'bank','ema_15m','macd_15m','rsi_15']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_tisco[columns_to_normalize] = scaler.fit_transform(merged_data_tisco[columns_to_normalize])

# %%
# Assuming merged_data_TISCO is a DataFrame
filtered_data_tisco = merged_data_tisco[['ref_date', 'tisco15_close', 'usd', 'cny', 'set50', 'gold', 'bank','ema_15m','macd_15m','rsi_15','tisco15_signal']]
filtered_data_tisco

# %% [markdown]
# ## ERW

# %% [markdown]
# ### ERW Data Preparation

# %%
# Assuming all your data frames have the same index (timestamps)
keys = ['ref_date','erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour','erw15_signal']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data_erw = pd.concat([ref_date,erw15_close, erw15_vol, usd, cny, set100, set50, gold, service, tour,erw15_signal], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

for column in columns_to_fillna:
    median_value = merged_data_erw[column].median()
    merged_data_erw[column].fillna(median_value, inplace=True)

# %%
erw2_close = ERW_2m_df['Close']
erw5_close = ERW_5m_df['Close']

keys = ['ref_date', 'erw2_close', 'erw5_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

reference_index = ref_date.index

merged_erw_new = pd.concat([ref_date, erw2_close, erw5_close, erw15_vol, usd, cny, set100, set50, gold, service, tour], axis=1, keys=keys).reindex(reference_index)
merged_erw_new

# %%
columns_to_fillna = ['erw2_close', 'erw5_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

for column in columns_to_fillna:
    median_value = merged_erw_new[column].median()
    merged_erw_new[column].fillna(median_value, inplace=True)

# %% [markdown]
# ### ERW Technical Features

# %% [markdown]
# #### 15m

# %% [markdown]
# ##### EMA

# %%
# ERW EMA 15m
# Calculate Exponential Moving Averages (EMA) with a window of 15 periods (15 minutes in this case)
merged_data_erw['ema_15m'] = talib.EMA(merged_data_erw['erw15_close'], timeperiod=15)

# Create Label (target variable)
merged_data_erw['target_ema_15m'] = np.where(merged_data_erw['erw15_close'].shift(-1) > merged_data_erw['erw15_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_data_erw['ema_15m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_data_erw['target_ema_15m'].fillna(method='ffill', inplace=True)

print(merged_data_erw[['ema_15m']])


# Verify the shapes of features and target
print("Shape of features:", merged_data_erw[['ema_15m']].shape)
print("Shape of target:",merged_data_erw['target_ema_15m'].shape)

# Plotting the EMA_15m
plt.figure(figsize=(14, 8))
plt.plot(merged_data_erw.index, merged_data_erw['erw15_close'], label='ERW 15 Close')
plt.plot(merged_data_erw.index, merged_data_erw['ema_15m'], label='EMA (15 periods)')
plt.title('ERW 15 Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_data_erw['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_data_erw.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.show()

# %% [markdown]
# ##### MACD

# %%
# ERW MACD 15m
# Calculate MACD with forward-fill to handle NaN values
merged_data_erw['macd_15m'], merged_data_erw['signal_macd_15m'], _ = talib.MACD(merged_data_erw['erw15_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_data_erw[['macd_15m', 'signal_macd_15m']] = merged_data_erw[['macd_15m', 'signal_macd_15m']].fillna(method='ffill')

# Create Label (target variable)
merged_data_erw['target_macd_15m'] = np.where(merged_data_erw['erw15_close'].shift(-1) > merged_data_erw['erw15_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_data_erw['target_macd_15m'].fillna(method='ffill', inplace=True)

print(merged_data_erw[['macd_15m', 'signal_macd_15m']])

# Verify the shapes of features and target
print("Shape of features:", merged_data_erw[['macd_15m', 'signal_macd_15m']].shape)
print("Shape of target:", merged_data_erw['target_macd_15m'].shape)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

ax1.plot(merged_data_erw['ref_date'], merged_data_erw['macd_15m'], label='MACD (12,26,9)', color='green')
ax1.plot(merged_data_erw['ref_date'], merged_data_erw['signal_macd_15m'], label='Signal Line (MACD)', color='red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='black')
ax1.tick_params(axis='y', colors='black')

# Creating a secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.bar(merged_data_erw['ref_date'], merged_data_erw['erw15_vol'], alpha=0.3, color='purple', label='Volume')
ax2.set_ylabel('Volume', color='purple')
ax2.tick_params(axis='y', colors='purple')

# Tilt the y-axis labels
ax1.tick_params(axis='x', labelrotation=45)

# Displaying legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('ERW 15 Close, MACD, Signal Line, and Volume')
plt.show()

# %% [markdown]
# ##### RSI

# %%
# ERW RSI 15m
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_data_erw['rsi_15'] = talib.RSI(merged_data_erw['erw15_close'], timeperiod=14)

# Create Label (target variable)
merged_data_erw['target_rsi_15'] = np.where(merged_data_erw['erw15_close'].shift(-1) > merged_data_erw['erw15_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_data_erw['rsi_15'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_data_erw['target_rsi_15'].fillna(method='ffill', inplace=True)

print(merged_data_erw[['rsi_15']])

# Verify the shapes of features and target
print("Shape of features:", merged_data_erw[['rsi_15']].shape)
print("Shape of target:", merged_data_erw['target_rsi_15'].shape)

# Plotting the RSI only with horizontal lines at levels 30 and 70
plt.figure(figsize=(14, 8))
plt.plot(merged_data_erw.index, merged_data_erw['rsi_15'], color='orange', label='RSI')
plt.axhline(y=30, color='blue', linestyle='--')
plt.axhline(y=70, color='blue', linestyle='--')

plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_data_erw['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_data_erw.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2m

# %% [markdown]
# ##### EMA

# %%
# ERW EMA 2m
# Calculate EMA with a window of period (minute)
merged_erw_new['ema_2m'] = talib.EMA(merged_erw_new['erw2_close'], timeperiod=2)

# Create Label (target variable)
merged_erw_new['target_ema_2m'] = np.where(merged_erw_new['erw2_close'].shift(-1) > merged_erw_new['erw2_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_erw_new['ema_2m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_erw_new['target_ema_2m'].fillna(method='ffill', inplace=True)

print(merged_erw_new[['ema_2m']])

# Plotting the EMA_2m
plt.figure(figsize=(14, 8))
plt.plot(merged_erw_new.index, merged_erw_new['erw2_close'], label='ERW 2 Close')
plt.plot(merged_erw_new.index, merged_erw_new[['ema_2m']], label='EMA (2 periods)')

plt.title('ERW Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_erw_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_erw_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.show()

# %% [markdown]
# ##### MACD

# %%
# ERW MACD 2m
# Calculate MACD with forward-fill to handle NaN values
merged_erw_new['macd_2m'], merged_erw_new['signal_macd_2m'], _ = talib.MACD(merged_erw_new['erw2_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_erw_new[['macd_2m', 'signal_macd_2m']] = merged_erw_new[['macd_2m', 'signal_macd_2m']].fillna(method='ffill')

# Create Label (target variable)
merged_erw_new['target_macd_2m'] = np.where(merged_erw_new['erw2_close'].shift(-1) > merged_erw_new['erw2_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_erw_new['target_macd_2m'].fillna(method='ffill', inplace=True)

print(merged_erw_new[['macd_2m', 'signal_macd_2m']])

# Verify the shapes of features and target
print("Shape of features:", merged_erw_new[['macd_2m', 'signal_macd_2m']].shape)
print("Shape of target:", merged_erw_new['target_macd_2m'].shape)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

ax1.plot(merged_erw_new['ref_date'], merged_erw_new['macd_2m'], label='MACD (12,26,9)', color='green')
ax1.plot(merged_erw_new['ref_date'], merged_erw_new['signal_macd_2m'], label='Signal Line (MACD)', color='red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='black')
ax1.tick_params(axis='y', colors='black')

# Creating a secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.bar(merged_erw_new['ref_date'], merged_erw_new['erw2_vol'], alpha=0.3, color='purple', label='Volume')
ax2.set_ylabel('Volume', color='purple')
ax2.tick_params(axis='y', colors='purple')

# Tilt the y-axis labels
ax1.tick_params(axis='x', labelrotation=45)

# Displaying legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('ERW 2 Close, MACD, Signal Line, and Volume')
plt.show()

# %% [markdown]
# ##### RSI

# %%
# ERW RSI 2m
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_erw_new['rsi_2'] = talib.RSI(merged_erw_new['erw2_close'], timeperiod=2)

# Create Label (target variable)
merged_erw_new['target_rsi_2'] = np.where(merged_erw_new['erw2_close'].shift(-1) > merged_erw_new['erw2_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_erw_new['rsi_2'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_erw_new['target_rsi_2'].fillna(method='ffill', inplace=True)

print(merged_erw_new[['rsi_2']])

# Verify the shapes of features and target
print("Shape of features:", merged_erw_new[['rsi_2']].shape)
print("Shape of target:", merged_erw_new['target_rsi_2'].shape)

# Plotting the RSI only with horizontal lines at levels 30 and 70
plt.figure(figsize=(14, 8))
plt.plot(merged_erw_new.index, merged_erw_new['rsi_2'], color='orange', label='RSI')
plt.axhline(y=30, color='blue', linestyle='--')
plt.axhline(y=70, color='blue', linestyle='--')

plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend(loc='upper right')

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_erw_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_erw_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5m

# %% [markdown]
# ##### EMA

# %%
# ERW EMA 5m
# Calculate EMA with a window of period (minute)
merged_erw_new['ema_5m'] = talib.EMA(merged_erw_new['erw5_close'], timeperiod=5)

# Create Label (target variable)
merged_erw_new['target_ema_5m'] = np.where(merged_erw_new['erw5_close'].shift(-1) > merged_erw_new['erw5_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_erw_new['ema_5m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_erw_new['target_ema_5m'].fillna(method='ffill', inplace=True)

print(merged_erw_new[['ema_5m']])

# Plotting the EMA_2m
plt.figure(figsize=(14, 8))
plt.plot(merged_erw_new.index, merged_erw_new['erw5_close'], label='ERW 5 Close')
plt.plot(merged_erw_new.index, merged_erw_new[['ema_5m']], label='EMA (5 periods)')

plt.title('ERW Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_erw_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_erw_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.show()

# %% [markdown]
# ##### MACD

# %%
# ERW MACD 5m
# Calculate MACD with forward-fill to handle NaN values
merged_erw_new['macd_5m'], merged_erw_new['signal_macd_5m'], _ = talib.MACD(merged_erw_new['erw5_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_erw_new[['macd_5m', 'signal_macd_5m']] = merged_erw_new[['macd_5m', 'signal_macd_5m']].fillna(method='ffill')

# Create Label (target variable)
merged_erw_new['target_macd_5m'] = np.where(merged_erw_new['erw5_close'].shift(-1) > merged_erw_new['erw5_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_erw_new['target_macd_5m'].fillna(method='ffill', inplace=True)

print(merged_erw_new[['macd_5m', 'signal_macd_5m']])

# Verify the shapes of features and target
print("Shape of features:", merged_erw_new[['macd_5m', 'signal_macd_5m']].shape)
print("Shape of target:", merged_erw_new['target_macd_5m'].shape)

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

ax1.plot(merged_erw_new['ref_date'], merged_erw_new['macd_5m'], label='MACD (12,26,9)', color='green')
ax1.plot(merged_erw_new['ref_date'], merged_erw_new['signal_macd_5m'], label='Signal Line (MACD)', color='red')
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color='black')
ax1.tick_params(axis='y', colors='black')

# Creating a secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.bar(merged_erw_new['ref_date'], merged_erw_new['erw5_vol'], alpha=0.3, color='purple', label='Volume')
ax2.set_ylabel('Volume', color='purple')
ax2.tick_params(axis='y', colors='purple')

# Tilt the y-axis labels
ax1.tick_params(axis='x', labelrotation=45)

# Displaying legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('ERW 5 Close, MACD, Signal Line, and Volume')
plt.show()

# %% [markdown]
# ##### RSI

# %%
# ERW RSI 5m
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_erw_new['rsi_5'] = talib.RSI(merged_erw_new['erw5_close'], timeperiod=5)

# Create Label (target variable)
merged_erw_new['target_rsi_5'] = np.where(merged_erw_new['erw5_close'].shift(-1) > merged_erw_new['erw5_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_erw_new['rsi_5'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_erw_new['target_rsi_5'].fillna(method='ffill', inplace=True)

print(merged_erw_new[['rsi_5']])

# Verify the shapes of features and target
print("Shape of features:", merged_erw_new[['rsi_5']].shape)
print("Shape of target:", merged_erw_new['target_rsi_5'].shape)

# Plotting the RSI only with horizontal lines at levels 30 and 70
plt.figure(figsize=(14, 8))
plt.plot(merged_erw_new.index, merged_erw_new['rsi_5'], color='orange', label='RSI')
plt.axhline(y=30, color='blue', linestyle='--')
plt.axhline(y=70, color='blue', linestyle='--')

plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.legend(loc='upper right')

selected_rows = [0, 100, 200, 300, 400, 500, 600, 700]
selected_dates = merged_erw_new['ref_date'].iloc[selected_rows].dt.date

plt.xticks(merged_erw_new.index[selected_rows], selected_dates, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fill Null Values

# %%
columns_to_fillna = ['erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour','ema_15m','macd_15m','rsi_15']

for column in columns_to_fillna:
    median_value = merged_data_erw[column].median()
    merged_data_erw[column].fillna(median_value, inplace=True)

# %% [markdown]
# ### Correlations

# %%
correlations = merged_data_erw.corr()['erw15_close']

print("Correlation with erw15_close:")
print(correlations)

print("\nInterpretation:")
for variable, correlation in correlations.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'erw15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'erw15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'erw15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'erw15_close' and '{variable}' ({correlation:.2f})")

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(merged_data_erw.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Heat Map of merged_data_ERW')

plt.show()

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['erw15_close', 'cny', 'set50', 'service', 'tour','ema_15m','macd_15m','rsi_15']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_erw[columns_to_normalize] = scaler.fit_transform(merged_data_erw[columns_to_normalize])

# %%
# Assuming merged_data_SRPC is a DataFrame
filtered_data_erw = merged_data_erw[['ref_date', 'erw15_close', 'cny', 'set50', 'service', 'tour','ema_15m','macd_15m','rsi_15','erw15_signal']]
filtered_data_erw

# %% [markdown]
# ## SPRC

# %% [markdown]
# ### SPRC Data Preparation

# %%
# Assuming all your data frames have the same index (timestamps)
keys = ['ref_date','sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy','sprc15_signal']

# Assuming tisco15_close has Datetime index
reference_index = ref_date.index

# Concatenate and reindex based on the reference index
merged_data_SPRC = pd.concat([ref_date, sprc15_close, sprc15_vol, usd ,cny, set100, set50, gold, resource, energy,sprc15_signal], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_data_SPRC[column].median()
    merged_data_SPRC[column].fillna(median_value, inplace=True)

# %%
sprc2_close = SPRC_2m_df['Close']
sprc5_close = SPRC_5m_df['Close']

keys = ['ref_date', 'sprc2_close', 'sprc5_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

reference_index = ref_date.index


merged_sprc_new = pd.concat([ref_date, sprc2_close, sprc5_close, sprc15_vol, usd ,cny, set100, set50, gold, resource, energy], axis=1, keys=keys).reindex(reference_index)
merged_sprc_new

# %%
columns_to_fillna = ['sprc2_close', 'sprc5_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_sprc_new[column].median()
    merged_sprc_new[column].fillna(median_value, inplace=True)

# %% [markdown]
# ### Technical Features

# %% [markdown]
# #### 15m

# %% [markdown]
# ##### EMA

# %%
# Calculate Exponential Moving Averages (EMA) with a window of 15 periods (15 minutes in this case)
merged_data_SPRC['ema_15m'] = talib.EMA(merged_data_SPRC['sprc15_close'], timeperiod=15)

# Create Label (target variable)
merged_data_SPRC['target_ema_15m'] = np.where(merged_data_SPRC['sprc15_close'].shift(-1) > merged_data_SPRC['sprc15_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_data_SPRC['ema_15m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_data_SPRC['target_ema_15m'].fillna(method='ffill', inplace=True)

print(merged_data_SPRC[['ema_15m']])


# Verify the shapes of features and target
print("Shape of features:",merged_data_SPRC[['ema_15m']].shape)
print("Shape of target:",merged_data_SPRC['target_ema_15m'].shape)

# Plotting the EMA_15m
plt.figure(figsize=(10, 6))
plt.plot(merged_data_SPRC.index, merged_data_SPRC['sprc15_close'], label='SPRC 15 Close')
plt.plot(merged_data_SPRC.index, merged_data_SPRC['ema_15m'], label='SPRC (15 periods)')
plt.title('SPRC 15 Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### MACD

# %%
merged_data_SPRC['macd_15m'], merged_data_SPRC['signal_macd_15m'], _ = talib.MACD(merged_data_SPRC['sprc15_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_data_SPRC[['macd_15m', 'signal_macd_15m']] = merged_data_SPRC[['macd_15m', 'signal_macd_15m']].fillna(method='ffill')

# Create Label (target variable)
merged_data_SPRC['target_macd_15m'] = np.where(merged_data_SPRC['sprc15_close'].shift(-1) > merged_data_SPRC['sprc15_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_data_SPRC['target_macd_15m'].fillna(method='ffill', inplace=True)

print(merged_data_SPRC[['macd_15m', 'signal_macd_15m']])

# Verify the shapes of features and target
print("Shape of features:", merged_data_SPRC[['macd_15m', 'signal_macd_15m']].shape)
print("Shape of target:", merged_data_SPRC['target_macd_15m'].shape)

# Plotting the MACD alongside Tisco15 Close
plt.figure(figsize=(10, 6))
plt.plot(merged_data_SPRC.index, merged_data_SPRC['sprc15_close'], label='SPRC 15 Close')
plt.plot(merged_data_SPRC.index, merged_data_SPRC['macd_15m'], label='MACD (12,26,9)')
plt.plot(merged_data_SPRC.index, merged_data_SPRC['signal_macd_15m'], label='Signal Line (MACD)')
plt.title('SPRC 15 Close, MACD, and Signal Line')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### RSI

# %%
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_data_SPRC['rsi_15'] = talib.RSI(merged_data_SPRC['sprc15_close'], timeperiod=14)

# Create Label (target variable)
merged_data_SPRC['target_rsi_15'] = np.where(merged_data_SPRC['sprc15_close'].shift(-1) > merged_data_SPRC['sprc15_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_data_SPRC['rsi_15'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_data_SPRC['target_rsi_15'].fillna(method='ffill', inplace=True)

print(merged_data_SPRC[['rsi_15']])

# Verify the shapes of features and target
print("Shape of features:", merged_data_SPRC[['rsi_15']].shape)
print("Shape of target:", merged_data_SPRC['target_rsi_15'].shape)

# Plotting the 'tisco15_close' and RSI
plt.figure(figsize=(10, 6))
plt.plot(merged_data_SPRC.index, merged_data_SPRC['sprc15_close'], label='SPRC 15 Close')
plt.title('SPRC 15 Close and Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')

# Create a secondary y-axis for RSI
ax2 = plt.gca().twinx()
ax2.plot(merged_data_SPRC.index, merged_data_SPRC['rsi_15'], color='orange', label='RSI')
ax2.set_ylabel('RSI')
ax2.legend(loc='upper right')

plt.show()

# %% [markdown]
# ##### OBV

# %%
merged_data_SPRC['obv'] = talib.OBV(merged_data_SPRC['sprc15_close'], merged_data_SPRC['sprc15_vol'])

# %% [markdown]
# #### 2m

# %% [markdown]
# ##### EMA

# %%
# Calculate EMA with a window of period (minute)
merged_sprc_new['ema_2m'] = talib.EMA(merged_sprc_new['sprc2_close'], timeperiod=2)

# Create Label (target variable)
merged_sprc_new['target_ema_2m'] = np.where(merged_sprc_new['sprc2_close'].shift(-1) > merged_sprc_new['sprc2_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_sprc_new['ema_2m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_sprc_new['target_ema_2m'].fillna(method='ffill', inplace=True)

print(merged_sprc_new[['ema_2m']])

# Plotting the EMA_2m
plt.figure(figsize=(10, 6))
plt.plot(merged_sprc_new.index, merged_sprc_new['sprc2_close'], label='SPRC 2 Close')
plt.plot(merged_sprc_new.index, merged_sprc_new[['ema_2m']], label='EMA (2 periods)')

plt.title('SPRC Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### MACD

# %%
# MACD_2m
# Calculate MACD with forward-fill to handle NaN values
merged_sprc_new['macd_2m'], merged_sprc_new['signal_macd_2m'], _ = talib.MACD(merged_sprc_new['sprc2_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_sprc_new[['macd_2m', 'signal_macd_2m']] = merged_sprc_new[['macd_2m', 'signal_macd_2m']].fillna(method='ffill')

# Create Label (target variable)
merged_sprc_new['target_macd_2m'] = np.where(merged_sprc_new['sprc2_close'].shift(-1) > merged_sprc_new['sprc2_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_sprc_new['target_macd_2m'].fillna(method='ffill', inplace=True)

print(merged_sprc_new[['macd_2m', 'signal_macd_2m']])

# Verify the shapes of features and target
print("Shape of features:", merged_sprc_new[['macd_2m', 'signal_macd_2m']].shape)
print("Shape of target:", merged_sprc_new['target_macd_2m'].shape)

# Plotting the MACD alongside sprc2 Close
plt.figure(figsize=(10, 6))
plt.plot(merged_sprc_new.index, merged_sprc_new['sprc2_close'], label='SPRC 2 Close')
plt.plot(merged_sprc_new.index, merged_sprc_new['macd_2m'], label='MACD (12,26,9)')
plt.plot(merged_sprc_new.index, merged_sprc_new['signal_macd_2m'], label='Signal Line (MACD)')
plt.title('SPRC 2 Close, MACD, and Signal Line')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### RSI

# %%
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_sprc_new['rsi_2'] = talib.RSI(merged_sprc_new['sprc2_close'], timeperiod=2)

# Create Label (target variable)
merged_sprc_new['target_rsi_2'] = np.where(merged_sprc_new['sprc2_close'].shift(-1) > merged_sprc_new['sprc2_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_sprc_new['rsi_2'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_sprc_new['target_rsi_2'].fillna(method='ffill', inplace=True)

print(merged_sprc_new[['rsi_2']])

# Verify the shapes of features and target
print("Shape of features:", merged_sprc_new[['rsi_2']].shape)
print("Shape of target:", merged_sprc_new['target_rsi_2'].shape)

# Plotting the 'sprc2_close' and RSI
plt.figure(figsize=(10, 6))
plt.plot(merged_sprc_new.index, merged_sprc_new['sprc2_close'], label='SPRC 2 Close')
plt.title('SPRC 2 Close and Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')

# Create a secondary y-axis for RSI
ax2 = plt.gca().twinx()
ax2.plot(merged_sprc_new.index, merged_sprc_new['rsi_2'], color='orange', label='RSI')
ax2.set_ylabel('RSI')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### 5m

# %% [markdown]
# ##### EMA

# %%
# Calculate EMA with a window of period (minute)
merged_sprc_new['ema_5m'] = talib.EMA(merged_sprc_new['sprc5_close'], timeperiod=5)

# Create Label (target variable)
merged_sprc_new['target_ema_5m'] = np.where(merged_sprc_new['sprc5_close'].shift(-1) > merged_sprc_new['sprc5_close'], 1, 0)

# Replace missing values in 'ema' with forward fill
merged_sprc_new['ema_5m'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_sprc_new['target_ema_5m'].fillna(method='ffill', inplace=True)

print(merged_sprc_new[['ema_5m']])

# Plotting the EMA_5m
plt.figure(figsize=(10, 6))
plt.plot(merged_sprc_new.index, merged_sprc_new['sprc5_close'], label='SPRC 5 Close')
plt.plot(merged_sprc_new.index, merged_sprc_new[['ema_5m']], label='EMA (5 periods)')

plt.title('SPRC Close and Exponential Moving Average (EMA)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### MACD

# %%
# Calculate MACD with forward-fill to handle NaN values
merged_sprc_new['macd_5m'], merged_sprc_new['signal_macd_5m'], _ = talib.MACD(merged_sprc_new['sprc5_close'], fastperiod=12, slowperiod=26, signalperiod=9)
merged_sprc_new[['macd_5m', 'signal_macd_5m']] = merged_sprc_new[['macd_5m', 'signal_macd_5m']].fillna(method='ffill')

# Create Label (target variable)
merged_sprc_new['target_macd_5m'] = np.where(merged_sprc_new['sprc5_close'].shift(-1) > merged_sprc_new['sprc5_close'], 1, 0)

# Replace missing values in 'target' with forward fill (if any)
merged_sprc_new['target_macd_5m'].fillna(method='ffill', inplace=True)

print(merged_sprc_new[['macd_5m', 'signal_macd_5m']])

# Verify the shapes of features and target
print("Shape of features:", merged_sprc_new[['macd_5m', 'signal_macd_5m']].shape)
print("Shape of target:", merged_sprc_new['target_macd_5m'].shape)

# Plotting the MACD alongside sprc5 Close
plt.figure(figsize=(10, 6))
plt.plot(merged_sprc_new.index, merged_sprc_new['sprc5_close'], label='SPRC 5 Close')
plt.plot(merged_sprc_new.index, merged_sprc_new['macd_5m'], label='MACD (12,26,9)')
plt.plot(merged_sprc_new.index, merged_sprc_new['signal_macd_5m'], label='Signal Line (MACD)')
plt.title('SPRC 5 Close, MACD, and Signal Line')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ##### RSI

# %%
# Calculate Relative Strength Index (RSI) with a window of 14 periods
merged_sprc_new['rsi_5'] = talib.RSI(merged_sprc_new['sprc5_close'], timeperiod=5)

# Create Label (target variable)
merged_sprc_new['target_rsi_5'] = np.where(merged_sprc_new['sprc5_close'].shift(-1) > merged_sprc_new['sprc5_close'], 1, 0)

# Replace missing values in 'rsi' with forward fill
merged_sprc_new['rsi_5'].fillna(method='ffill', inplace=True)

# Replace missing values in 'target' with forward fill (if any)
merged_sprc_new['target_rsi_5'].fillna(method='ffill', inplace=True)

print(merged_sprc_new[['rsi_5']])

# Verify the shapes of features and target
print("Shape of features:", merged_sprc_new[['rsi_5']].shape)
print("Shape of target:", merged_sprc_new['target_rsi_5'].shape)

# Plotting the 'sprc5_close' and RSI
plt.figure(figsize=(10, 6))
plt.plot(merged_sprc_new.index, merged_sprc_new['sprc5_close'], label='SPRC 5 Close')
plt.title('SPRC 5 Close and Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='upper left')

# Create a secondary y-axis for RSI
ax2 = plt.gca().twinx()
ax2.plot(merged_sprc_new.index, merged_sprc_new['rsi_5'], color='orange', label='RSI')
ax2.set_ylabel('RSI')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Fill Null Value

# %%
columns_to_fillna = ['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy','ema_15m','macd_15m','rsi_15', 'obv']

for column in columns_to_fillna:
    median_value = merged_data_SPRC[column].median()
    merged_data_SPRC[column].fillna(median_value, inplace=True)

# %% [markdown]
# ### Correlations

# %%
correlations = merged_data_SPRC.corr()['sprc15_close']

print("Correlation with sprc15_close:")
print(correlations)

print("\nInterpretation:")
for variable, correlation in correlations.items():
    if correlation > 0.7 or correlation < -0.7:
        print(f"The correlation between 'sprc15_close' and '{variable}' is strong ({correlation:.2f})")
    elif 0.3 <= correlation <= 0.7 or -0.7 <= correlation <= -0.3:
        print(f"The correlation between 'sprc15_close' and '{variable}' is moderate ({correlation:.2f})")
    elif 0.1 <= correlation <= 0.3 or -0.3 <= correlation <= -0.1:
        print(f"The correlation between 'sprc15_close' and '{variable}' is weak ({correlation:.2f})")
    else:
        print(f"There is no significant correlation between 'sprc15_close' and '{variable}' ({correlation:.2f})")

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(merged_data_SPRC.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Heat Map of merged_data_SRPC')

plt.show()

# %% [markdown]
# ### Standardization

# %%
# Specify the columns you want to normalize
columns_to_normalize = ['sprc15_close', 'cny', 'set50', 'energy','ema_15m','macd_15m','rsi_15', 'obv']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_SPRC[columns_to_normalize] = scaler.fit_transform(merged_data_SPRC[columns_to_normalize])

# %%
# Assuming merged_data_SRPC is a DataFrame
# filtered_data_SPRC = merged_data_SPRC[['ref_date', 'sprc15_close', 'cny', 'set50', 'energy','ema_15m','macd_15m','rsi_15','sprc15_signal']]
# filtered_data_SPRC = merged_data_SPRC[['ref_date', 'sprc15_close', 'cny', 'set50', 'energy','sprc15_signal']]
filtered_data_SPRC = merged_data_SPRC[['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy','ema_15m','macd_15m','rsi_15', 'sprc15_signal', 'obv']]
# filtered_data_SPRC = merged_data_SPRC[['ref_date', 'sprc15_close', 'cny', 'set50', 'energy','ema_15m','rsi_15','sprc15_signal']]
filtered_data_SPRC

# %% [markdown]
# # Model Development (Training)

# %% [markdown]
# ### TISCO

# %%
X_train_df = filtered_data_tisco[['tisco15_close', 'usd', 'cny', 'set50', 'gold', 'bank','ema_15m','macd_15m','rsi_15']]
y_train_df = filtered_data_tisco[['tisco15_signal']]

# %%
# Split dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train_df, y_train_df, test_size=0.2, random_state=123, stratify=y_train_df)

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer, roc_auc_score, confusion_matrix
import numpy as np

# set parameter
y_train = y_train.values.ravel()
k = 5
auc_scorer = make_scorer(roc_auc_score, greater_is_better = True, average= 'macro',multi_class='ovr',needs_proba=True)

# 1. Logistic regression
lgr = LogisticRegression(solver='liblinear')
param_grid_lgr = {'C': np.logspace(-4, 4, 20), 'penalty': ['l1', 'l2']}
grid_search_lgr = GridSearchCV(estimator=lgr, param_grid=param_grid_lgr, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_lgr.fit(X_train, y_train)


# 2. Extreme Gradient Boosting (XGBoost)
xgb_classifier = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
param_grid_xgb = {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 5], 'learning_rate': [0.1, 0.01, 0.001]}
grid_search_xgb = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid_xgb, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_xgb.fit(X_train, y_train)


# 3. SVM Support Vector Machine (SVM)
svm = SVC(probability=True)
param_grid_svm = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}
grid_search_svm = GridSearchCV(estimator=svm, param_grid=param_grid_svm, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_svm.fit(X_train, y_train)


# 4. Random forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
param_grid_rf = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_rf.fit(X_train, y_train)


# 5. Decision tree
dt = DecisionTreeClassifier(random_state=42)
param_grid_dt = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_dt = GridSearchCV(estimator=dt, param_grid=param_grid_dt, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_dt.fit(X_train, y_train)

# %% [markdown]
# ### ERW

# %%
X_train_df = filtered_data_erw[['erw15_close', 'cny', 'set50', 'service', 'tour','ema_15m','macd_15m','rsi_15']]
y_train_df = filtered_data_erw[['erw15_signal']]

# %%
# Split dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train_df, y_train_df, test_size=0.2, random_state=123, stratify=y_train_df)

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer, roc_auc_score, confusion_matrix
import numpy as np

# set parameter
y_train = y_train.values.ravel()
k = 5
auc_scorer = make_scorer(roc_auc_score, greater_is_better = True, average= 'macro',multi_class='ovr',needs_proba=True)

# 1. Logistic regression
lgr = LogisticRegression(solver='liblinear')
param_grid_lgr = {'C': np.logspace(-4, 4, 20), 'penalty': ['l1', 'l2']}
grid_search_lgr = GridSearchCV(estimator=lgr, param_grid=param_grid_lgr, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_lgr.fit(X_train, y_train)


# 2. Extreme Gradient Boosting (XGBoost)
xgb_classifier = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
param_grid_xgb = {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 5], 'learning_rate': [0.1, 0.01, 0.001]}
grid_search_xgb = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid_xgb, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_xgb.fit(X_train, y_train)


# 3. SVM Support Vector Machine (SVM)
svm = SVC(probability=True)
param_grid_svm = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}
grid_search_svm = GridSearchCV(estimator=svm, param_grid=param_grid_svm, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_svm.fit(X_train, y_train)


# 4. Random forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
param_grid_rf = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_rf.fit(X_train, y_train)


# 5. Decision tree

dt = DecisionTreeClassifier(random_state=42)
param_grid_dt = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_dt = GridSearchCV(estimator=dt, param_grid=param_grid_dt, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_dt.fit(X_train, y_train)

# %% [markdown]
# ### SRPC

# %%
X_train_df = filtered_data_SPRC[['sprc15_close', 'cny', 'set50', 'energy','ema_15m','rsi_15', 'obv']]
# X_train_df = filtered_data_SPRC[['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy','ema_15m','macd_15m','rsi_15', 'obv']]
# X_train_df = filtered_data_SPRC[['sprc15_close', 'cny', 'set50', 'energy']]
y_train_df = filtered_data_SPRC[['sprc15_signal']]
y_train_df.fillna(0, inplace=True)

# %%
# Split dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train_df, y_train_df, test_size=0.2, random_state=123, stratify=y_train_df)

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import make_scorer, roc_auc_score, confusion_matrix
import numpy as np

# set parameter
y_train = y_train.values.ravel()
k = 5
auc_scorer = make_scorer(roc_auc_score, greater_is_better = True, average= 'macro',multi_class='ovr',needs_proba=True)

# 1. Logistic regression
lgr = LogisticRegression(solver='liblinear')
param_grid_lgr = {'C': np.logspace(-4, 4, 20), 'penalty': ['l1', 'l2']}
grid_search_lgr = GridSearchCV(estimator=lgr, param_grid=param_grid_lgr, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_lgr.fit(X_train, y_train)


# 2. Extreme Gradient Boosting (XGBoost)
xgb_classifier = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
param_grid_xgb = {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 5], 'learning_rate': [0.1, 0.01, 0.001]}
grid_search_xgb = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid_xgb, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_xgb.fit(X_train, y_train)


# 3. SVM Support Vector Machine (SVM)
svm = SVC(probability=True)
param_grid_svm = {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}
grid_search_svm = GridSearchCV(estimator=svm, param_grid=param_grid_svm, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_svm.fit(X_train, y_train)


# 4. Random forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
param_grid_rf = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_rf.fit(X_train, y_train)


# 5. Decision tree
dt = DecisionTreeClassifier(random_state=42)
param_grid_dt = {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]}
grid_search_dt = GridSearchCV(estimator=dt, param_grid=param_grid_dt, cv=k, scoring=auc_scorer, return_train_score=False, verbose=1)
grid_search_dt.fit(X_train, y_train)

# %% [markdown]
# ## Model Evaluation (Testing Model)

# %%
# Prediction
# Confusion Matrix and AUC Calculation

# 1. Logistic regression

y_prob_lgr = grid_search_lgr.predict_proba(X_test)
auc_lgr = roc_auc_score(y_test, y_prob_lgr, multi_class='ovr') * 100

y_pred_lgr = grid_search_lgr.predict(X_test)
conf_matrix_lgr = confusion_matrix(y_test, y_pred_lgr)

print("\nLogistic Regression Confusion Matrix:")
print(conf_matrix_lgr)
print(f"Logistic Regression AUC Score: {auc_lgr:.2f}%")


# 2. Extreme Gradient Boosting (XGBoost)

y_prob_xgb = grid_search_xgb.predict_proba(X_test)
auc_xgb = roc_auc_score(y_test, y_prob_xgb, multi_class='ovr') * 100

y_pred_xgb = grid_search_xgb.predict(X_test)
conf_matrix_xgb = confusion_matrix(y_test, y_pred_xgb)

print("\nExtreme Gradient Boostingn Confusion Matrix:")
print(conf_matrix_xgb)
print(f"Extreme Gradient Boosting AUC Score: {auc_xgb:.2f}%")

# 3. SVM

y_prob_svm = grid_search_svm.predict_proba(X_test)
auc_svm = roc_auc_score(y_test, y_prob_svm, multi_class='ovr') * 100

y_pred_svm = grid_search_svm.predict(X_test)
conf_matrix_svm = confusion_matrix(y_test, y_pred_svm)

print("\nSVM Confusion Matrix:")
print(conf_matrix_svm)
print(f"SVM AUC Score: {auc_svm:.2f}%")


# 4. Random forest

y_prob_rf = grid_search_rf.predict_proba(X_test)
auc_rf = roc_auc_score(y_test, y_prob_rf, multi_class='ovr') * 100

y_pred_rf = grid_search_rf.predict(X_test)
conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)

print("\nRandom forest Confusion Matrix:")
print(conf_matrix_rf)
print(f"Random forest AUC Score: {auc_rf:.2f}%")


# 5. Decision tree

y_prob_dt = grid_search_dt.predict_proba(X_test)
auc_dt = roc_auc_score(y_test, y_prob_dt, multi_class='ovr') * 100

y_pred_dt = grid_search_dt.predict(X_test)
conf_matrix_dt = confusion_matrix(y_test, y_pred_dt)

print("\nDecision tree Confusion Matrix:")
print(conf_matrix_dt)
print(f"Decision tree AUC Score: {auc_dt:.2f}%")

# %% [markdown]
# ## Deployment (Prediction)

# %%
# Select the best score Model

# %% [markdown]
# ## Submission

# %%
# Output
submission = pd.DataFrame({"Id":range(1,301),"Expected":result}) # To be revised
print(submission.shape)
print(submission.head())
submission.to_csv("submission.csv", index=False)
