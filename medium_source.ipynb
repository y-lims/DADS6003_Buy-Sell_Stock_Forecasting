# %% [markdown]
# # Libraries

# %%
pip install TA-Lib
# Out:
# Requirement already satisfied: TA-Lib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.4.28)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from TA-Lib) (1.26.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the Libraries

# Data Manupulation
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Techinical Indicators
import talib as ta

# Plotting graphs
import matplotlib.pyplot as plt

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report

# Data fetching
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# # Stock Data

# %% [markdown]
# ## TISCO

# %% [markdown]
# ### 1m

# %%
# TISCO 1m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
TISCO_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_1m_df = pd.concat([TISCO_1m_df, data])

# Reset the index to get Date as a column
TISCO_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_1m_df)

# Save the DataFrame to a CSV file
TISCO_1m_df.to_csv('data_TISCO_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date    Open   High     Low  Close  \
# 0         1m 2024-01-03 10:00:00+07:00   99.50   99.5   99.50   99.5
# 1         1m 2024-01-03 10:02:00+07:00   99.75  100.0   99.75  100.0
# 2         1m 2024-01-03 10:03:00+07:00  100.00  100.0  100.00  100.0
# 3         1m 2024-01-03 10:04:00+07:00  100.00  100.5  100.00  100.5
# 4         1m 2024-01-03 10:05:00+07:00  100.50  100.5  100.00  100.5
# ..       ...                       ...     ...    ...     ...    ...
# 722       1m 2024-01-05 16:25:00+07:00  100.50  100.5  100.00  100.5
# 723       1m 2024-01-05 16:26:00+07:00  100.50  100.5  100.00  100.0
# 724       1m 2024-01-05 16:27:00+07:00  100.00  100.5  100.00  100.5
# 725       1m 2024-01-05 16:28:00+07:00  100.50  100.5  100.00  100.0
# 726       1m 2024-01-05 16:29:00+07:00  100.50  100.5  100.00  100.5
#
#      Adj Close  Volume
# 0         99.5       0
# 1        100.0  241605
# 2        100.0    5245
# 3        100.5  675732
# 4        100.5  200635
# ..         ...     ...
# 722      100.5    2801
# 723      100.0    5900
# 724      100.5   19371
# 725      100.0    9400
# 726      100.5    5300
#
# [727 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# TISCO 2m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
TISCO_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_2m_df = pd.concat([TISCO_2m_df, data])

# Reset the index to get Date as a column
TISCO_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_2m_df)

# Save the DataFrame to a CSV file
TISCO_2m_df.to_csv('data_TISCO_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date    Open    High     Low   Close  \
# 0          2m 2023-11-15 10:00:00+07:00   97.25   97.25   97.25   97.25
# 1          2m 2023-11-15 10:06:00+07:00   97.25   97.25   97.00   97.00
# 2          2m 2023-11-15 10:08:00+07:00   97.00   97.25   97.00   97.25
# 3          2m 2023-11-15 10:10:00+07:00   97.00   97.00   97.00   97.00
# 4          2m 2023-11-15 10:16:00+07:00   97.25   97.25   97.25   97.25
# ...       ...                       ...     ...     ...     ...     ...
# 4279       2m 2024-01-05 16:20:00+07:00  100.50  100.50  100.00  100.50
# 4280       2m 2024-01-05 16:22:00+07:00  100.00  100.50  100.00  100.50
# 4281       2m 2024-01-05 16:24:00+07:00  100.00  100.50  100.00  100.50
# 4282       2m 2024-01-05 16:26:00+07:00  100.50  100.50  100.00  100.50
# 4283       2m 2024-01-05 16:28:00+07:00  100.50  100.50  100.00  100.50
#
#       Adj Close  Volume
# 0         97.25       0
# 1         97.00    2302
# 2         97.25    6668
# 3         97.00    2353
# 4         97.25    1253
# ...         ...     ...
# 4279     100.50    8700
# 4280     100.50    9900
# 4281     100.50    9111
# 4282     100.50   25271
# 4283     100.50   14700
#
# [4284 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# TISCO 5m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
TISCO_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_5m_df = pd.concat([TISCO_5m_df, data])

# Reset the index to get Date as a column
TISCO_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_5m_df)

# Save the DataFrame to a CSV file
TISCO_5m_df.to_csv('data_TISCO_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date    Open    High     Low   Close  \
# 0          5m 2023-11-08 10:00:00+07:00   97.25   97.50   97.00   97.25
# 1          5m 2023-11-08 10:05:00+07:00   97.25   97.25   97.00   97.25
# 2          5m 2023-11-08 10:10:00+07:00   97.25   97.25   97.00   97.25
# 3          5m 2023-11-08 10:15:00+07:00   97.50   97.50   97.25   97.25
# 4          5m 2023-11-08 10:20:00+07:00   97.50   97.50   97.25   97.25
# ...       ...                       ...     ...     ...     ...     ...
# 2075       5m 2024-01-05 16:05:00+07:00  100.50  100.50  100.00  100.50
# 2076       5m 2024-01-05 16:10:00+07:00  100.00  100.50  100.00  100.50
# 2077       5m 2024-01-05 16:15:00+07:00  100.50  100.50  100.00  100.50
# 2078       5m 2024-01-05 16:20:00+07:00  100.50  100.50  100.00  100.50
# 2079       5m 2024-01-05 16:25:00+07:00  100.50  100.50  100.00  100.50
#
#       Adj Close  Volume
# 0         97.25   24758
# 1         97.25       0
# 2         97.25   52156
# 3         97.25       0
# 4         97.25    3848
# ...         ...     ...
# 2075     100.50   15428
# 2076     100.50   31955
# 2077     100.50   24401
# 2078     100.50   24910
# 2079     100.50   42772
#
# [2080 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# TISCO 15m
stock_symbol = 'TISCO.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
TISCO_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TISCO_15m_df = pd.concat([TISCO_15m_df, data])

# Reset the index to get Date as a column
TISCO_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TISCO_15m_df)

# Save the DataFrame to a CSV file
TISCO_15m_df.to_csv('data_TISCO_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date    Open    High    Low   Close  Adj Close  \
# 0        15m 2023-11-08 10:00:00   97.25   97.50   97.0   97.25      97.25
# 1        15m 2023-11-08 10:15:00   97.50   97.50   97.0   97.25      97.25
# 2        15m 2023-11-08 10:30:00   97.00   97.25   97.0   97.25      97.25
# 3        15m 2023-11-08 10:45:00   97.00   97.25   97.0   97.25      97.25
# 4        15m 2023-11-08 11:00:00   97.25   97.25   97.0   97.25      97.25
# ..       ...                 ...     ...     ...    ...     ...        ...
# 717      15m 2024-01-05 15:15:00  100.00  100.50  100.0  100.50     100.50
# 718      15m 2024-01-05 15:30:00  100.00  100.50  100.0  100.50     100.50
# 719      15m 2024-01-05 15:45:00  100.50  100.50  100.0  100.50     100.50
# 720      15m 2024-01-05 16:00:00  100.50  100.50  100.0  100.50     100.50
# 721      15m 2024-01-05 16:15:00  100.50  100.50  100.0  100.50     100.50
#
#      Volume
# 0     76914
# 1    101248
# 2     23450
# 3     13662
# 4     22726
# ..      ...
# 717   30995
# 718   66794
# 719   55503
# 720   64386
# 721   92083
#
# [722 rows x 8 columns]

# %% [markdown]
# ## ERW

# %% [markdown]
# ### 1m

# %%
# ERW 1m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
ERW_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_1m_df = pd.concat([ERW_1m_df, data])

# Reset the index to get Date as a column
ERW_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_1m_df)

# Save the DataFrame to a CSV file
ERW_1m_df.to_csv('data_ERW_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0         1m 2024-01-03 10:00:00+07:00  5.15  5.15  5.15   5.15       5.15
# 1         1m 2024-01-03 10:01:00+07:00  5.15  5.20  5.15   5.20       5.20
# 2         1m 2024-01-03 10:02:00+07:00  5.15  5.15  5.15   5.15       5.15
# 3         1m 2024-01-03 10:03:00+07:00  5.15  5.20  5.10   5.20       5.20
# 4         1m 2024-01-03 10:04:00+07:00  5.20  5.20  5.20   5.20       5.20
# ..       ...                       ...   ...   ...   ...    ...        ...
# 628       1m 2024-01-05 16:25:00+07:00  5.25  5.25  5.20   5.25       5.25
# 629       1m 2024-01-05 16:26:00+07:00  5.25  5.25  5.20   5.20       5.20
# 630       1m 2024-01-05 16:27:00+07:00  5.25  5.25  5.20   5.20       5.20
# 631       1m 2024-01-05 16:28:00+07:00  5.20  5.25  5.20   5.25       5.25
# 632       1m 2024-01-05 16:29:00+07:00  5.25  5.25  5.25   5.25       5.25
#
#       Volume
# 0          0
# 1          0
# 2     509401
# 3    2215500
# 4       5500
# ..       ...
# 628     5900
# 629    14700
# 630     9400
# 631    33500
# 632   279100
#
# [633 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# ERW 2m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
ERW_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_2m_df = pd.concat([ERW_2m_df, data])

# Reset the index to get Date as a column
ERW_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_2m_df)

# Save the DataFrame to a CSV file
ERW_2m_df.to_csv('data_ERW_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          2m 2023-11-15 10:00:00+07:00  5.20  5.20  5.20   5.20       5.20
# 1          2m 2023-11-15 10:02:00+07:00  5.20  5.20  5.15   5.15       5.15
# 2          2m 2023-11-15 10:04:00+07:00  5.20  5.20  5.20   5.20       5.20
# 3          2m 2023-11-15 10:06:00+07:00  5.20  5.20  5.20   5.20       5.20
# 4          2m 2023-11-15 10:10:00+07:00  5.20  5.20  5.20   5.20       5.20
# ...       ...                       ...   ...   ...   ...    ...        ...
# 3739       2m 2024-01-05 16:20:00+07:00  5.20  5.25  5.20   5.20       5.20
# 3740       2m 2024-01-05 16:22:00+07:00  5.25  5.25  5.20   5.20       5.20
# 3741       2m 2024-01-05 16:24:00+07:00  5.25  5.25  5.20   5.25       5.25
# 3742       2m 2024-01-05 16:26:00+07:00  5.25  5.25  5.20   5.20       5.20
# 3743       2m 2024-01-05 16:28:00+07:00  5.20  5.25  5.20   5.25       5.25
#
#       Volume
# 0          0
# 1      26500
# 2     230400
# 3       2300
# 4      71900
# ...      ...
# 3739   12000
# 3740   22100
# 3741   27100
# 3742   24100
# 3743  312600
#
# [3744 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# ERW 5m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
ERW_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_5m_df = pd.concat([ERW_5m_df, data])

# Reset the index to get Date as a column
ERW_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_5m_df)

# Save the DataFrame to a CSV file
ERW_5m_df.to_csv('data_ERW_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High  Low  Close  Adj Close  \
# 0          5m 2023-11-08 10:00:00+07:00  5.25  5.30  5.2   5.20       5.20
# 1          5m 2023-11-08 10:05:00+07:00  5.20  5.25  5.2   5.20       5.20
# 2          5m 2023-11-08 10:10:00+07:00  5.20  5.25  5.2   5.20       5.20
# 3          5m 2023-11-08 10:15:00+07:00  5.20  5.25  5.2   5.25       5.25
# 4          5m 2023-11-08 10:20:00+07:00  5.20  5.25  5.2   5.20       5.20
# ...       ...                       ...   ...   ...  ...    ...        ...
# 2018       5m 2024-01-05 16:05:00+07:00  5.20  5.25  5.2   5.20       5.20
# 2019       5m 2024-01-05 16:10:00+07:00  5.20  5.25  5.2   5.20       5.20
# 2020       5m 2024-01-05 16:15:00+07:00  5.20  5.25  5.2   5.20       5.20
# 2021       5m 2024-01-05 16:20:00+07:00  5.20  5.25  5.2   5.25       5.25
# 2022       5m 2024-01-05 16:25:00+07:00  5.25  5.25  5.2   5.25       5.25
#
#       Volume
# 0          0
# 1     128800
# 2      12006
# 3     151602
# 4      13000
# ...      ...
# 2018   88000
# 2019  885500
# 2020  140500
# 2021   55300
# 2022  342600
#
# [2023 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# ERW 15m
stock_symbol = 'ERW.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
ERW_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ERW_15m_df = pd.concat([ERW_15m_df, data])

# Reset the index to get Date as a column
ERW_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ERW_15m_df)

# Save the DataFrame to a CSV file
ERW_15m_df.to_csv('data_ERW_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High  Low  Close  Adj Close   Volume
# 0        15m 2023-11-08 10:00:00  5.25  5.30  5.2   5.20       5.20   140806
# 1        15m 2023-11-08 10:15:00  5.20  5.25  5.2   5.20       5.20   185402
# 2        15m 2023-11-08 10:30:00  5.20  5.25  5.2   5.25       5.25    88100
# 3        15m 2023-11-08 10:45:00  5.25  5.25  5.2   5.20       5.20   539000
# 4        15m 2023-11-08 11:00:00  5.20  5.25  5.2   5.25       5.25    10200
# ..       ...                 ...   ...   ...  ...    ...        ...      ...
# 717      15m 2024-01-05 15:15:00  5.20  5.25  5.2   5.20       5.20   317900
# 718      15m 2024-01-05 15:30:00  5.25  5.25  5.2   5.20       5.20   362100
# 719      15m 2024-01-05 15:45:00  5.25  5.25  5.2   5.20       5.20   175800
# 720      15m 2024-01-05 16:00:00  5.25  5.25  5.2   5.20       5.20  1028400
# 721      15m 2024-01-05 16:15:00  5.20  5.25  5.2   5.25       5.25   538400
#
# [722 rows x 8 columns]

# %% [markdown]
# ## SPRC

# %% [markdown]
# ### 1m

# %%
# SPRC 1m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=7)).strftime('%Y-%m-%d')
intervals = ['1m']

# Create an empty DataFrame to store the results
SPRC_1m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_1m_df = pd.concat([SPRC_1m_df, data])

# Reset the index to get Date as a column
SPRC_1m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_1m_df)

# Save the DataFrame to a CSV file
SPRC_1m_df.to_csv('data_SPRC_1m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0         1m 2024-01-03 10:01:00+07:00  8.30   8.3  8.30   8.30       8.30
# 1         1m 2024-01-03 10:02:00+07:00  8.30   8.3  8.30   8.30       8.30
# 2         1m 2024-01-03 10:03:00+07:00  8.30   8.3  8.25   8.30       8.30
# 3         1m 2024-01-03 10:04:00+07:00  8.30   8.3  8.25   8.25       8.25
# 4         1m 2024-01-03 10:05:00+07:00  8.30   8.3  8.25   8.25       8.25
# ..       ...                       ...   ...   ...   ...    ...        ...
# 725       1m 2024-01-05 16:25:00+07:00  8.50   8.5  8.45   8.50       8.50
# 726       1m 2024-01-05 16:26:00+07:00  8.45   8.5  8.45   8.45       8.45
# 727       1m 2024-01-05 16:27:00+07:00  8.50   8.5  8.45   8.45       8.45
# 728       1m 2024-01-05 16:28:00+07:00  8.45   8.5  8.45   8.45       8.45
# 729       1m 2024-01-05 16:29:00+07:00  8.50   8.5  8.45   8.45       8.45
#
#      Volume
# 0         0
# 1         0
# 2     23800
# 3     17200
# 4      1500
# ..      ...
# 725    6800
# 726   10301
# 727    7200
# 728    5400
# 729    5400
#
# [730 rows x 8 columns]

# %% [markdown]
# ### 2m

# %%
# SPRC 2m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['2m']

# Create an empty DataFrame to store the results
SPRC_2m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_2m_df = pd.concat([SPRC_2m_df, data])

# Reset the index to get Date as a column
SPRC_2m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_2m_df)

# Save the DataFrame to a CSV file
SPRC_2m_df.to_csv('data_SPRC_2m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          2m 2023-11-15 10:00:00+07:00  8.10   8.1  8.10   8.10       8.10
# 1          2m 2023-11-15 10:02:00+07:00  8.10   8.1  8.10   8.10       8.10
# 2          2m 2023-11-15 10:04:00+07:00  8.10   8.1  8.10   8.10       8.10
# 3          2m 2023-11-15 10:06:00+07:00  8.10   8.1  8.05   8.05       8.05
# 4          2m 2023-11-15 10:08:00+07:00  8.05   8.1  8.05   8.10       8.10
# ...       ...                       ...   ...   ...   ...    ...        ...
# 3910       2m 2024-01-05 16:20:00+07:00  8.50   8.5  8.45   8.50       8.50
# 3911       2m 2024-01-05 16:22:00+07:00  8.45   8.5  8.45   8.45       8.45
# 3912       2m 2024-01-05 16:24:00+07:00  8.50   8.5  8.45   8.50       8.50
# 3913       2m 2024-01-05 16:26:00+07:00  8.45   8.5  8.45   8.45       8.45
# 3914       2m 2024-01-05 16:28:00+07:00  8.45   8.5  8.45   8.45       8.45
#
#       Volume
# 0       4000
# 1      12300
# 2      16101
# 3       6000
# 4       6100
# ...      ...
# 3910   15800
# 3911   12700
# 3912   14700
# 3913   17501
# 3914   10800
#
# [3915 rows x 8 columns]

# %% [markdown]
# ### 5m

# %%
# SPRC 5m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['5m']

# Create an empty DataFrame to store the results
SPRC_5m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_5m_df = pd.concat([SPRC_5m_df, data])

# Reset the index to get Date as a column
SPRC_5m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_5m_df)

# Save the DataFrame to a CSV file
SPRC_5m_df.to_csv('data_SPRC_5m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                      Date  Open  High   Low  Close  Adj Close  \
# 0          5m 2023-11-08 10:00:00+07:00  7.90  7.90  7.80   7.85       7.85
# 1          5m 2023-11-08 10:05:00+07:00  7.85  7.85  7.85   7.85       7.85
# 2          5m 2023-11-08 10:10:00+07:00  7.85  7.85  7.80   7.80       7.80
# 3          5m 2023-11-08 10:15:00+07:00  7.80  7.90  7.80   7.85       7.85
# 4          5m 2023-11-08 10:20:00+07:00  7.90  7.90  7.80   7.80       7.80
# ...       ...                       ...   ...   ...   ...    ...        ...
# 2037       5m 2024-01-05 16:05:00+07:00  8.50  8.55  8.45   8.50       8.50
# 2038       5m 2024-01-05 16:10:00+07:00  8.50  8.50  8.45   8.45       8.45
# 2039       5m 2024-01-05 16:15:00+07:00  8.45  8.50  8.45   8.45       8.45
# 2040       5m 2024-01-05 16:20:00+07:00  8.50  8.50  8.45   8.50       8.50
# 2041       5m 2024-01-05 16:25:00+07:00  8.50  8.50  8.45   8.45       8.45
#
#        Volume
# 0     1142100
# 1       27300
# 2      383900
# 3      203501
# 4      754900
# ...       ...
# 2037   307300
# 2038    51800
# 2039    53200
# 2040    36400
# 2041    35101
#
# [2042 rows x 8 columns]

# %% [markdown]
# ### 15m

# %%
# SPRC 15m
stock_symbol = 'SPRC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SPRC_15m_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SPRC_15m_df = pd.concat([SPRC_15m_df, data])

# Reset the index to get Date as a column
SPRC_15m_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SPRC_15m_df)

# Save the DataFrame to a CSV file
SPRC_15m_df.to_csv('data_SPRC_15m.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close   Volume
# 0        15m 2023-11-08 10:00:00  7.90  7.90  7.80   7.80       7.80  1553300
# 1        15m 2023-11-08 10:15:00  7.80  7.90  7.75   7.80       7.80  1732301
# 2        15m 2023-11-08 10:30:00  7.75  7.80  7.75   7.75       7.75  1075400
# 3        15m 2023-11-08 10:45:00  7.80  7.80  7.75   7.75       7.75   539200
# 4        15m 2023-11-08 11:00:00  7.75  7.80  7.70   7.75       7.75   456800
# ..       ...                 ...   ...   ...   ...    ...        ...      ...
# 715      15m 2024-01-05 15:15:00  8.60  8.65  8.50   8.55       8.55  2891525
# 716      15m 2024-01-05 15:30:00  8.55  8.60  8.45   8.50       8.50  3804060
# 717      15m 2024-01-05 15:45:00  8.55  8.55  8.45   8.55       8.55  1084419
# 718      15m 2024-01-05 16:00:00  8.50  8.55  8.45   8.45       8.45   462100
# 719      15m 2024-01-05 16:15:00  8.45  8.50  8.45   8.45       8.45   124701
#
# [720 rows x 8 columns]

# %% [markdown]
# # Features Data

# %% [markdown]
# ## FX RATE USD-THB

# %%
# USD 15m
stock_symbol = 'THB=X'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
USD_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    USD_df = pd.concat([USD_df, data])

# Reset the index to get Date as a column
USD_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(USD_df)

# Save the DataFrame to a CSV file
USD_df.to_csv('data_USD.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-08 00:00:00  35.500000  35.505001  35.430000  35.470001
# 1         15m 2023-11-08 00:15:00  35.459999  35.484001  35.410000  35.430000
# 2         15m 2023-11-08 00:30:00  35.439999  35.495998  35.430000  35.480000
# 3         15m 2023-11-08 00:45:00  35.490002  35.500000  35.459999  35.490002
# 4         15m 2023-11-08 01:00:00  35.480000  35.506001  35.450001  35.450001
# ...       ...                 ...        ...        ...        ...        ...
# 3904      15m 2024-01-05 21:00:00  34.700001  34.700001  34.680000  34.689999
# 3905      15m 2024-01-05 21:15:00  34.700001  34.700001  34.689999  34.689999
# 3906      15m 2024-01-05 21:30:00  34.700001  34.700001  34.680000  34.700001
# 3907      15m 2024-01-05 21:45:00  34.669998  34.680000  34.669998  34.680000
# 3908      15m 2024-01-05 22:00:00  34.680000  34.680000  34.680000  34.680000
#
#       Adj Close  Volume
# 0     35.470001       0
# 1     35.430000       0
# 2     35.480000       0
# 3     35.490002       0
# 4     35.450001       0
# ...         ...     ...
# 3904  34.689999       0
# 3905  34.689999       0
# 3906  34.700001       0
# 3907  34.680000       0
# 3908  34.680000       0
#
# [3909 rows x 8 columns]

# %% [markdown]
# ## CNYX

# %%
# CNY 15m
stock_symbol = 'CNY=X'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
CNY_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    CNY_df = pd.concat([CNY_df, data])

# Reset the index to get Date as a column
CNY_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(CNY_df)

# Save the DataFrame to a CSV file
CNY_df.to_csv('data_CNY.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date    Open    High     Low   Close  Adj Close  \
# 0         15m 2023-11-08 01:30:00  7.2760  7.2775  7.2736  7.2736     7.2736
# 1         15m 2023-11-08 01:45:00  7.2731  7.2749  7.2696  7.2696     7.2696
# 2         15m 2023-11-08 02:00:00  7.2697  7.2720  7.2697  7.2703     7.2703
# 3         15m 2023-11-08 02:15:00  7.2696  7.2696  7.2652  7.2671     7.2671
# 4         15m 2023-11-08 02:30:00  7.2674  7.2701  7.2674  7.2701     7.2701
# ...       ...                 ...     ...     ...     ...     ...        ...
# 2502      15m 2024-01-05 17:45:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2503      15m 2024-01-05 19:15:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2504      15m 2024-01-05 19:45:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2505      15m 2024-01-05 20:30:00  7.1390  7.1390  7.1390  7.1390     7.1390
# 2506      15m 2024-01-05 22:00:00  7.1390  7.1390  7.1390  7.1390     7.1390
#
#       Volume
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2502       0
# 2503       0
# 2504       0
# 2505       0
# 2506       0
#
# [2507 rows x 8 columns]

# %% [markdown]
# ## SET100

# %%
# SET100 15m
stock_symbol = 'BSET100.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SET100_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SET100_df = pd.concat([SET100_df, data])

# Reset the index to get Date as a column
SET100_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SET100_df)

# Save the DataFrame to a CSV file
SET100_df.to_csv('data_SET100.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close  Volume
# 0        15m 2023-11-08 10:00:00  9.22  9.22  9.22   9.22       9.22       0
# 1        15m 2023-11-08 10:15:00  9.24  9.24  9.24   9.24       9.24   46800
# 2        15m 2023-11-08 10:30:00  9.23  9.23  9.23   9.23       9.23     100
# 3        15m 2023-11-08 10:45:00  9.23  9.23  9.23   9.23       9.23     100
# 4        15m 2023-11-08 11:00:00  9.23  9.23  9.23   9.23       9.23     100
# ..       ...                 ...   ...   ...   ...    ...        ...     ...
# 419      15m 2024-01-05 12:00:00  9.30  9.30  9.30   9.30       9.30     500
# 420      15m 2024-01-05 14:15:00  9.29  9.29  9.29   9.29       9.29     600
# 421      15m 2024-01-05 14:30:00  9.29  9.29  9.29   9.29       9.29    1000
# 422      15m 2024-01-05 15:45:00  9.27  9.27  9.27   9.27       9.27     700
# 423      15m 2024-01-05 16:00:00  9.27  9.27  9.25   9.25       9.25    6401
#
# [424 rows x 8 columns]

# %% [markdown]
# ## SET50

# %%
# SET50 15m
stock_symbol = 'TDEX.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SET50_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SET50_df = pd.concat([SET50_df, data])

# Reset the index to get Date as a column
SET50_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SET50_df)

# Save the DataFrame to a CSV file
SET50_df.to_csv('data_SET50.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date  Open  High   Low  Close  Adj Close  Volume
# 0        15m 2023-11-08 10:00:00  8.59  8.59  8.56   8.58       8.58    8920
# 1        15m 2023-11-08 10:15:00  8.59  8.61  8.59   8.60       8.60   35083
# 2        15m 2023-11-08 10:30:00  8.59  8.60  8.59   8.60       8.60   15616
# 3        15m 2023-11-08 10:45:00  8.60  8.60  8.59   8.59       8.59   14500
# 4        15m 2023-11-08 11:00:00  8.59  8.60  8.58   8.60       8.60    1924
# ..       ...                 ...   ...   ...   ...    ...        ...     ...
# 717      15m 2024-01-05 15:15:00  8.63  8.63  8.62   8.62       8.62    4100
# 718      15m 2024-01-05 15:30:00  8.62  8.63  8.61   8.62       8.62   14437
# 719      15m 2024-01-05 15:45:00  8.62  8.63  8.61   8.62       8.62    2950
# 720      15m 2024-01-05 16:00:00  8.62  8.62  8.61   8.61       8.61   31366
# 721      15m 2024-01-05 16:15:00  8.61  8.61  8.61   8.61       8.61   10518
#
# [722 rows x 8 columns]

# %% [markdown]
# ## Gold

# %%
# Gold 15m
stock_symbol = 'GC=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
GOLD_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    GOLD_df = pd.concat([GOLD_df, data])

# Reset the index to get Date as a column
GOLD_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(GOLD_df)

# Save the DataFrame to a CSV file
GOLD_df.to_csv('data_GOLD.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date         Open         High          Low  \
# 0         15m 2023-11-08 00:00:00  1973.800049  1974.099976  1973.300049
# 1         15m 2023-11-08 00:15:00  1973.400024  1973.400024  1972.199951
# 2         15m 2023-11-08 00:30:00  1972.300049  1972.400024  1971.199951
# 3         15m 2023-11-08 00:45:00  1971.300049  1972.300049  1971.300049
# 4         15m 2023-11-08 01:00:00  1971.699951  1972.500000  1971.099976
# ...       ...                 ...          ...          ...          ...
# 3679      15m 2024-01-05 15:45:00  2050.800049  2051.899902  2050.600098
# 3680      15m 2024-01-05 16:00:00  2050.800049  2051.800049  2050.800049
# 3681      15m 2024-01-05 16:15:00  2051.399902  2052.000000  2051.199951
# 3682      15m 2024-01-05 16:30:00  2051.899902  2052.000000  2050.899902
# 3683      15m 2024-01-05 16:45:00  2051.899902  2053.199951  2051.699951
#
#             Close    Adj Close  Volume
# 0     1973.400024  1973.400024     266
# 1     1972.199951  1972.199951     547
# 2     1971.300049  1971.300049     943
# 3     1971.599976  1971.599976     494
# 4     1972.500000  1972.500000    1046
# ...           ...          ...     ...
# 3679  2050.800049  2050.800049     952
# 3680  2051.600098  2051.600098     572
# 3681  2051.800049  2051.800049     250
# 3682  2051.899902  2051.899902     376
# 3683  2052.600098  2052.600098     613
#
# [3684 rows x 8 columns]

# %% [markdown]
# ## Financial Index

# %%
# Fincial Index 15m
stock_symbol = '^FINCIAL.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
FINCIAL_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    FINCIAL_df = pd.concat([FINCIAL_df, data])

# Reset the index to get Date as a column
FINCIAL_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(FINCIAL_df)

# Save the DataFrame to a CSV file
FINCIAL_df.to_csv('data_FINCIAL.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-08 10:00:00  141.050003  141.050003  140.399994
# 1        15m 2023-11-08 10:15:00  140.820007  141.139999  140.820007
# 2        15m 2023-11-08 10:30:00  140.940002  140.940002  140.690002
# 3        15m 2023-11-08 10:45:00  140.729996  140.970001  140.699997
# 4        15m 2023-11-08 11:00:00  140.809998  141.000000  140.740005
# ..       ...                 ...         ...         ...         ...
# 753      15m 2024-01-05 15:15:00  142.139999  142.429993  141.990005
# 754      15m 2024-01-05 15:30:00  142.240005  142.309998  141.960007
# 755      15m 2024-01-05 15:45:00  142.050003  142.289993  141.979996
# 756      15m 2024-01-05 16:00:00  142.220001  142.250000  141.860001
# 757      15m 2024-01-05 16:15:00  141.949997  142.169998  141.850006
#
#           Close   Adj Close  Volume
# 0    140.860001  140.860001       0
# 1    140.940002  140.940002       0
# 2    140.809998  140.809998       0
# 3    140.839996  140.839996       0
# 4    140.960007  140.960007       0
# ..          ...         ...     ...
# 753  142.199997  142.199997       0
# 754  142.000000  142.000000       0
# 755  142.139999  142.139999       0
# 756  142.050003  142.050003       0
# 757  142.029999  142.029999       0
#
# [758 rows x 8 columns]

# %% [markdown]
# ## Banking Index

# %%
# Banking Index 15m
stock_symbol = '^BANK.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
BANKING_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    BANKING_df = pd.concat([BANKING_df, data])

# Reset the index to get Date as a column
BANKING_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(BANKING_df)

# Save the DataFrame to a CSV file
BANKING_df.to_csv('data_BANKING.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-08 10:00:00  379.130005  379.260010  377.190002
# 1        15m 2023-11-08 10:15:00  378.660004  379.589996  378.109985
# 2        15m 2023-11-08 10:30:00  378.940002  379.320007  378.350006
# 3        15m 2023-11-08 10:45:00  378.600006  379.480011  378.350006
# 4        15m 2023-11-08 11:00:00  378.850006  379.440002  378.500000
# ..       ...                 ...         ...         ...         ...
# 751      15m 2024-01-05 15:15:00  385.309998  386.239990  384.619995
# 752      15m 2024-01-05 15:30:00  385.609985  385.859985  384.700012
# 753      15m 2024-01-05 15:45:00  385.149994  385.649994  384.670013
# 754      15m 2024-01-05 16:00:00  385.549988  385.549988  384.510010
# 755      15m 2024-01-05 16:15:00  384.880005  385.809998  384.459991
#
#           Close   Adj Close  Volume
# 0    378.769989  378.769989       0
# 1    378.940002  378.940002       0
# 2    378.850006  378.850006       0
# 3    379.100006  379.100006       0
# 4    379.140015  379.140015       0
# ..          ...         ...     ...
# 751  385.609985  385.609985       0
# 752  385.250000  385.250000       0
# 753  385.299988  385.299988       0
# 754  385.130005  385.130005       0
# 755  385.760010  385.760010       0
#
# [756 rows x 8 columns]

# %% [markdown]
# ## Service Index

# %%
# Service Index 15m
stock_symbol = '^SERVICE.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
SERVICE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    SERVICE_df = pd.concat([SERVICE_df, data])

# Reset the index to get Date as a column
SERVICE_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(SERVICE_df)

# Save the DataFrame to a CSV file
SERVICE_df.to_csv('data_SERVICE.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-08 10:00:00  433.920013  435.290009  433.619995
# 1        15m 2023-11-08 10:15:00  434.950012  436.070007  434.779999
# 2        15m 2023-11-08 10:30:00  435.579987  436.269989  435.010010
# 3        15m 2023-11-08 10:45:00  435.940002  436.339996  434.850006
# 4        15m 2023-11-08 11:00:00  434.899994  435.929993  434.589996
# ..       ...                 ...         ...         ...         ...
# 753      15m 2024-01-05 15:15:00  432.369995  433.010010  431.549988
# 754      15m 2024-01-05 15:30:00  432.750000  433.079987  431.630005
# 755      15m 2024-01-05 15:45:00  432.070007  432.809998  431.670013
# 756      15m 2024-01-05 16:00:00  432.149994  432.540009  430.869995
# 757      15m 2024-01-05 16:15:00  431.239990  432.910004  430.980011
#
#           Close   Adj Close  Volume
# 0    435.130005  435.130005       0
# 1    435.570007  435.570007       0
# 2    435.920013  435.920013       0
# 3    435.470001  435.470001       0
# 4    435.809998  435.809998       0
# ..          ...         ...     ...
# 753  431.679993  431.679993       0
# 754  432.049988  432.049988       0
# 755  431.929993  431.929993       0
# 756  431.190002  431.190002       0
# 757  432.489990  432.489990       0
#
# [758 rows x 8 columns]

# %% [markdown]
# ## Tourism Index

# %%
# Tourism Index 15m
stock_symbol = '^TOURISM.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
TOURISM_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    TOURISM_df = pd.concat([TOURISM_df, data])

# Reset the index to get Date as a column
TOURISM_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(TOURISM_df)

# Save the DataFrame to a CSV file
TOURISM_df.to_csv('data_TOURISM.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date        Open        High         Low  \
# 0        15m 2023-11-08 10:00:00  560.830017  564.830017  558.210022
# 1        15m 2023-11-08 10:15:00  564.799988  565.760010  562.390015
# 2        15m 2023-11-08 10:30:00  562.979980  566.080017  562.929993
# 3        15m 2023-11-08 10:45:00  562.929993  566.280029  562.250000
# 4        15m 2023-11-08 11:00:00  562.250000  564.919983  561.469971
# ..       ...                 ...         ...         ...         ...
# 746      15m 2024-01-05 15:15:00  568.169983  571.200012  567.599976
# 747      15m 2024-01-05 15:30:00  571.059998  571.409973  567.669983
# 748      15m 2024-01-05 15:45:00  568.580017  571.250000  567.760010
# 749      15m 2024-01-05 16:00:00  568.250000  571.190002  567.630005
# 750      15m 2024-01-05 16:15:00  568.409973  572.359985  567.630005
#
#           Close   Adj Close  Volume
# 0    564.799988  564.799988       0
# 1    562.979980  562.979980       0
# 2    563.359985  563.359985       0
# 3    562.250000  562.250000       0
# 4    561.900024  561.900024       0
# ..          ...         ...     ...
# 746  568.400024  568.400024       0
# 747  568.150024  568.150024       0
# 748  567.809998  567.809998       0
# 749  568.409973  568.409973       0
# 750  572.359985  572.359985       0
#
# [751 rows x 8 columns]

# %% [markdown]
# ## Resource Index

# %%
# Resource Index 15m
stock_symbol = '^RESOURC.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
RESOURCE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    RESOURCE_df = pd.concat([TOURISM_df, data])

# Reset the index to get Date as a column
TOURISM_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(RESOURCE_df)

# Save the DataFrame to a CSV file
RESOURCE_df.to_csv('data_RESOURC.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                            Interval                Date        Open  \
# 0                               15m 2023-11-08 10:00:00  560.830017
# 1                               15m 2023-11-08 10:15:00  564.799988
# 2                               15m 2023-11-08 10:30:00  562.979980
# 3                               15m 2023-11-08 10:45:00  562.929993
# 4                               15m 2023-11-08 11:00:00  562.250000
# ...                             ...                 ...         ...
# (15m, 2024-01-05 15:15:00)      NaN                 NaT  181.850006
# (15m, 2024-01-05 15:30:00)      NaN                 NaT  181.639999
# (15m, 2024-01-05 15:45:00)      NaN                 NaT  182.100006
# (15m, 2024-01-05 16:00:00)      NaN                 NaT  181.899994
# (15m, 2024-01-05 16:15:00)      NaN                 NaT  181.580002
#
#                                   High         Low       Close   Adj Close  \
# 0                           564.830017  558.210022  564.799988  564.799988
# 1                           565.760010  562.390015  562.979980  562.979980
# 2                           566.080017  562.929993  563.359985  563.359985
# 3                           566.280029  562.250000  562.250000  562.250000
# 4                           564.919983  561.469971  561.900024  561.900024
# ...                                ...         ...         ...         ...
# (15m, 2024-01-05 15:15:00)  182.440002  181.600006  181.639999  181.639999
# (15m, 2024-01-05 15:30:00)  182.119995  181.509995  182.039993  182.039993
# (15m, 2024-01-05 15:45:00)  182.190002  181.490005  181.940002  181.940002
# (15m, 2024-01-05 16:00:00)  182.169998  181.449997  181.639999  181.639999
# (15m, 2024-01-05 16:15:00)  182.240005  181.550003  181.940002  181.940002
#
#                             Volume
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# (15m, 2024-01-05 15:15:00)       0
# (15m, 2024-01-05 15:30:00)       0
# (15m, 2024-01-05 15:45:00)       0
# (15m, 2024-01-05 16:00:00)       0
# (15m, 2024-01-05 16:15:00)       0
#
# [1509 rows x 8 columns]

# %% [markdown]
# ## Energy Index

# %%
# Energy Index 15m
stock_symbol = '^ENERG.BK'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
ENERGY_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    ENERGY_df = pd.concat([ENERGY_df, data])

# Reset the index to get Date as a column
ENERGY_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(ENERGY_df)

# Save the DataFrame to a CSV file
ENERGY_df.to_csv('data_ENERG.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#     Interval                Date          Open          High           Low  \
# 0        15m 2023-11-08 10:00:00  20173.730469  20249.619141  20107.630859
# 1        15m 2023-11-08 10:15:00  20188.349609  20272.330078  20188.349609
# 2        15m 2023-11-08 10:30:00  20233.490234  20269.820312  20181.279297
# 3        15m 2023-11-08 10:45:00  20262.949219  20262.949219  20187.210938
# 4        15m 2023-11-08 11:00:00  20187.439453  20278.460938  20187.439453
# ..       ...                 ...           ...           ...           ...
# 753      15m 2024-01-05 15:15:00  20742.310547  20809.000000  20713.140625
# 754      15m 2024-01-05 15:30:00  20717.380859  20772.990234  20702.630859
# 755      15m 2024-01-05 15:45:00  20770.769531  20780.820312  20701.060547
# 756      15m 2024-01-05 16:00:00  20747.529297  20778.330078  20696.039062
# 757      15m 2024-01-05 16:15:00  20710.830078  20786.550781  20707.839844
#
#             Close     Adj Close  Volume
# 0    20187.460938  20187.460938       0
# 1    20201.919922  20201.919922       0
# 2    20204.849609  20204.849609       0
# 3    20242.500000  20242.500000       0
# 4    20217.330078  20217.330078       0
# ..            ...           ...     ...
# 753  20718.339844  20718.339844       0
# 754  20763.289062  20763.289062       0
# 755  20752.400391  20752.400391       0
# 756  20718.000000  20718.000000       0
# 757  20752.099609  20752.099609       0
#
# [758 rows x 8 columns]

# %% [markdown]
# ## BRENT

# %%
# BRENT 15m
stock_symbol = 'BZ=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
BRENT_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    BRENT_df = pd.concat([BRENT_df, data])

# Reset the index to get Date as a column
BRENT_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(BRENT_df)

# Save the DataFrame to a CSV file
BRENT_df.to_csv('data_BRENT.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-08 00:00:00  81.580002  81.580002  81.559998  81.580002
# 1         15m 2023-11-08 00:15:00  81.500000  81.500000  81.389999  81.389999
# 2         15m 2023-11-08 00:30:00  81.400002  81.440002  81.389999  81.430000
# 3         15m 2023-11-08 00:45:00  81.400002  81.480003  81.400002  81.480003
# 4         15m 2023-11-08 01:00:00  81.480003  81.510002  81.440002  81.489998
# ...       ...                 ...        ...        ...        ...        ...
# 3204      15m 2024-01-05 15:45:00  78.760002  78.849998  78.750000  78.839996
# 3205      15m 2024-01-05 16:00:00  78.839996  78.900002  78.800003  78.809998
# 3206      15m 2024-01-05 16:15:00  78.809998  78.839996  78.809998  78.839996
# 3207      15m 2024-01-05 16:30:00  78.820000  78.820000  78.769997  78.769997
# 3208      15m 2024-01-05 16:45:00  78.779999  78.900002  78.779999  78.900002
#
#       Adj Close  Volume
# 0     81.580002      10
# 1     81.389999      14
# 2     81.430000      19
# 3     81.480003       3
# 4     81.489998      27
# ...         ...     ...
# 3204  78.839996     216
# 3205  78.809998      78
# 3206  78.839996      12
# 3207  78.769997      27
# 3208  78.900002      88
#
# [3209 rows x 8 columns]

# %% [markdown]
# ## Crude

# %%
# Crude 15m
stock_symbol = 'BZ=F'
end_date = datetime.today().strftime('%Y-%m-%d')
start_date = (datetime.today() - timedelta(days=59)).strftime('%Y-%m-%d')
intervals = ['15m']

# Create an empty DataFrame to store the results
CRUDE_df = pd.DataFrame()

# Loop through each interval and append data to the DataFrame
for interval in intervals:
    data = yf.download(stock_symbol, start=start_date, end=end_date, interval=interval)
    # Add a level to the MultiIndex for the interval
    data.index = pd.MultiIndex.from_product([[interval], data.index], names=['Interval', 'Date'])
    CRUDE_df = pd.concat([CRUDE_df, data])

# Reset the index to get Date as a column
CRUDE_df.reset_index(inplace=True)

# Display the resulting DataFrame
display(CRUDE_df)

# Save the DataFrame to a CSV file
CRUDE_df.to_csv('data_CRUDE.csv', index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#      Interval                Date       Open       High        Low      Close  \
# 0         15m 2023-11-08 00:00:00  81.580002  81.580002  81.559998  81.580002
# 1         15m 2023-11-08 00:15:00  81.500000  81.500000  81.389999  81.389999
# 2         15m 2023-11-08 00:30:00  81.400002  81.440002  81.389999  81.430000
# 3         15m 2023-11-08 00:45:00  81.400002  81.480003  81.400002  81.480003
# 4         15m 2023-11-08 01:00:00  81.480003  81.510002  81.440002  81.489998
# ...       ...                 ...        ...        ...        ...        ...
# 3204      15m 2024-01-05 15:45:00  78.760002  78.849998  78.750000  78.839996
# 3205      15m 2024-01-05 16:00:00  78.839996  78.900002  78.800003  78.809998
# 3206      15m 2024-01-05 16:15:00  78.809998  78.839996  78.809998  78.839996
# 3207      15m 2024-01-05 16:30:00  78.820000  78.820000  78.769997  78.769997
# 3208      15m 2024-01-05 16:45:00  78.779999  78.900002  78.779999  78.900002
#
#       Adj Close  Volume
# 0     81.580002      10
# 1     81.389999      14
# 2     81.430000      19
# 3     81.480003       3
# 4     81.489998      27
# ...         ...     ...
# 3204  78.839996     216
# 3205  78.809998      78
# 3206  78.839996      12
# 3207  78.769997      27
# 3208  78.900002      88
#
# [3209 rows x 8 columns]

# %% [markdown]
# # Variables

# %%
## Add Diff Columns
TISCO_15m_df['Diff'] = TISCO_15m_df['Open'] - TISCO_15m_df['Close']
ERW_15m_df['Diff'] = ERW_15m_df['Open'] - ERW_15m_df['Close']
SPRC_15m_df['Diff'] = SPRC_15m_df['Open'] - SPRC_15m_df['Close']

# %%
# Set Variables
# Set Y
tisco15_diff = TISCO_15m_df['Diff']
erw15_diff = ERW_15m_df['Diff']
sprc15_diff = SPRC_15m_df['Diff']

# Features (X)
tisco15_close = TISCO_15m_df[['Date', 'Close']]
erw15_close = ERW_15m_df[['Date', 'Close']]
sprc15_close = SPRC_15m_df[['Date', 'Close']]
tisco15_vol = TISCO_15m_df[['Date', 'Volume']]
erw15_vol = ERW_15m_df[['Date', 'Volume']]
sprc15_vol = SPRC_15m_df[['Date', 'Volume']]
usd = USD_df[['Date', 'Close']]
cny = CNY_df[['Date', 'Close']]
set100 = SET100_df[['Date', 'Close']]
set50 = SET50_df[['Date', 'Close']]
gold = GOLD_df[['Date', 'Close']]
fin = FINCIAL_df[['Date', 'Close']]
bank = BANKING_df[['Date', 'Close']]
service = SERVICE_df[['Date', 'Close']]
tour = TOURISM_df[['Date', 'Close']]
resource = RESOURCE_df[['Date', 'Close']]
energy = ENERGY_df[['Date', 'Close']]
brent = BRENT_df[['Date', 'Close']]
crude = CRUDE_df[['Date', 'Close']]

# %% [markdown]
# # Waiting

# %%
# Assuming all your data frames have the same index (timestamps)
keys = ['tisco15_close', 'erw15_close', 'sprc15_close',
        'tisco15_vol', 'erw15_vol', 'sprc15_vol',
        'usd', 'cny', 'set100', 'set50',
        'gold', 'fin', 'bank', 'service', 'tour',
        'resource', 'energy', 'brent', 'crude']

# Assuming tisco15_close has Datetime index
reference_index = tisco15_close.index

# Concatenate and reindex based on the reference index
merged_data = pd.concat([tisco15_close, erw15_close, sprc15_close,
                        tisco15_vol, erw15_vol, sprc15_vol,
                        usd, cny, set100, set50,
                        gold, fin, bank, service, tour,
                        resource, energy, brent, crude], axis=1, keys=keys).reindex(reference_index)

# %%
#Check Null values
nan_count = merged_data.isna().sum()
print("NaN (n) = 722:")
print(nan_count, '\n')
# Out:
# NaN (n) = 722:
# tisco15_close  Date        0
#                Close       0
# erw15_close    Date        0
#                Close       0
# sprc15_close   Date        2
#                Close       2
# tisco15_vol    Date        0
#                Volume      0
# erw15_vol      Date        0
#                Volume      0
# sprc15_vol     Date        2
#                Volume      2
# usd            Date        0
#                Close       0
# cny            Date        0
#                Close       0
# set100         Date      298
#                Close     298
# set50          Date        0
#                Close       0
# gold           Date        0
#                Close       0
# fin            Date        0
#                Close       0
# bank           Date        0
#                Close       0
# service        Date        0
#                Close       0
# tour           Date        0
#                Close       0
# resource       Date        0
#                Close       0
# energy         Date        0
#                Close       0
# brent          Date        0
#                Close       0
# crude          Date        0
#                Close       0
# dtype: int64

# %%
column_names_list = list(merged_data.columns)
print(column_names_list)
# Out:
# [('tisco15_close', 'Date'), ('tisco15_close', 'Close'), ('erw15_close', 'Date'), ('erw15_close', 'Close'), ('sprc15_close', 'Date'), ('sprc15_close', 'Close'), ('tisco15_vol', 'Date'), ('tisco15_vol', 'Volume'), ('erw15_vol', 'Date'), ('erw15_vol', 'Volume'), ('sprc15_vol', 'Date'), ('sprc15_vol', 'Volume'), ('usd', 'Date'), ('usd', 'Close'), ('cny', 'Date'), ('cny', 'Close'), ('set100', 'Date'), ('set100', 'Close'), ('set50', 'Date'), ('set50', 'Close'), ('gold', 'Date'), ('gold', 'Close'), ('fin', 'Date'), ('fin', 'Close'), ('bank', 'Date'), ('bank', 'Close'), ('service', 'Date'), ('service', 'Close'), ('tour', 'Date'), ('tour', 'Close'), ('resource', 'Date'), ('resource', 'Close'), ('energy', 'Date'), ('energy', 'Close'), ('brent', 'Date'), ('brent', 'Close'), ('crude', 'Date'), ('crude', 'Close')]

# %%
columns = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

fig, axs = plt.subplots(9, 2, figsize=(12, 18))

# Flatten the 2D array of axes to simplify indexing
axs = axs.flatten()

for i, column in enumerate(columns):
    axs[i].hist(merged_data[column], bins=20, color='skyblue', edgecolor='black')
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('Frequency')
    axs[i].set_title(f'Histogram of {column}')
    
    mean_val = merged_data[column].mean()
    median_val = merged_data[column].median()
    
    axs[i].axvline(mean_val, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_val:.2f}')
    axs[i].axvline(median_val, color='green', linestyle='dashed', linewidth=1, label=f'Median: {median_val:.2f}')
    axs[i].legend()

# Hide any unused subplots
for i in range(len(columns), len(axs)):
    axs[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 9
#       6 axs = axs.flatten()
#       8 for i, column in enumerate(columns):
# ----> 9     axs[i].hist(merged_data[column], bins=20, color='skyblue', edgecolor='black')
#      10     axs[i].set_xlabel(column)
#      11     axs[i].set_ylabel('Frequency')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6815, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6813     colors = mcolors.to_rgba_array(color)
#    6814     if len(colors) != nx:
# -> 6815         raise ValueError(f"The 'color' keyword argument must have one "
#    6816                          f"color per dataset, but {nx} datasets and "
#    6817                          f"{len(colors)} colors were provided")
#    6819 hist_kwargs = dict()
#    6821 # if the bin_range is not given, compute without nan numpy
#    6822 # does not do this for us when guessing the range (but will
#    6823 # happily ignore nans when computing the histogram).
#
# ValueError: The 'color' keyword argument must have one color per dataset, but 2 datasets and 1 colors were provided

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(5, 4, figsize=(15, 15))

columns_to_test = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

color = 'pink'

for i, column in enumerate(columns_to_test):
    plt.subplot(5, 4, i + 1)
    sns.boxplot(x=merged_data[column], color=color)
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %%
columns_to_fillna = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_data[column].median()
    merged_data[column].fillna(median_value, inplace=True)

# %%
import scipy.stats as stats

columns_to_test = ['tisco15_close', 'erw15_close', 'sprc15_close', 'tisco15_vol', 'erw15_vol', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank', 'service', 'tour', 'resource', 'energy']

for column_name in columns_to_test:
    df_tmp = merged_data[[column_name]].dropna()
    
    print(f'{column_name} : ', end='')
    
    # Perform Anderson-Darling test for normality
    statistic, critical_values, significance_levels = stats.anderson(df_tmp[column_name], dist='norm')
    print(f'Statistic: {statistic:.3f}, Critical Values: {critical_values}, Significance Levels: {significance_levels}')
    
    # Check normality based on the 5% significance level
    if statistic >= critical_values[2]:
        print('Not normal')
    else:
        print('Normal')
    
    print('==========================================')
# Out:
# tisco15_close : Statistic: 10.798, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# erw15_close : Statistic: 9.390, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# sprc15_close : Statistic: 6.934, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# tisco15_vol : Statistic: 64.464, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# erw15_vol : Statistic: 67.070, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# sprc15_vol : Statistic: 53.443, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# usd : Statistic: 2.732, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# cny : Statistic: 87.586, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# set100 : Statistic: 29.626, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# set50 : Statistic: 87.586, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# gold : Statistic: 16.275, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# fin : Statistic: 5.702, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# bank : Statistic: 11.687, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# service : Statistic: 14.047, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# tour : Statistic: 17.854, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# resource : Statistic: 3.846, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================
# energy : Statistic: 3.849, Critical Values: [0.573 0.652 0.783 0.913 1.086], Significance Levels: [15.  10.   5.   2.5  1. ]
# Not normal
# ==========================================

# %% [markdown]
# TISCO_Preparedata

# %%
import pandas as pd

# Assuming all your data frames have the same index (timestamps)
keys = ['erw15_close', 'tisco15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank']

# Assuming tisco15_close has Datetime index
reference_index = tisco15_close.index

# Concatenate and reindex based on the reference index
merged_data_tisco = pd.concat([tisco15_close, tisco15_vol, usd, cny, set100, set50, gold, fin, bank], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['tisco15_close', 'tisco15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank']

for column in columns_to_fillna:
    median_value = merged_data_tisco[column].median()
    merged_data_tisco[column].fillna(median_value, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['tisco15_close', 'tisco15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'fin', 'bank']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_tisco[columns_to_normalize] = scaler.fit_transform(merged_data_tisco[columns_to_normalize])

# %%
merged_data_tisco
# Out:
#                      tisco15_close  tisco15_vol       usd       cny    set100  \
# Datetime
# 2023-11-07 10:00:00       0.176471     0.013376  0.746753  0.966857  0.749999
# 2023-11-07 10:15:00       0.235294     0.087835  0.724275  0.964755  0.770832
# 2023-11-07 10:30:00       0.294118     0.045933  0.724275  0.961597  0.583332
# 2023-11-07 10:45:00       0.235294     0.172929  0.714284  0.961597  0.854165
# 2023-11-07 11:00:00       0.235294     0.014942  0.737761  0.961597  0.583332
# ...                            ...          ...       ...       ...       ...
# 2024-01-04 15:15:00       0.882353     0.177448  0.194805  0.305103  0.854165
# 2024-01-04 15:30:00       0.823529     0.278268  0.209789  0.299316  0.833334
# 2024-01-04 15:45:00       0.823529     0.052103  0.224774  0.306680  0.583332
# 2024-01-04 16:00:00       0.823529     0.097768  0.199799  0.262493  0.583332
# 2024-01-04 16:15:00       0.823529     0.284257  0.214784  0.262493  0.583332
#
#                         set50      gold       fin      bank
# Datetime
# 2023-11-07 10:00:00  0.966857  0.201041  0.945335  0.814502
# 2023-11-07 10:15:00  0.964755  0.198438  0.966667  0.872399
# 2023-11-07 10:30:00  0.961597  0.189980  0.985333  0.925801
# 2023-11-07 10:45:00  0.961597  0.198438  1.000000  0.951096
# 2023-11-07 11:00:00  0.961597  0.213402  0.966667  0.926363
# ...                       ...       ...       ...       ...
# 2024-01-04 15:15:00  0.305103  0.731944  0.950667  0.887015
# 2024-01-04 15:30:00  0.299316  0.731295  0.965334  0.923552
# 2024-01-04 15:45:00  0.306680  0.724137  0.929333  0.865091
# 2024-01-04 16:00:00  0.262493  0.724788  0.902667  0.815064
# 2024-01-04 16:15:00  0.262493  0.724788  0.932001  0.883079
#
# [722 rows x 9 columns]

# %% [markdown]
# ERW_Preparedata

# %%
import pandas as pd

# Assuming all your data frames have the same index (timestamps)
keys = ['erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

# Assuming tisco15_close has Datetime index
reference_index = erw15_close.index

# Concatenate and reindex based on the reference index
merged_data_erw = pd.concat([erw15_close, erw15_vol, usd, cny, set100, set50, gold, service, tour], axis=1, keys=keys).reindex(reference_index)

# %%
columns_to_fillna = ['erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

for column in columns_to_fillna:
    median_value = merged_data_erw[column].median()
    merged_data_erw[column].fillna(median_value, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['erw15_close', 'erw15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'service', 'tour']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_erw[columns_to_normalize] = scaler.fit_transform(merged_data_erw[columns_to_normalize])

# %%
merged_data_erw
# Out:
#                      erw15_close  erw15_vol       usd       cny    set100  \
# Datetime
# 2023-11-07 10:00:00     0.272727   0.122590  0.746753  0.966857  0.749999
# 2023-11-07 10:15:00     0.363636   0.009813  0.724275  0.964755  0.770832
# 2023-11-07 10:30:00     0.363636   0.162785  0.724275  0.961597  0.583332
# 2023-11-07 10:45:00     0.272727   0.091743  0.714284  0.961597  0.854165
# 2023-11-07 11:00:00     0.363636   0.055249  0.737761  0.961597  0.583332
# ...                          ...        ...       ...       ...       ...
# 2024-01-04 15:15:00     0.545455   0.220211  0.194805  0.305103  0.854165
# 2024-01-04 15:30:00     0.545455   0.005894  0.209789  0.299316  0.833334
# 2024-01-04 15:45:00     0.545455   0.003551  0.224774  0.306680  0.583332
# 2024-01-04 16:00:00     0.545455   0.047863  0.199799  0.262493  0.583332
# 2024-01-04 16:15:00     0.636363   0.244604  0.214784  0.262493  0.583332
#
#                         set50      gold   service      tour
# Datetime
# 2023-11-07 10:00:00  0.966857  0.201041  0.899195  0.698008
# 2023-11-07 10:15:00  0.964755  0.198438  0.936129  0.766373
# 2023-11-07 10:30:00  0.961597  0.189980  0.926687  0.753813
# 2023-11-07 10:45:00  0.961597  0.198438  0.950847  0.760453
# 2023-11-07 11:00:00  0.961597  0.213402  0.940572  0.763503
# ...                       ...       ...       ...       ...
# 2024-01-04 15:15:00  0.305103  0.731944  0.869203  0.944195
# 2024-01-04 15:30:00  0.299316  0.731295  0.886698  0.944733
# 2024-01-04 15:45:00  0.306680  0.724137  0.874202  0.946349
# 2024-01-04 16:00:00  0.262493  0.724788  0.892808  0.970752
# 2024-01-04 16:15:00  0.262493  0.724788  0.895862  0.956397
#
# [722 rows x 9 columns]

# %% [markdown]
# SPRC_Preparedata

# %%
import pandas as pd

# Assuming all your data frames have the same index (timestamps)
keys = ['erw15_close','sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

# Assuming tisco15_close has Datetime index
reference_index = erw15_close.index

# Concatenate and reindex based on the reference index
merged_data_SRPC = pd.concat([erw15_close, sprc15_close, sprc15_vol, usd ,cny, set100, set50, gold, resource, energy], axis=1, keys=keys).reindex(reference_index)

# %%
merged_data_SRPC
# Out:
#                      erw15_close  sprc15_close  sprc15_vol        usd     cny  \
# Datetime
# 2023-11-07 10:00:00         5.15          7.90    262100.0  35.575001  7.2839
# 2023-11-07 10:15:00         5.20          7.85     64802.0  35.529999  7.2835
# 2023-11-07 10:30:00         5.20          7.90     49000.0  35.529999  7.2829
# 2023-11-07 10:45:00         5.15          7.95    727700.0  35.509998  7.2829
# 2023-11-07 11:00:00         5.20          7.95    122200.0  35.556999  7.2829
# ...                          ...           ...         ...        ...     ...
# 2024-01-04 15:15:00         5.30          8.50     78505.0  34.470001  7.1581
# 2024-01-04 15:30:00         5.30          8.60   1314803.0  34.500000  7.1570
# 2024-01-04 15:45:00         5.30          8.50   1469200.0  34.529999  7.1584
# 2024-01-04 16:00:00         5.30          8.50    498299.0  34.480000     NaN
# 2024-01-04 16:15:00         5.35          8.50    774040.0  34.509998     NaN
#
#                      set100   set50         gold    resource        energy
# Datetime
# 2023-11-07 10:00:00    9.23  7.2839  1970.300049  177.960007  20298.009766
# 2023-11-07 10:15:00    9.24  7.2835  1969.900024  178.619995  20373.859375
# 2023-11-07 10:30:00     NaN  7.2829  1968.599976  178.160004  20320.609375
# 2023-11-07 10:45:00    9.28  7.2829  1969.900024  179.440002  20467.009766
# 2023-11-07 11:00:00     NaN  7.2829  1972.199951  179.039993  20421.060547
# ...                     ...     ...          ...         ...           ...
# 2024-01-04 15:15:00    9.28  7.1581  2051.899902  183.220001  20898.240234
# 2024-01-04 15:30:00    9.27  7.1570  2051.800049  182.949997  20867.529297
# 2024-01-04 15:45:00     NaN  7.1584  2050.699951  182.639999  20832.240234
# 2024-01-04 16:00:00     NaN     NaN  2050.800049  182.380005  20802.810547
# 2024-01-04 16:15:00     NaN     NaN  2050.800049  182.779999  20847.810547
#
# [722 rows x 10 columns]

# %%
columns_to_fillna = ['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

for column in columns_to_fillna:
    median_value = merged_data_SRPC[column].median()
    merged_data_SRPC[column].fillna(median_value, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# Specify the columns you want to normalize
columns_to_normalize = ['sprc15_close', 'sprc15_vol', 'usd', 'cny', 'set100', 'set50', 'gold', 'resource', 'energy']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the specified columns
merged_data_SRPC[columns_to_normalize] = scaler.fit_transform(merged_data_SRPC[columns_to_normalize])

# %%
merged_data_SRPC
# Out:
#                      erw15_close  sprc15_close  sprc15_vol       usd  \
# Datetime
# 2023-11-07 10:00:00         5.15      0.384615    0.026153  0.746753
# 2023-11-07 10:15:00         5.20      0.346154    0.006413  0.724275
# 2023-11-07 10:30:00         5.20      0.384615    0.004832  0.724275
# 2023-11-07 10:45:00         5.15      0.423077    0.072736  0.714284
# 2023-11-07 11:00:00         5.20      0.423077    0.012156  0.737761
# ...                          ...           ...         ...       ...
# 2024-01-04 15:15:00         5.30      0.846154    0.007784  0.194805
# 2024-01-04 15:30:00         5.30      0.923077    0.131476  0.209789
# 2024-01-04 15:45:00         5.30      0.846154    0.146923  0.224774
# 2024-01-04 16:00:00         5.30      0.846154    0.049785  0.199799
# 2024-01-04 16:15:00         5.35      0.846154    0.077373  0.214784
#
#                           cny    set100     set50      gold  resource  \
# Datetime
# 2023-11-07 10:00:00  0.966857  0.749999  0.966857  0.201041  0.216299
# 2023-11-07 10:15:00  0.964755  0.770832  0.964755  0.198438  0.282696
# 2023-11-07 10:30:00  0.961597  0.583332  0.961597  0.189980  0.236419
# 2023-11-07 10:45:00  0.961597  0.854165  0.961597  0.198438  0.365192
# 2023-11-07 11:00:00  0.961597  0.583332  0.961597  0.213402  0.324949
# ...                       ...       ...       ...       ...       ...
# 2024-01-04 15:15:00  0.305103  0.854165  0.305103  0.731944  0.745473
# 2024-01-04 15:30:00  0.299316  0.833334  0.299316  0.731295  0.718310
# 2024-01-04 15:45:00  0.306680  0.583332  0.306680  0.724137  0.687123
# 2024-01-04 16:00:00  0.262493  0.583332  0.262493  0.724788  0.660966
# 2024-01-04 16:15:00  0.262493  0.583332  0.262493  0.724788  0.701207
#
#                        energy
# Datetime
# 2023-11-07 10:00:00  0.216340
# 2023-11-07 10:15:00  0.283205
# 2023-11-07 10:30:00  0.236263
# 2023-11-07 10:45:00  0.365322
# 2023-11-07 11:00:00  0.324815
# ...                       ...
# 2024-01-04 15:15:00  0.745471
# 2024-01-04 15:30:00  0.718398
# 2024-01-04 15:45:00  0.687289
# 2024-01-04 16:00:00  0.661345
# 2024-01-04 16:15:00  0.701015
#
# [722 rows x 10 columns]

# %%
import pandas as pd
import talib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf
import numpy as np

# Calculate MACD
# Calculate MACD with forward-fill to handle NaN values
tisco15_close['macd'], tisco15_close['signal'], _ = talib.MACD(tisco15_close['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
tisco15_close[['macd', 'signal']] = tisco15_close[['macd', 'signal']].fillna(method='ffill')

# Create Label (target variable)
tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['macd', 'signal', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])
    
# Create Features
features = tisco15_close[['macd', 'signal']]
print(features)
# Create Label (target variable)

tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['macd', 'signal', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])


# Remove rows with missing data
tisco15_close = tisco15_close.dropna(subset=['macd', 'signal', 'target'])

print("Shape of features:", features.shape)
print("Shape of target:", tisco15_close['target'].shape)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, tisco15_close['target'], test_size=0.2, random_state=42)

# Create and Train Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Test the Model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# Evaluate the Model
print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(y_test, predictions))
# Out:
#          macd    signal
# 363  0.070184  0.116045
# 364  0.062764  0.105389
# 365  0.056235  0.095558
# 366  0.030536  0.082554
# 367  0.029996  0.072042
# ..        ...       ...
# 717  0.194880  0.188273
# 718  0.193731  0.189364
# 719  0.190623  0.189616
# 720  0.186015  0.188896
# 721  0.180285  0.187174
#
# [359 rows x 2 columns]
# Shape of features: (359, 2)
# Shape of target: (359,)
# Accuracy: 0.6527777777777778
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76        54
#            1       0.33      0.39      0.36        18
#
#     accuracy                           0.65        72
#    macro avg       0.56      0.56      0.56        72
# weighted avg       0.67      0.65      0.66        72
# /var/folders/xn/r6g6gmhd0jl_k9sn_4sp2vzr0000gp/T/ipykernel_40438/211605243.py:12: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   tisco15_close[['macd', 'signal']] = tisco15_close[['macd', 'signal']].fillna(method='ffill')

# %%
import pandas as pd
import talib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf
import numpy as np

# Calculate Moving Averages
# Assume you want to use a simple moving average (SMA) with a window of 10 periods
tisco15_close['ma'] = talib.SMA(tisco15_close['Close'], timeperiod=10)

# Create Label (target variable)
tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['ma', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])

# Create Features
features = tisco15_close[['ma']]
print(features)

# Verify the shapes of features and target
print("Shape of features:", features.shape)
print("Shape of target:", tisco15_close['target'].shape)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, tisco15_close['target'], test_size=0.2, random_state=42)

# Create and Train Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Test the Model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# Evaluate the Model
print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(y_test, predictions))
# Out:
#           ma
# 372   97.525
# 373   97.525
# 374   97.525
# 375   97.525
# 376   97.550
# ..       ...
# 717  100.450
# 718  100.450
# 719  100.450
# 720  100.450
# 721  100.450
#
# [350 rows x 1 columns]
# Shape of features: (350, 1)
# Shape of target: (350,)
# Accuracy: 0.7428571428571429
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85        54
#            1       0.33      0.12      0.18        16
#
#     accuracy                           0.74        70
#    macro avg       0.56      0.53      0.51        70
# weighted avg       0.68      0.74      0.70        70

# %%
import pandas as pd
import talib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import yfinance as yf
import numpy as np

# Calculate Relative Strength Index (RSI)
# Assume you want to use a window of 14 periods for RSI
tisco15_close['rsi'] = talib.RSI(tisco15_close['Close'], timeperiod=14)

# Create Label (target variable)
tisco15_close['target'] = np.where(tisco15_close['Close'].shift(-1) > tisco15_close['Close'], 1, 0)

# Drop rows with missing data
tisco15_close = tisco15_close.dropna(subset=['rsi', 'target'])

# Check for missing values in the target variable
if tisco15_close['target'].isnull().any():
    print("Warning: There are missing values in the target variable. Dropping rows with missing values.")
    tisco15_close = tisco15_close.dropna(subset=['target'])

# Create Features
features = tisco15_close[['rsi']]
print(features)

# Verify the shapes of features and target
print("Shape of features:", features.shape)
print("Shape of target:", tisco15_close['target'].shape)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, tisco15_close['target'], test_size=0.2, random_state=42)

# Create and Train Decision Tree Model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Test the Model
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)

# Evaluate the Model
print(f"Accuracy: {accuracy}")
print("Classification Report:\n", classification_report(y_test, predictions))
# Out:
#             rsi
# 386  100.000000
# 387  100.000000
# 388  100.000000
# 389  100.000000
# 390  100.000000
# ..          ...
# 717   59.166108
# 718   59.166108
# 719   59.166108
# 720   59.166108
# 721   59.166108
#
# [336 rows x 1 columns]
# Shape of features: (336, 1)
# Shape of target: (336,)
# Accuracy: 0.6764705882352942
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79        48
#            1       0.40      0.20      0.27        20
#
#     accuracy                           0.68        68
#    macro avg       0.56      0.54      0.53        68
# weighted avg       0.63      0.68      0.64        68
